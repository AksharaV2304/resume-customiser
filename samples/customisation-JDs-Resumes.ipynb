# %%
import os
import re
import docx
import fitz  # PyMuPDF
import requests
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# --------------- CONFIG -----------------
RAW_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
JD_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JDs"
OUTPUT_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\LLM_Customised_Resumes"
SAMPLE_TEXT_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\Kartik\EY_ClientFacing_Resume.txt"
LLM_URL = "http://127.0.0.1:1234/v1/chat/completions"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# --------------- HELPERS -----------------
def read_txt(path):
    with open(path, "r", encoding="utf-8") as f:
        return f.read().strip()

def read_pdf(path):
    doc = fitz.open(path)
    return "\n".join([page.get_text() for page in doc])

def read_docx(path):
    doc = docx.Document(path)
    return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

def read_any_resume(path):
    ext = os.path.splitext(path)[1].lower()
    if ext == ".pdf":
        return read_pdf(path)
    elif ext == ".docx":
        return read_docx(path)
    elif ext == ".txt":
        return read_txt(path)
    return ""

def scrub_pii(text):
    text = re.sub(r'\b\d{10}\b', '', text)  # phone
    text = re.sub(r'\S+@\S+', '', text)     # emails
    text = re.sub(r'http\S+|www.\S+', '', text)  # URLs
    return text

def call_llm(prompt):
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": "mistral",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.4,
        "max_tokens": 1800,
        "stream": False
    }
    try:
        res = requests.post(LLM_URL, headers=headers, json=payload)
        return res.json()["choices"][0]["message"]["content"].strip()
    except Exception as e:
        print(f"[ERROR] LLM Call Failed: {e}")
        return ""

def compute_similarity(a, b):
    vecs = TfidfVectorizer().fit_transform([a, b])
    return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

def match_best_jd(resume_text, jd_texts):
    best_match = ""
    best_score = -1
    for name, jd in jd_texts:
        sim = compute_similarity(resume_text, jd)
        if sim > best_score:
            best_score = sim
            best_match = (name, jd)
    return best_match

def build_prompt(resume_text, jd_text, sample_text):
    return f"""
You are a resume writing expert.

Format this resume to align with the job description and exactly follow the structure and tone of the sample. Be concise and role-aligned.

[SAMPLE FORMAT]
{sample_text.strip()}

[JOB DESCRIPTION]
{jd_text.strip()}

[RAW RESUME]
{resume_text.strip()}

[FORMATTED OUTPUT]
"""

# --------------- MAIN PIPELINE -----------------
def run_customization_pipeline():
    print("[INFO] Starting resume customization for batch of resumes...")

    sample_text = read_txt(SAMPLE_TEXT_PATH)

    jd_texts = []
    for file in os.listdir(JD_FOLDER):
        path = os.path.join(JD_FOLDER, file)
        if path.endswith(".txt"):
            jd_texts.append((file, read_txt(path)))
        elif path.endswith(".docx"):
            jd_texts.append((file, read_docx(path)))

    if not jd_texts:
        print("[ERROR] No job descriptions found.")
        return

    results = []

    for resume_file in os.listdir(RAW_FOLDER):
        path = os.path.join(RAW_FOLDER, resume_file)
        if not path.lower().endswith((".pdf", ".docx", ".txt")):
            continue

        resume_text = read_any_resume(path)
        resume_text = scrub_pii(resume_text)

        if not resume_text.strip():
            print(f"[SKIPPED] Empty resume: {resume_file}")
            continue

        best_jd_name, best_jd_text = match_best_jd(resume_text, jd_texts)
        if not best_jd_text.strip():
            print(f"[SKIPPED] No matching JD found: {resume_file}")
            continue

        prompt = build_prompt(resume_text, best_jd_text, sample_text)
        llm_output = call_llm(prompt)

        if not llm_output:
            print(f"[ERROR] LLM returned nothing: {resume_file}")
            continue

        output_path = os.path.join(OUTPUT_FOLDER, f"{os.path.splitext(resume_file)[0]}_formatted.txt")
        with open(output_path, "w", encoding="utf-8") as f:
            f.write(llm_output)

        score = compute_similarity(sample_text, llm_output)
        print(f"[DONE] {resume_file} | Match with Sample: {score}%")
        results.append((resume_file, score))

    print("\n[SUMMARY]")
    for name, score in results:
        print(f"{name}: {score}%")

# ------------------ TRIGGER ---------------------
if __name__ == "__main__":
    run_customization_pipeline()
# Out:
# [INFO] Starting resume customization for batch of resumes...
# [DONE] Anuska Das.pdf | Match with Sample: 51.75%
# [DONE] CV_Aarsh.pdf | Match with Sample: 82.83%
# [DONE] CV_Arnab Roy_Model_Validation.pdf | Match with Sample: 45.24%
# [DONE] G N Sindhur_resume_2025.pdf | Match with Sample: 60.44%
# [DONE] Isha Porwal Resume.pdf | Match with Sample: 80.58%
# [DONE] KartikMohan.pdf | Match with Sample: 77.63%
# [DONE] Kshitij_Sahdev_CV (002).pdf | Match with Sample: 76.28%
# [DONE] Kundan_Kumar.pdf | Match with Sample: 73.53%
# [DONE] Munna Choudhary.pdf | Match with Sample: 78.97%
# [DONE] Narendra_Sahu_CreditRisk.pdf | Match with Sample: 52.97%
# [DONE] Naukri_AbhimanyuSingh[3y_7m].pdf | Match with Sample: 54.71%
# [DONE] Naukri_AnandKumar[10y_0m].pdf | Match with Sample: 71.89%
# [DONE] Naukri_DEBSUBHRAGHOSH[7y_0m].pdf | Match with Sample: 52.08%
# [DONE] Naukri_GirishKhandelwal[11y_0m].docx | Match with Sample: 60.79%
# [DONE] Naukri_SAHILPATIL[2y_11m].pdf | Match with Sample: 71.93%
# [DONE] Naukri_SusmitaMisra[3y_9m].pdf | Match with Sample: 66.24%
# [DONE] Naukri_Vaibhav[3y_6m].pdf | Match with Sample: 75.95%
# [DONE] Naukri_YashRai[4y_0m].pdf | Match with Sample: 59.16%
# [DONE] Nidhika-Tomar.pdf | Match with Sample: 37.73%
# [DONE] Praveen R- Resume.pdf | Match with Sample: 57.35%
# [DONE] Priyajit Bishayee resume 2025.pdf | Match with Sample: 75.71%
# [DONE] Rajvi Doshi.pdf | Match with Sample: 81.23%
# [DONE] Resume - Reema Panday.docx | Match with Sample: 63.39%
# [DONE] Resume.SautrikGanguly.pdf | Match with Sample: 42.05%
# [DONE] Resume_Rahul_kushwaha.pdf | Match with Sample: 65.45%
# [SKIPPED] Empty resume: SAIKIRAN KPMG CV-1-2-2.pdf
# [DONE] Shashwata_Mondal.pdf | Match with Sample: 47.77%
# [DONE] Stuti Mehrotra_CV 1.pdf | Match with Sample: 49.48%
# [DONE] Sulagna Paul Resume (1).pdf | Match with Sample: 66.58%
# [DONE] Vedanti Khokher.pdf | Match with Sample: 82.75%
#
# [SUMMARY]
# Anuska Das.pdf: 51.75%
# CV_Aarsh.pdf: 82.83%
# CV_Arnab Roy_Model_Validation.pdf: 45.24%
# G N Sindhur_resume_2025.pdf: 60.44%
# Isha Porwal Resume.pdf: 80.58%
# KartikMohan.pdf: 77.63%
# Kshitij_Sahdev_CV (002).pdf: 76.28%
# Kundan_Kumar.pdf: 73.53%
# Munna Choudhary.pdf: 78.97%
# Narendra_Sahu_CreditRisk.pdf: 52.97%
# Naukri_AbhimanyuSingh[3y_7m].pdf: 54.71%
# Naukri_AnandKumar[10y_0m].pdf: 71.89%
# Naukri_DEBSUBHRAGHOSH[7y_0m].pdf: 52.08%
# Naukri_GirishKhandelwal[11y_0m].docx: 60.79%
# Naukri_SAHILPATIL[2y_11m].pdf: 71.93%
# Naukri_SusmitaMisra[3y_9m].pdf: 66.24%
# Naukri_Vaibhav[3y_6m].pdf: 75.95%
# Naukri_YashRai[4y_0m].pdf: 59.16%
# Nidhika-Tomar.pdf: 37.73%
# Praveen R- Resume.pdf: 57.35%
# Priyajit Bishayee resume 2025.pdf: 75.71%
# Rajvi Doshi.pdf: 81.23%
# Resume - Reema Panday.docx: 63.39%
# Resume.SautrikGanguly.pdf: 42.05%
# Resume_Rahul_kushwaha.pdf: 65.45%
# Shashwata_Mondal.pdf: 47.77%
# Stuti Mehrotra_CV 1.pdf: 49.48%
# Sulagna Paul Resume (1).pdf: 66.58%
# Vedanti Khokher.pdf: 82.75%

# %%
# import os
# import re
# import fitz
# import docx
# import openpyxl
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # --------- PATH CONFIGURATION ----------
# RAW_RESUME_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# MANUAL_RESUME_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\ManualResumes"
# OUTPUT_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\GeneratedResumes"
# EY_SAMPLE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_format1.txt"
# PROMPT_EXCEL = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JD_Sentence_Variants.xlsx"
# LLM_URL = "http://127.0.0.1:1234/v1/chat/completions"

# os.makedirs(OUTPUT_DIR, exist_ok=True)

# # --------- UTILITY FUNCTIONS ----------
# def read_txt(path):
#     with open(path, "r", encoding="utf-8") as f:
#         return f.read().strip()

# def read_pdf(path):
#     return "\n".join([page.get_text() for page in fitz.open(path)])

# def read_docx(path):
#     return "\n".join([p.text for p in docx.Document(path).paragraphs if p.text.strip()])

# def read_resume(path):
#     ext = os.path.splitext(path)[1].lower()
#     if ext == ".pdf":
#         return read_pdf(path)
#     elif ext == ".docx":
#         return read_docx(path)
#     elif ext == ".txt":
#         return read_txt(path)
#     return ""

# def scrub_pii(text):
#     text = re.sub(r'\b\d{10}\b', '', text)
#     text = re.sub(r'\S+@\S+', '', text)
#     text = re.sub(r'http\S+|www.\S+', '', text)
#     return text

# def compute_similarity(a, b):
#     vecs = TfidfVectorizer().fit_transform([a, b])
#     return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

# def call_llm(prompt):
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.3,
#         "max_tokens": 2000,
#         "stream": False
#     }
#     try:
#         res = requests.post(LLM_URL, headers=headers, json=payload)
#         return res.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"[ERROR] LLM call failed: {e}")
#         return ""

# # --------- JD CONSTRUCTION FROM EXCEL ---------
# def load_jd_sentences():
#     wb = openpyxl.load_workbook(PROMPT_EXCEL)
#     sheet = wb.active
#     jd_map = {}

#     for i, row in enumerate(sheet.iter_rows(min_row=2), start=1):
#         resume_name = row[0].value
#         jd_parts = [str(cell.value).strip() for cell in row[1:] if cell.value]
#         if resume_name and jd_parts:
#             jd_text = "\n".join(jd_parts)
#             jd_map[resume_name.strip()] = jd_text
#     return jd_map

# # --------- PROMPT BUILDER ---------
# def build_prompt(resume_text, jd_text, sample_text):
#     return f"""
# You are a resume writing expert.

# Format this resume to align with the job description and exactly follow the structure and tone of the sample. Do not include personal details or redundant education.

# [SAMPLE FORMAT]
# {sample_text}

# [JOB DESCRIPTION]
# {jd_text}

# [RAW RESUME]
# {resume_text}

# [FORMATTED OUTPUT]
# """

# # --------- MAIN PIPELINE ----------
# def run_automation():
#     sample_text = read_txt(EY_SAMPLE_PATH)
#     jd_map = load_jd_sentences()

#     for resume_file in os.listdir(RAW_RESUME_DIR):
#         resume_name = os.path.splitext(resume_file)[0]
#         resume_path = os.path.join(RAW_RESUME_DIR, resume_file)

#         if resume_name not in jd_map:
#             print(f"[SKIPPED] No JD mapped for: {resume_name}")
#             continue

#         resume_text = read_resume(resume_path)
#         resume_text = scrub_pii(resume_text)

#         if not resume_text.strip():
#             print(f"[SKIPPED] Empty resume: {resume_name}")
#             continue

#         jd_text = jd_map[resume_name]
#         prompt = build_prompt(resume_text, jd_text, sample_text)
#         llm_output = call_llm(prompt)

#         output_path = os.path.join(OUTPUT_DIR, f"{resume_name}_customised.txt")
#         with open(output_path, "w", encoding="utf-8") as f:
#             f.write(llm_output)

#         # --- Compare with manual ---
#         manual_path = os.path.join(MANUAL_RESUME_DIR, f"{resume_name}.txt")
#         if os.path.exists(manual_path):
#             manual_text = read_txt(manual_path)
#             score = compute_similarity(llm_output, manual_text)
#             print(f"[DONE] {resume_file} | Match with Manual: {score}%")
#         else:
#             print(f"[NOTE] Manual resume not found for comparison: {resume_name}")

# # --------- TRIGGER ----------
# if __name__ == "__main__":
#     run_automation()
# Out:
# [SKIPPED] No JD mapped for: Anuska Das
# [SKIPPED] No JD mapped for: CV_Aarsh
# [SKIPPED] No JD mapped for: CV_Arnab Roy_Model_Validation
# [SKIPPED] No JD mapped for: G N Sindhur_resume_2025
# [SKIPPED] No JD mapped for: Isha Porwal Resume
# [SKIPPED] No JD mapped for: KartikMohan
# [SKIPPED] No JD mapped for: Kshitij_Sahdev_CV (002)
# [SKIPPED] No JD mapped for: Kundan_Kumar
# [SKIPPED] No JD mapped for: Munna Choudhary
# [SKIPPED] No JD mapped for: Narendra_Sahu_CreditRisk
# [SKIPPED] No JD mapped for: Naukri_AbhimanyuSingh[3y_7m]
# [SKIPPED] No JD mapped for: Naukri_AnandKumar[10y_0m]
# [SKIPPED] No JD mapped for: Naukri_DEBSUBHRAGHOSH[7y_0m]
# [SKIPPED] No JD mapped for: Naukri_GirishKhandelwal[11y_0m]
# [SKIPPED] No JD mapped for: Naukri_SAHILPATIL[2y_11m]
# [SKIPPED] No JD mapped for: Naukri_SusmitaMisra[3y_9m]
# [SKIPPED] No JD mapped for: Naukri_Vaibhav[3y_6m]
# [SKIPPED] No JD mapped for: Naukri_YashRai[4y_0m]
# [SKIPPED] No JD mapped for: Nidhika-Tomar
# [SKIPPED] No JD mapped for: Praveen R- Resume
# [SKIPPED] No JD mapped for: Priyajit Bishayee resume 2025
# [SKIPPED] No JD mapped for: Rajvi Doshi
# [SKIPPED] No JD mapped for: Resume - Reema Panday
# [SKIPPED] No JD mapped for: Resume.SautrikGanguly
# [SKIPPED] No JD mapped for: Resume_Rahul_kushwaha
# [SKIPPED] No JD mapped for: SAIKIRAN KPMG CV-1-2-2
# [SKIPPED] No JD mapped for: Shashwata_Mondal
# [SKIPPED] No JD mapped for: Stuti Mehrotra_CV 1
# [SKIPPED] No JD mapped for: Sulagna Paul Resume (1)
# [SKIPPED] No JD mapped for: Vedanti Khokher

# %%
# import os
# import re
# import fitz  # PyMuPDF
# import docx
# import pandas as pd
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # --------------- CONFIG -----------------
# RAW_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# OUTPUT_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Prompt_Customised_Resumes"
# SAMPLE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_format1.txt"
# JD_PROMPT_EXCEL = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JD_Sentence_Variants.xlsx"
# JD_PROMPT_SHEET = "Sheet1"  # update if the sheet has a different name
# JD_PROMPT_COL = "Prompt"   # update if prompt column is named differently

# os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# # --------------- HELPERS -----------------
# def normalize_name(name):
#     name = os.path.splitext(name)[0]
#     name = name.lower()
#     return re.sub(r'[^a-z0-9]', '', name)  # keep only alphanumeric

# def read_txt(path):
#     with open(path, "r", encoding="utf-8") as f:
#         return f.read().strip()

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_any_resume(path):
#     ext = os.path.splitext(path)[1].lower()
#     if ext == ".pdf":
#         return read_pdf(path)
#     elif ext == ".docx":
#         return read_docx(path)
#     elif ext == ".txt":
#         return read_txt(path)
#     return ""

# def scrub_pii(text):
#     text = re.sub(r'\b\d{10}\b', '', text)
#     text = re.sub(r'\S+@\S+', '', text)
#     text = re.sub(r'http\S+|www.\S+', '', text)
#     return text

# def call_llm(prompt):
#     url = "http://127.0.0.1:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.4,
#         "max_tokens": 1800,
#         "stream": False
#     }
#     try:
#         res = requests.post(url, headers=headers, json=payload)
#         return res.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"[ERROR] LLM Call Failed: {e}")
#         return ""

# def compute_similarity(a, b):
#     vecs = TfidfVectorizer().fit_transform([a, b])
#     return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

# def build_prompt(resume_text, jd_prompt, sample_text):
#     return f"""
# You are a resume writing expert.

# Format this resume to align with the job description and exactly follow the structure and tone of the sample. Be concise and role-aligned.

# [SAMPLE FORMAT]
# {sample_text.strip()}

# [JOB DESCRIPTION]
# {jd_prompt.strip()}

# [RAW RESUME]
# {resume_text.strip()}

# [FORMATTED OUTPUT]
# """

# # --------------- MAIN PIPELINE -----------------
# def run_customization_pipeline():
#     print("[INFO] Starting prompt-based resume customization...")

#     sample_text = read_txt(SAMPLE_PATH)

#     # Load JD prompt mapping and normalize keys
#     df = pd.read_excel(JD_PROMPT_EXCEL, sheet_name=JD_PROMPT_SHEET)
#     jd_map = {}
#     for _, row in df.iterrows():
#         raw_key = str(row[0])
#         prompt_text = str(row[JD_PROMPT_COL]) if JD_PROMPT_COL in row else ""
#         if raw_key and prompt_text:
#             normalized_key = normalize_name(raw_key)
#             jd_map[normalized_key] = prompt_text.strip()

#     results = []

#     for resume_file in os.listdir(RAW_FOLDER):
#         path = os.path.join(RAW_FOLDER, resume_file)
#         if not path.lower().endswith((".pdf", ".docx", ".txt")):
#             continue

#         resume_text = read_any_resume(path)
#         resume_text = scrub_pii(resume_text)

#         if not resume_text.strip():
#             print(f"[SKIPPED] Empty resume: {resume_file}")
#             continue

#         resume_key = normalize_name(resume_file)
#         if resume_key not in jd_map:
#             print(f"[SKIPPED] No JD mapped for: {resume_file}")
#             continue

#         jd_prompt = jd_map[resume_key]
#         prompt = build_prompt(resume_text, jd_prompt, sample_text)
#         llm_output = call_llm(prompt)

#         if not llm_output:
#             print(f"[ERROR] LLM returned nothing for: {resume_file}")
#             continue

#         output_path = os.path.join(OUTPUT_FOLDER, f"{resume_key}_customized.txt")
#         with open(output_path, "w", encoding="utf-8") as f:
#             f.write(llm_output)

#         score = compute_similarity(sample_text, llm_output)
#         print(f"[DONE] {resume_file} | Match with Sample: {score}%")
#         results.append((resume_file, score))

#     print("\n[SUMMARY]")
#     for name, score in results:
#         print(f"{name}: {score}%")

# # --------------- TRIGGER -----------------
# if __name__ == "__main__":
#     run_customization_pipeline()
# Out:
# [INFO] Starting prompt-based resume customization...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 150
#     148 # --------------- TRIGGER -----------------
#     149 if __name__ == "__main__":
# --> 150     run_customization_pipeline()
#
# Cell In[1], line 100, in run_customization_pipeline()
#      97 sample_text = read_txt(SAMPLE_PATH)
#      99 # Load JD prompt mapping and normalize keys
# --> 100 df = pd.read_excel(JD_PROMPT_EXCEL, sheet_name=JD_PROMPT_SHEET)
#     101 jd_map = {}
#     102 for _, row in df.iterrows():
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:508, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502     raise ValueError(
#     503         "Engine should not be specified when passing "
#     504         "an ExcelFile - ExcelFile already has the engine set"
#     505     )
#     507 try:
# --> 508     data = io.parse(
#     509         sheet_name=sheet_name,
#     510         header=header,
#     511         names=names,
#     512         index_col=index_col,
#     513         usecols=usecols,
#     514         dtype=dtype,
#     515         converters=converters,
#     516         true_values=true_values,
#     517         false_values=false_values,
#     518         skiprows=skiprows,
#     519         nrows=nrows,
#     520         na_values=na_values,
#     521         keep_default_na=keep_default_na,
#     522         na_filter=na_filter,
#     523         verbose=verbose,
#     524         parse_dates=parse_dates,
#     525         date_parser=date_parser,
#     526         date_format=date_format,
#     527         thousands=thousands,
#     528         decimal=decimal,
#     529         comment=comment,
#     530         skipfooter=skipfooter,
#     531         dtype_backend=dtype_backend,
#     532     )
#     533 finally:
#     534     # make sure to close opened file handles
#     535     if should_close:
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1616, in ExcelFile.parse(self, sheet_name, header, names, index_col, usecols, converters, true_values, false_values, skiprows, nrows, na_values, parse_dates, date_parser, date_format, thousands, comment, skipfooter, dtype_backend, **kwds)
#    1576 def parse(
#    1577     self,
#    1578     sheet_name: str | int | list[int] | list[str] | None = 0,
#    (...)
#    1596     **kwds,
#    1597 ) -> DataFrame | dict[str, DataFrame] | dict[int, DataFrame]:
#    1598     """
#    1599     Parse specified sheet(s) into a DataFrame.
#    1600
#    (...)
#    1614     >>> file.parse()  # doctest: +SKIP
#    1615     """
# -> 1616     return self._reader.parse(
#    1617         sheet_name=sheet_name,
#    1618         header=header,
#    1619         names=names,
#    1620         index_col=index_col,
#    1621         usecols=usecols,
#    1622         converters=converters,
#    1623         true_values=true_values,
#    1624         false_values=false_values,
#    1625         skiprows=skiprows,
#    1626         nrows=nrows,
#    1627         na_values=na_values,
#    1628         parse_dates=parse_dates,
#    1629         date_parser=date_parser,
#    1630         date_format=date_format,
#    1631         thousands=thousands,
#    1632         comment=comment,
#    1633         skipfooter=skipfooter,
#    1634         dtype_backend=dtype_backend,
#    1635         **kwds,
#    1636     )
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:773, in BaseExcelReader.parse(self, sheet_name, header, names, index_col, usecols, dtype, true_values, false_values, skiprows, nrows, na_values, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, dtype_backend, **kwds)
#     770     print(f"Reading sheet {asheetname}")
#     772 if isinstance(asheetname, str):
# --> 773     sheet = self.get_sheet_by_name(asheetname)
#     774 else:  # assume an integer if not a string
#     775     sheet = self.get_sheet_by_index(asheetname)
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_openpyxl.py:582, in OpenpyxlReader.get_sheet_by_name(self, name)
#     581 def get_sheet_by_name(self, name: str):
# --> 582     self.raise_if_bad_sheet_by_name(name)
#     583     return self.book[name]
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:624, in BaseExcelReader.raise_if_bad_sheet_by_name(self, name)
#     622 def raise_if_bad_sheet_by_name(self, name: str) -> None:
#     623     if name not in self.sheet_names:
# --> 624         raise ValueError(f"Worksheet named '{name}' not found")
#
# ValueError: Worksheet named 'Sheet1' not found

# %%
# import os
# import re
# import fitz  # PyMuPDF
# import docx
# import requests
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # ---------------- CONFIGURATION ----------------
# RAW_RESUME_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# OUTPUT_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\LLM_Customised_Resumes"
# SAMPLE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_format1.txt"
# JD_PROMPT_EXCEL = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JD_Sentence_Variants.xlsx"
# JD_PROMPT_SHEET = 'in'  # Corrected sheet name
# LLM_URL = "http://127.0.0.1:1234/v1/chat/completions"

# os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# # ---------------- HELPERS ----------------

# def read_txt(path):
#     with open(path, "r", encoding="utf-8") as f:
#         return f.read().strip()

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_any_resume(path):
#     ext = os.path.splitext(path)[1].lower()
#     if ext == ".pdf":
#         return read_pdf(path)
#     elif ext == ".docx":
#         return read_docx(path)
#     elif ext == ".txt":
#         return read_txt(path)
#     return ""

# def scrub_pii(text):
#     text = re.sub(r'\b\d{10}\b', '', text)
#     text = re.sub(r'\S+@\S+', '', text)
#     text = re.sub(r'http\S+|www.\S+', '', text)
#     return text.strip()

# def call_llm(prompt):
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.4,
#         "max_tokens": 1800,
#         "stream": False
#     }
#     try:
#         res = requests.post(LLM_URL, headers=headers, json=payload)
#         return res.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"[ERROR] LLM call failed: {e}")
#         return ""

# def compute_similarity(a, b):
#     vecs = TfidfVectorizer().fit_transform([a, b])
#     return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

# def normalize_name(name):
#     return re.sub(r'[^a-zA-Z0-9]', '', name.lower())

# # ---------------- PROMPT BUILDING ----------------

# def build_prompt(resume_text, jd_prompt, sample_text):
#     return f"""
# You are a resume customization expert.

# Using the below sample format and tone, customize the raw resume strictly based on the job description and keep the formatting style of the sample.

# [SAMPLE FORMAT]
# {sample_text}

# [JOB DESCRIPTION]
# {jd_prompt}

# [RAW RESUME]
# {resume_text}

# [FORMATTED OUTPUT]
# """

# # ---------------- MAIN ----------------

# def run_customization_pipeline():
#     print("[INFO] Starting prompt-based resume customization...")

#     sample_text = read_txt(SAMPLE_PATH)

#     # Load JD prompt mapping and normalize keys
#     df = pd.read_excel(JD_PROMPT_EXCEL, sheet_name=JD_PROMPT_SHEET)
#     jd_map = {}
#     for _, row in df.iterrows():
#         raw_name = row['Resume File Name']
#         jd_prompt = row['JD Prompt']
#         norm_name = normalize_name(os.path.splitext(raw_name)[0])
#         jd_map[norm_name] = jd_prompt

#     results = []

#     for file in os.listdir(RAW_RESUME_FOLDER):
#         if not file.lower().endswith((".pdf", ".docx", ".txt")):
#             continue

#         resume_path = os.path.join(RAW_RESUME_FOLDER, file)
#         resume_text = scrub_pii(read_any_resume(resume_path))

#         norm_name = normalize_name(os.path.splitext(file)[0])
#         jd_prompt = jd_map.get(norm_name, "")

#         if not jd_prompt:
#             print(f"[SKIPPED] No JD mapped for: {file}")
#             continue

#         prompt = build_prompt(resume_text, jd_prompt, sample_text)
#         llm_output = call_llm(prompt)

#         if not llm_output.strip():
#             print(f"[ERROR] No output from LLM for: {file}")
#             continue

#         output_path = os.path.join(OUTPUT_FOLDER, f"{os.path.splitext(file)[0]}_customized.txt")
#         with open(output_path, "w", encoding="utf-8") as f:
#             f.write(llm_output)

#         match_score = compute_similarity(sample_text, llm_output)
#         print(f"[DONE] {file} | Match Score with Sample: {match_score}%")
#         results.append((file, match_score))

#     print("\n[SUMMARY]")
#     for name, score in results:
#         print(f"{name}: {score}%")

# # ---------------- EXECUTE ----------------

# if __name__ == "__main__":
#     run_customization_pipeline()
# Out:
# [INFO] Starting prompt-based resume customization...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Resume File Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 147
#     144 # ---------------- EXECUTE ----------------
#     146 if __name__ == "__main__":
# --> 147     run_customization_pipeline()
#
# Cell In[1], line 104, in run_customization_pipeline()
#     102 jd_map = {}
#     103 for _, row in df.iterrows():
# --> 104     raw_name = row['Resume File Name']
#     105     jd_prompt = row['JD Prompt']
#     106     norm_name = normalize_name(os.path.splitext(raw_name)[0])
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Resume File Name'

# %%
# import os
# import re
# import docx
# import fitz  # PyMuPDF
# import requests
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # ---------------- CONFIG -----------------
# RAW_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# OUTPUT_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\LLM_Customised_Resumes"
# SAMPLE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\\raw and ey curated samples\EY_sample_format1.txt"
# JD_PROMPT_EXCEL = r"C:\Users\HN338QQ\OneDrive - EY\Documents\\raw and ey curated samples\JD_Sentence_Variants.xlsx"
# JD_PROMPT_SHEET = "in"
# LLM_URL = "http://127.0.0.1:1234/v1/chat/completions"
# os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# # ---------------- HELPERS ----------------
# def read_txt(path):
#     with open(path, "r", encoding="utf-8") as f:
#         return f.read().strip()

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_any_resume(path):
#     ext = os.path.splitext(path)[1].lower()
#     if ext == ".pdf":
#         return read_pdf(path)
#     elif ext == ".docx":
#         return read_docx(path)
#     elif ext == ".txt":
#         return read_txt(path)
#     return ""

# def scrub_pii(text):
#     text = re.sub(r'\b\d{10}\b', '', text)
#     text = re.sub(r'\S+@\S+', '', text)
#     text = re.sub(r'http\S+|www.\S+', '', text)
#     return text

# def normalize_name(name):
#     return re.sub(r'\W+', '', name).lower()

# def call_llm(prompt):
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.4,
#         "max_tokens": 1800,
#         "stream": False
#     }
#     try:
#         res = requests.post(LLM_URL, headers=headers, json=payload)
#         return res.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"[ERROR] LLM call failed: {e}")
#         return ""

# def compute_similarity(a, b):
#     vecs = TfidfVectorizer().fit_transform([a, b])
#     return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

# def build_prompt(resume_text, jd_prompt, sample_text):
#     return f"""
# You are a resume writing expert.

# Format this resume to align with the job description and exactly follow the structure and tone of the sample. Be concise and role-aligned.

# [SAMPLE FORMAT]
# {sample_text.strip()}

# [JOB DESCRIPTION]
# {jd_prompt.strip()}

# [RAW RESUME]
# {resume_text.strip()}

# [FORMATTED OUTPUT]
# """

# # ---------------- PIPELINE ----------------
# def run_customization_pipeline():
#     print("[INFO] Starting resume customization for batch of resumes...\n")

#     sample_text = read_txt(SAMPLE_PATH)

#     # Load JD prompt mapping and normalize keys
#     df = pd.read_excel(JD_PROMPT_EXCEL, sheet_name=JD_PROMPT_SHEET)
#     jd_map = {}
#     for _, row in df.iterrows():
#         raw_name = str(row['Resume'])  # Excel column name
#         jd_prompt = str(row['Prompt'])  # Excel column name
#         norm_name = normalize_name(os.path.splitext(raw_name)[0])
#         jd_map[norm_name] = jd_prompt

#     results = []

#     for file in os.listdir(RAW_FOLDER):
#         resume_path = os.path.join(RAW_FOLDER, file)
#         if not resume_path.lower().endswith((".pdf", ".docx", ".txt")):
#             continue

#         raw_text = read_any_resume(resume_path)
#         scrubbed = scrub_pii(raw_text)

#         base_name = normalize_name(os.path.splitext(file)[0])
#         jd_prompt = jd_map.get(base_name)

#         if not jd_prompt:
#             print(f"[SKIPPED] No JD mapped for: {file}")
#             continue

#         prompt = build_prompt(scrubbed, jd_prompt, sample_text)
#         llm_output = call_llm(prompt)

#         if not llm_output:
#             print(f"[ERROR] LLM returned nothing: {file}")
#             continue

#         out_path = os.path.join(OUTPUT_FOLDER, f"{os.path.splitext(file)[0]}_formatted.txt")
#         with open(out_path, "w", encoding="utf-8") as f:
#             f.write(llm_output)

#         sim_score = compute_similarity(sample_text, llm_output)
#         print(f"[DONE] {file} | Match with Sample: {sim_score}%")
#         results.append((file, sim_score))

#     print("\n[SUMMARY]")
#     for name, score in results:
#         print(f"{name}: {score}%")

# # ---------------- EXECUTE ----------------
# if __name__ == "__main__":
#     run_customization_pipeline()
# Out:
# [INFO] Starting resume customization for batch of resumes...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Resume'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 142
#     140 # ---------------- EXECUTE ----------------
#     141 if __name__ == "__main__":
# --> 142     run_customization_pipeline()
#
# Cell In[1], line 99, in run_customization_pipeline()
#      97 jd_map = {}
#      98 for _, row in df.iterrows():
# ---> 99     raw_name = str(row['Resume'])  # Excel column name
#     100     jd_prompt = str(row['Prompt'])  # Excel column name
#     101     norm_name = normalize_name(os.path.splitext(raw_name)[0])
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Resume'

# %%
# import os
# import re
# import docx
# import fitz  # PyMuPDF
# import requests
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # ---------------- CONFIG ----------------
# RAW_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# OUTPUT_FOLDER = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Prompt_Customised_Resumes"
# SAMPLE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_format1.txt"
# JD_PROMPT_EXCEL = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JD_Sentence_Variants.xlsx"
# JD_PROMPT_SHEET = "in"
# LLM_URL = "http://127.0.0.1:1234/v1/chat/completions"

# os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# # ---------------- HELPERS ----------------
# def read_txt(path):
#     with open(path, "r", encoding="utf-8") as f:
#         return f.read().strip()

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_any_resume(path):
#     ext = os.path.splitext(path)[1].lower()
#     if ext == ".pdf":
#         return read_pdf(path)
#     elif ext == ".docx":
#         return read_docx(path)
#     elif ext == ".txt":
#         return read_txt(path)
#     return ""

# def scrub_pii(text):
#     text = re.sub(r'\b\d{10}\b', '', text)
#     text = re.sub(r'\S+@\S+', '', text)
#     text = re.sub(r'http\S+|www.\S+', '', text)
#     return text

# def call_llm(prompt):
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.4,
#         "max_tokens": 1800,
#         "stream": False
#     }
#     try:
#         res = requests.post(LLM_URL, headers=headers, json=payload)
#         return res.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"[ERROR] LLM Call Failed: {e}")
#         return ""

# def compute_similarity(a, b):
#     vecs = TfidfVectorizer().fit_transform([a, b])
#     return round(float(cosine_similarity(vecs[0:1], vecs[1:2])[0][0]) * 100, 2)

# def normalize_name(name):
#     return re.sub(r'[^a-z0-9]', '', name.lower())

# # ---------------- PROMPT CONSTRUCTION ----------------
# def build_prompt(resume_text, prompt_text, sample_text):
#     return f"""
# You are a resume writing expert.

# Format this resume to align with the following prompt and exactly follow the structure and tone of the sample. Be concise and role-aligned.

# [SAMPLE FORMAT]
# {sample_text.strip()}

# [JD PROMPT]
# {prompt_text.strip()}

# [RAW RESUME]
# {resume_text.strip()}

# [FORMATTED OUTPUT]
# """

# # ---------------- MAIN PIPELINE ----------------
# def run_customization_pipeline():
#     print("[INFO] Starting resume customization using JD prompts...")

#     sample_text = read_txt(SAMPLE_PATH)

#     # Load JD prompt mapping and normalize keys
#     df = pd.read_excel(JD_PROMPT_EXCEL, sheet_name=JD_PROMPT_SHEET)
#     jd_map = {}
#     for _, row in df.iterrows():
#         raw_name = row['JD Resume Mapping']
#         jd_prompt = row['Prompt']
#         norm_name = normalize_name(os.path.splitext(raw_name)[0])
#         jd_map[norm_name] = jd_prompt

#     results = []

#     for file in os.listdir(RAW_FOLDER):
#         path = os.path.join(RAW_FOLDER, file)
#         if not path.lower().endswith((".pdf", ".docx", ".txt")):
#             continue

#         resume_text = read_any_resume(path)
#         resume_text = scrub_pii(resume_text)

#         if not resume_text.strip():
#             print(f"[SKIPPED] Empty resume: {file}")
#             continue

#         norm_resume = normalize_name(os.path.splitext(file)[0])
#         if norm_resume not in jd_map:
#             print(f"[SKIPPED] No JD mapped for: {file}")
#             continue

#         prompt_text = jd_map[norm_resume]
#         prompt = build_prompt(resume_text, prompt_text, sample_text)
#         llm_output = call_llm(prompt)

#         if not llm_output:
#             print(f"[ERROR] LLM failed for: {file}")
#             continue

#         output_path = os.path.join(OUTPUT_FOLDER, f"{os.path.splitext(file)[0]}_customized.txt")
#         with open(output_path, "w", encoding="utf-8") as f:
#             f.write(llm_output)

#         score = compute_similarity(sample_text, llm_output)
#         print(f"[DONE] {file} | Match with Sample: {score}%")
#         results.append((file, score))

#     print("\n[SUMMARY]")
#     for name, score in results:
#         print(f"{name}: {score}%")

# # ---------------- EXECUTE ----------------
# if __name__ == "__main__":
#     run_customization_pipeline()
# Out:
# [INFO] Starting resume customization using JD prompts...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'JD Resume Mapping'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 147
#     145 # ---------------- EXECUTE ----------------
#     146 if __name__ == "__main__":
# --> 147     run_customization_pipeline()
#
# Cell In[1], line 101, in run_customization_pipeline()
#      99 jd_map = {}
#     100 for _, row in df.iterrows():
# --> 101     raw_name = row['JD Resume Mapping']
#     102     jd_prompt = row['Prompt']
#     103     norm_name = normalize_name(os.path.splitext(raw_name)[0])
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'JD Resume Mapping'

# %%
# import os
# import json
# import requests
# import time
# import zipfile
# import re
# import docx
# import fitz  # PyMuPDF
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # === PATHS ===
# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
# jd_excel_path = os.path.join(base_path, "JD_Sentence_Variants.xlsx")
# ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
# raw_zip = os.path.join(base_path, "Rawresumes.zip")
# manual_zip = os.path.join(base_path, "manualcustomisedresumes.zip")

# jd_output_dir = os.path.join(base_path, "generated_jds")
# custom_output_dir = os.path.join(base_path, "customized_resumes")
# log_output_dir = os.path.join(base_path, "match_logs")

# os.makedirs(jd_output_dir, exist_ok=True)
# os.makedirs(custom_output_dir, exist_ok=True)
# os.makedirs(log_output_dir, exist_ok=True)

# # === JD GENERATION (LM STUDIO) ===
# def generate_jd(prompt):
#     url = "http://localhost:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral-7b-instruct-v0.3-q4_k_m-gguf",
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.7
#     }
#     try:
#         res = requests.post(url, headers=headers, data=json.dumps(payload), timeout=60)
#         res.raise_for_status()
#         return res.json()['choices'][0]['message']['content'].strip()
#     except Exception as e:
#         print(f"LM Studio error for prompt: {prompt[:60]}... -> {e}")
#         return ""

# def generate_all_jds():
#     df = pd.read_excel(jd_excel_path)
#     for i, row in df.iterrows():
#         prompt = str(row[0]).strip()
#         if not prompt:
#             continue
#         print(f"Generating JD_{i+1}.txt")
#         jd_text = generate_jd(prompt)
#         if jd_text:
#             with open(os.path.join(jd_output_dir, f"JD_{i+1}.txt"), "w", encoding="utf-8") as f:
#                 f.write(jd_text)
#         time.sleep(1)

# # === FILE LOADERS ===
# def extract_zip(zip_path, extract_to):
#     os.makedirs(extract_to, exist_ok=True)
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf(file_path):
#     doc = fitz.open(file_path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(file_path):
#     doc = docx.Document(file_path)
#     return "\n".join([para.text for para in doc.paragraphs if para.text.strip()])

# def load_resumes(folder):
#     resumes = {}
#     for file in os.listdir(folder):
#         path = os.path.join(folder, file)
#         name = os.path.splitext(file)[0]
#         try:
#             if file.endswith(".pdf"):
#                 resumes[name] = read_pdf(path)
#             elif file.endswith(".docx"):
#                 resumes[name] = read_docx(path)
#         except Exception as e:
#             print(f"Error reading {file}: {e}")
#     return resumes

# # === TEXT MATCHING ===
# def get_most_relevant_sections(jd_text, resume_text, top_k=5):
#     sentences = [s.strip() for s in resume_text.split('\n') if len(s.strip()) > 20]
#     all_texts = [jd_text] + sentences
#     tfidf = TfidfVectorizer().fit_transform(all_texts)
#     scores = cosine_similarity(tfidf[0:1], tfidf[1:]).flatten()
#     top_indices = scores.argsort()[-top_k:][::-1]
#     return "\n".join([sentences[i] for i in top_indices]), float(scores[top_indices].mean())

# # === FORMAT OUTPUT ===
# def format_resume(ey_template_text, injected_text):
#     return ey_template_text.replace("[EXPERIENCE_PLACEHOLDER]", injected_text)

# # === MAIN PIPELINE ===
# def run_pipeline():
#     # Extract raw and manual resumes
#     raw_path = os.path.join(base_path, "raw_resume_extracted")
#     manual_path = os.path.join(base_path, "manual_resume_extracted")
#     extract_zip(raw_zip, raw_path)
#     extract_zip(manual_zip, manual_path)

#     # Load data
#     raw_resumes = load_resumes(raw_path)
#     manual_resumes = load_resumes(manual_path)

#     with open(ey_format_path, "r", encoding="utf-8") as f:
#         ey_template = f.read()

#     # Loop through each JD and match
#     for jd_file in os.listdir(jd_output_dir):
#         jd_path = os.path.join(jd_output_dir, jd_file)
#         jd_name = os.path.splitext(jd_file)[0]
#         with open(jd_path, "r", encoding="utf-8") as f:
#             jd_text = f.read()

#         for raw_name, raw_text in raw_resumes.items():
#             matched_text, match_score = get_most_relevant_sections(jd_text, raw_text)
#             customized_resume = format_resume(ey_template, matched_text)
#             out_path = os.path.join(custom_output_dir, f"{jd_name}__{raw_name}.txt")
#             with open(out_path, "w", encoding="utf-8") as f:
#                 f.write(customized_resume)

#             # Match against manual
#             manual_match_text = manual_resumes.get(raw_name, "")
#             sim_to_manual, _ = get_most_relevant_sections(customized_resume, manual_match_text)

#             # Save log
#             log_data = {
#                 "JD": jd_name,
#                 "Candidate": raw_name,
#                 "AutoGenerated_vs_Raw_Score": round(match_score, 4),
#                 "AutoGenerated_vs_Manual_Score": round(_, 4)
#             }
#             log_file = os.path.join(log_output_dir, f"{jd_name}__{raw_name}.json")
#             with open(log_file, "w") as lf:
#                 json.dump(log_data, lf, indent=2)

# # === RUN ALL ===
# if __name__ == "__main__":
#     print("STEP 1: Generating all JDs from prompts using LM Studio...")
#     generate_all_jds()

#     print("STEP 2 to 5: Running full resume customization pipeline...")
#     run_pipeline()
#     print("Done. Customized resumes and logs are saved.")
# Out:
# STEP 1: Generating all JDs from prompts using LM Studio...
# C:\Users\HN338QQ\AppData\Local\Temp\ipykernel_11700\3878804757.py:48: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prompt = str(row[0]).strip()
# Generating JD_1.txt
# LM Studio error for prompt: Create a JD for a retail IRB model development requirement. ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_2.txt
# LM Studio error for prompt: Create a JD for a retail IRB model development requirement. ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_3.txt
# LM Studio error for prompt: Create a JD for a retail IRB model development requirement. ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_4.txt
# LM Studio error for prompt: Create a JD for a retail IRB model development requirement. ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_5.txt
# LM Studio error for prompt: Create a JD for a retail IRB model validation requirement. M... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_6.txt
# LM Studio error for prompt: Create a JD for a retail IRB model validation requirement. M... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_7.txt
# LM Studio error for prompt: Create a JD for a retail IRB model validation requirement. M... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_8.txt
# LM Studio error for prompt: Create a JD for a retail IRB model validation requirement. M... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_9.txt
# LM Studio error for prompt: Create a JD for a retail IRB model audit requirement. Mentio... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_10.txt
# LM Studio error for prompt: Create a JD for a retail IRB model audit requirement. Mentio... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_11.txt
# LM Studio error for prompt: Create a JD for a retail IRB model audit requirement. Mentio... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_12.txt
# LM Studio error for prompt: Create a JD for a retail IRB model audit requirement. Mentio... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_13.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model development requirement... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_14.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model development requirement... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_15.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model development requirement... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_16.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model development requirement... -> 400 Client Error: Bad Request for url: http://localhost:1234/v1/chat/completions
# Generating JD_17.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model validation requirement.... -> 404 Client Error: Not Found for url: http://localhost:1234/v1/chat/completions
# Generating JD_18.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model validation requirement.... -> 404 Client Error: Not Found for url: http://localhost:1234/v1/chat/completions
# Generating JD_19.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model validation requirement.... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_20.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model validation requirement.... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_21.txt
# LM Studio error for prompt: Create a JD for a retail IFRS9 model audit requirement. Ment... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=60)
# Generating JD_22.txt

# %%
import os
import json
import time
import re
import fitz  # PyMuPDF
import docx
import zipfile
import pandas as pd
import requests
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# --------------------- CONFIGURATION ---------------------

base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
jd_excel_path = os.path.join(base_path, "JD_Sentence_Variants.xlsx")
jd_output_dir = os.path.join(base_path, "JDs")
manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")
manual_resume_dir = os.path.join(base_path, "manualcustomisedresumes")
raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
raw_resume_dir = os.path.join(base_path, "rawresumes")
ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
customised_output_dir = os.path.join(base_path, "customised_resumes")
logs_dir = os.path.join(base_path, "logs")

for folder in [jd_output_dir, manual_resume_dir, raw_resume_dir, customised_output_dir, logs_dir]:
    os.makedirs(folder, exist_ok=True)

# --------------------- FILE UTILS ---------------------

def extract_zip(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

def read_pdf_text(pdf_path):
    doc = fitz.open(pdf_path)
    return "\n".join([page.get_text() for page in doc])

def read_docx_text(docx_path):
    doc = docx.Document(docx_path)
    return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

def read_resume(path):
    if path.endswith(".pdf"):
        return read_pdf_text(path)
    elif path.endswith(".docx"):
        return read_docx_text(path)
    else:
        return ""

# --------------------- TEXT UTILS ---------------------

def clean_text(text):
    return re.sub(r'\s+', ' ', text.strip().lower())

def get_similarity(text1, text2):
    vectorizer = TfidfVectorizer().fit_transform([text1, text2])
    vectors = vectorizer.toarray()
    return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# --------------------- JD GENERATION ---------------------

def generate_jds_from_prompts():
    df = pd.read_excel(jd_excel_path)
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    model = "mistral-7b-instruct-v0.3-q4_k_m-gguf"

    for idx, row in df.iterrows():
        prompt = str(row.iloc[0]).strip()
        print(f"Generating JD_{idx + 1}.txt")
        try:
            payload = {
                "model": model,
                "messages": [{"role": "user", "content": prompt}],
                "temperature": 0.7,
                "stream": False
            }
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            jd_text = response.json()['choices'][0]['message']['content']
            with open(os.path.join(jd_output_dir, f"JD_{idx+1}.txt"), "w", encoding="utf-8") as f:
                f.write(jd_text)
        except Exception as e:
            print(f"LM Studio error for prompt: {prompt[:80]}... ->", e)
        time.sleep(2)

# --------------------- CUSTOMISATION ---------------------

def customize_resume(raw_text, jd_text, ey_template):
    raw_sentences = raw_text.split(". ")
    matched = []
    for sentence in raw_sentences:
        score = get_similarity(sentence, jd_text)
        if score > 0.15:
            matched.append(sentence.strip())
    final_experience = "\n".join(matched).strip()
    return ey_template.replace("[EXPERIENCE_PLACEHOLDER]", final_experience)

# --------------------- PIPELINE ---------------------

def full_pipeline():
    print("STEP 1: Generating JDs...")
    generate_jds_from_prompts()

    print("STEP 2: Extracting resumes...")
    extract_zip(manual_resume_zip, manual_resume_dir)
    extract_zip(raw_resume_zip, raw_resume_dir)

    ey_template = open(ey_format_path, "r", encoding="utf-8").read()

    raw_resumes = {
        os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
        for root, _, files in os.walk(raw_resume_dir)
        for f in files
    }

    manual_resumes = {
        os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
        for root, _, files in os.walk(manual_resume_dir)
        for f in files
    }

    for jd_file in sorted(os.listdir(jd_output_dir)):
        jd_index = os.path.splitext(jd_file)[0].split("_")[1]
        jd_path = os.path.join(jd_output_dir, jd_file)
        jd_text = open(jd_path, "r", encoding="utf-8").read()

        for raw_name, raw_text in raw_resumes.items():
            customised = customize_resume(raw_text, jd_text, ey_template)
            output_path = os.path.join(customised_output_dir, f"{raw_name}_JD{jd_index}.txt")
            with open(output_path, "w", encoding="utf-8") as f:
                f.write(customised)

            # Validation
            match_key = next((k for k in manual_resumes if raw_name.lower() in k.lower()), None)
            if match_key:
                manual_text = manual_resumes[match_key]
                score = get_similarity(customised, manual_text)
                log = f"{raw_name}_JD{jd_index}: Score={score:.2f}"
                print(log)
                with open(os.path.join(logs_dir, f"log_JD{jd_index}.txt"), "a", encoding="utf-8") as logf:
                    logf.write(log + "\n")

# --------------------- RUN ---------------------

if __name__ == "__main__":
    full_pipeline()
# Out:
# STEP 1: Generating JDs...
# Generating JD_1.txt
# Generating JD_2.txt
# Generating JD_3.txt
# Generating JD_4.txt
# Generating JD_5.txt
# Generating JD_6.txt
# Generating JD_7.txt
# Generating JD_8.txt
# LM Studio error for prompt: Create a JD for a retail IRB model validation requirement. Mention that SQL is a... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_9.txt
# Generating JD_10.txt
# Generating JD_11.txt
# Generating JD_12.txt
# Generating JD_13.txt
# Generating JD_14.txt
# Generating JD_15.txt
# Generating JD_16.txt
# Generating JD_17.txt
# Generating JD_18.txt
# Generating JD_19.txt
# Generating JD_20.txt
# Generating JD_21.txt
# Generating JD_22.txt
# Generating JD_23.txt
# Generating JD_24.txt
# Generating JD_25.txt
# Generating JD_26.txt
# Generating JD_27.txt
# Generating JD_28.txt
# Generating JD_29.txt
# Generating JD_30.txt
# Generating JD_31.txt
# Generating JD_32.txt
# Generating JD_33.txt
# Generating JD_34.txt
# Generating JD_35.txt
# Generating JD_36.txt
# Generating JD_37.txt
# Generating JD_38.txt
# Generating JD_39.txt
# Generating JD_40.txt
# Generating JD_41.txt
# Generating JD_42.txt
# Generating JD_43.txt
# Generating JD_44.txt
# Generating JD_45.txt
# Generating JD_46.txt
# Generating JD_47.txt
# Generating JD_48.txt
# Generating JD_49.txt
# LM Studio error for prompt: Create a JD for a retail CCAR model development requirement. Mention that R is a... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_50.txt
# Generating JD_51.txt
# LM Studio error for prompt: Create a JD for a retail CCAR model development requirement. Mention that SAS is... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_52.txt
# Generating JD_53.txt
# Generating JD_54.txt
# Generating JD_55.txt
# Generating JD_56.txt
# Generating JD_57.txt
# Generating JD_58.txt
# Generating JD_59.txt
# Generating JD_60.txt
# Generating JD_61.txt
# Generating JD_62.txt
# Generating JD_63.txt
# LM Studio error for prompt: Create a JD for a retail AI/ML model development requirement. Mention that SAS i... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_64.txt
# Generating JD_65.txt
# Generating JD_66.txt
# LM Studio error for prompt: Create a JD for a retail AI/ML model validation requirement. Mention that Python... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_67.txt
# Generating JD_68.txt
# Generating JD_69.txt
# Generating JD_70.txt
# Generating JD_71.txt
# Generating JD_72.txt
# Generating JD_73.txt
# Generating JD_74.txt
# Generating JD_75.txt
# Generating JD_76.txt
# Generating JD_77.txt
# Generating JD_78.txt
# Generating JD_79.txt
# Generating JD_80.txt
# Generating JD_81.txt
# Generating JD_82.txt
# Generating JD_83.txt
# Generating JD_84.txt
# Generating JD_85.txt
# Generating JD_86.txt
# Generating JD_87.txt
# Generating JD_88.txt
# Generating JD_89.txt
# Generating JD_90.txt
# Generating JD_91.txt
# Generating JD_92.txt
# Generating JD_93.txt
# Generating JD_94.txt
# Generating JD_95.txt
# Generating JD_96.txt
# Generating JD_97.txt
# Generating JD_98.txt
# Generating JD_99.txt
# Generating JD_100.txt
# Generating JD_101.txt
# Generating JD_102.txt
# Generating JD_103.txt
# Generating JD_104.txt
# Generating JD_105.txt
# Generating JD_106.txt
# Generating JD_107.txt
# Generating JD_108.txt
# Generating JD_109.txt
# Generating JD_110.txt
# Generating JD_111.txt
# Generating JD_112.txt
# Generating JD_113.txt
# Generating JD_114.txt
# Generating JD_115.txt
# Generating JD_116.txt
# Generating JD_117.txt
# Generating JD_118.txt
# Generating JD_119.txt
# Generating JD_120.txt
# Generating JD_121.txt
# Generating JD_122.txt
# LM Studio error for prompt: Create a JD for a wholesale CCAR model development requirement. Mention that Pyt... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_123.txt
# Generating JD_124.txt
# Generating JD_125.txt
# Generating JD_126.txt
# Generating JD_127.txt
# Generating JD_128.txt
# LM Studio error for prompt: Create a JD for a wholesale CCAR model validation requirement. Mention that SQL ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_129.txt
# Generating JD_130.txt
# Generating JD_131.txt
# Generating JD_132.txt
# Generating JD_133.txt
# LM Studio error for prompt: Create a JD for a wholesale AI/ML model development requirement. Mention that R ... -> HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# Generating JD_134.txt
# Generating JD_135.txt
# Generating JD_136.txt
# Generating JD_137.txt
# Generating JD_138.txt
# Generating JD_139.txt
# Generating JD_140.txt
# Generating JD_141.txt
# Generating JD_142.txt
# Generating JD_143.txt
# Generating JD_144.txt
# STEP 2: Extracting resumes...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 147
#     144 # --------------------- RUN ---------------------
#     146 if __name__ == "__main__":
# --> 147     full_pipeline()
#
# Cell In[1], line 112, in full_pipeline()
#     107 extract_zip(raw_resume_zip, raw_resume_dir)
#     109 ey_template = open(ey_format_path, "r", encoding="utf-8").read()
#     111 raw_resumes = {
# --> 112     os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#     113     for root, _, files in os.walk(raw_resume_dir)
#     114     for f in files
#     115 }
#     117 manual_resumes = {
#     118     os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#     119     for root, _, files in os.walk(manual_resume_dir)
#     120     for f in files
#     121 }
#     123 for jd_file in sorted(os.listdir(jd_output_dir)):
#
# Cell In[1], line 45, in read_resume(path)
#      43 def read_resume(path):
#      44     if path.endswith(".pdf"):
# ---> 45         return read_pdf_text(path)
#      46     elif path.endswith(".docx"):
#      47         return read_docx_text(path)
#
# Cell In[1], line 36, in read_pdf_text(pdf_path)
#      35 def read_pdf_text(pdf_path):
# ---> 36     doc = fitz.open(pdf_path)
#      37     return "\n".join([page.get_text() for page in doc])
#
# AttributeError: module 'fitz' has no attribute 'open'

# %%
# import os
# import zipfile
# import fitz  # PyMuPDF
# import docx
# import re
# import pandas as pd
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # --------------------- CONFIGURATION ---------------------

# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
# jd_output_dir = os.path.join(base_path, "JDs")
# manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")
# manual_resume_dir = os.path.join(base_path, "manualcustomisedresumes")
# raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
# raw_resume_dir = os.path.join(base_path, "rawresumes")
# ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
# customised_output_dir = os.path.join(base_path, "customised_resumes")
# logs_dir = os.path.join(base_path, "logs")

# for folder in [manual_resume_dir, raw_resume_dir, customised_output_dir, logs_dir]:
#     os.makedirs(folder, exist_ok=True)

# # --------------------- UTILS ---------------------

# def extract_zip(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx_text(docx_path):
#     doc = docx.Document(docx_path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf_text(path)
#     elif path.endswith(".docx"):
#         return read_docx_text(path)
#     else:
#         return ""

# def get_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def customize_resume(raw_text, jd_text, ey_template):
#     raw_sentences = raw_text.split(". ")
#     matched = []
#     for sentence in raw_sentences:
#         score = get_similarity(sentence, jd_text)
#         if score > 0.15:
#             matched.append(sentence.strip())
#     final_experience = "\n".join(matched).strip()
#     return ey_template.replace("[EXPERIENCE_PLACEHOLDER]", final_experience)

# # --------------------- MAIN CUSTOMIZATION PIPELINE ---------------------

# def customise_resumes_from_existing_JDs():
#     print("STEP 2: Extracting Resumes...")
#     extract_zip(raw_resume_zip, raw_resume_dir)
#     extract_zip(manual_resume_zip, manual_resume_dir)

#     ey_template = open(ey_format_path, "r", encoding="utf-8").read()

#     raw_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(raw_resume_dir)
#         for f in files
#     }

#     manual_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(manual_resume_dir)
#         for f in files
#     }

#     print("STEP 3: Customising Resumes with JDs...")
#     for jd_file in sorted(os.listdir(jd_output_dir)):
#         jd_index = os.path.splitext(jd_file)[0].split("_")[1]
#         jd_path = os.path.join(jd_output_dir, jd_file)
#         jd_text = open(jd_path, "r", encoding="utf-8").read()

#         for raw_name, raw_text in raw_resumes.items():
#             customised = customize_resume(raw_text, jd_text, ey_template)
#             output_path = os.path.join(customised_output_dir, f"{raw_name}_JD{jd_index}.txt")
#             with open(output_path, "w", encoding="utf-8") as f:
#                 f.write(customised)

#             # Validation: compare with manual resume
#             match_key = next((k for k in manual_resumes if raw_name.lower() in k.lower()), None)
#             if match_key:
#                 manual_text = manual_resumes[match_key]
#                 score = get_similarity(customised, manual_text)
#                 log = f"{raw_name}_JD{jd_index}: Score={score:.2f}"
#                 print(log)
#                 with open(os.path.join(logs_dir, f"log_JD{jd_index}.txt"), "a", encoding="utf-8") as logf:
#                     logf.write(log + "\n")

# # --------------------- RUN ---------------------

# if __name__ == "__main__":
#     customise_resumes_from_existing_JDs()
# Out:
# STEP 2: Extracting Resumes...
# STEP 3: Customising Resumes with JDs...
# Anuska Das_JD1: Score=0.00
# CV_Aarsh_JD1: Score=0.63
# CV_Arnab Roy_Model_Validation_JD1: Score=0.55
# G N Sindhur_resume_2025_JD1: Score=0.65
# Isha Porwal Resume_JD1: Score=0.62
# KartikMohan_JD1: Score=0.73
# Kshitij_Sahdev_CV (002)_JD1: Score=0.53
# Kundan_Kumar_JD1: Score=0.70
# Munna Choudhary_JD1: Score=0.00
# Narendra_Sahu_CreditRisk_JD1: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD1: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD1: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD1: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD1: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD1: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD1: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD1: Score=0.61
# Naukri_YashRai[4y_0m]_JD1: Score=0.63
# Nidhika-Tomar_JD1: Score=0.53
# Praveen R- Resume_JD1: Score=0.72
# Priyajit Bishayee resume 2025_JD1: Score=0.72
# Rajvi Doshi_JD1: Score=0.65
# Resume - Reema Panday_JD1: Score=0.52
# Resume.SautrikGanguly_JD1: Score=0.51
# Resume_Rahul_kushwaha_JD1: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD1: Score=0.00
# Shashwata_Mondal_JD1: Score=0.51
# Stuti Mehrotra_CV 1_JD1: Score=0.71
# Sulagna Paul Resume (1)_JD1: Score=0.67
# Vedanti Khokher_JD1: Score=0.00
# Anuska Das_JD10: Score=0.00
# CV_Aarsh_JD10: Score=0.63
# CV_Arnab Roy_Model_Validation_JD10: Score=0.55
# G N Sindhur_resume_2025_JD10: Score=0.65
# Isha Porwal Resume_JD10: Score=0.62
# KartikMohan_JD10: Score=0.73
# Kshitij_Sahdev_CV (002)_JD10: Score=0.53
# Kundan_Kumar_JD10: Score=0.70
# Munna Choudhary_JD10: Score=0.00
# Narendra_Sahu_CreditRisk_JD10: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD10: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD10: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD10: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD10: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD10: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD10: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD10: Score=0.61
# Naukri_YashRai[4y_0m]_JD10: Score=0.63
# Nidhika-Tomar_JD10: Score=0.53
# Praveen R- Resume_JD10: Score=0.72
# Priyajit Bishayee resume 2025_JD10: Score=0.72
# Rajvi Doshi_JD10: Score=0.65
# Resume - Reema Panday_JD10: Score=0.52
# Resume.SautrikGanguly_JD10: Score=0.51
# Resume_Rahul_kushwaha_JD10: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD10: Score=0.00
# Shashwata_Mondal_JD10: Score=0.51
# Stuti Mehrotra_CV 1_JD10: Score=0.71
# Sulagna Paul Resume (1)_JD10: Score=0.67
# Vedanti Khokher_JD10: Score=0.00
# Anuska Das_JD100: Score=0.00
# CV_Aarsh_JD100: Score=0.63
# CV_Arnab Roy_Model_Validation_JD100: Score=0.55
# G N Sindhur_resume_2025_JD100: Score=0.65
# Isha Porwal Resume_JD100: Score=0.62
# KartikMohan_JD100: Score=0.73
# Kshitij_Sahdev_CV (002)_JD100: Score=0.53
# Kundan_Kumar_JD100: Score=0.70
# Munna Choudhary_JD100: Score=0.00
# Narendra_Sahu_CreditRisk_JD100: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD100: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD100: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD100: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD100: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD100: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD100: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD100: Score=0.61
# Naukri_YashRai[4y_0m]_JD100: Score=0.63
# Nidhika-Tomar_JD100: Score=0.53
# Praveen R- Resume_JD100: Score=0.72
# Priyajit Bishayee resume 2025_JD100: Score=0.72
# Rajvi Doshi_JD100: Score=0.65
# Resume - Reema Panday_JD100: Score=0.52
# Resume.SautrikGanguly_JD100: Score=0.51
# Resume_Rahul_kushwaha_JD100: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD100: Score=0.00
# Shashwata_Mondal_JD100: Score=0.51
# Stuti Mehrotra_CV 1_JD100: Score=0.71
# Sulagna Paul Resume (1)_JD100: Score=0.67
# Vedanti Khokher_JD100: Score=0.00
# Anuska Das_JD101: Score=0.00
# CV_Aarsh_JD101: Score=0.63
# CV_Arnab Roy_Model_Validation_JD101: Score=0.55
# G N Sindhur_resume_2025_JD101: Score=0.65
# Isha Porwal Resume_JD101: Score=0.62
# KartikMohan_JD101: Score=0.73
# Kshitij_Sahdev_CV (002)_JD101: Score=0.53
# Kundan_Kumar_JD101: Score=0.70
# Munna Choudhary_JD101: Score=0.00
# Narendra_Sahu_CreditRisk_JD101: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD101: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD101: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD101: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD101: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD101: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD101: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD101: Score=0.61
# Naukri_YashRai[4y_0m]_JD101: Score=0.63
# Nidhika-Tomar_JD101: Score=0.53
# Praveen R- Resume_JD101: Score=0.72
# Priyajit Bishayee resume 2025_JD101: Score=0.72
# Rajvi Doshi_JD101: Score=0.65
# Resume - Reema Panday_JD101: Score=0.52
# Resume.SautrikGanguly_JD101: Score=0.51
# Resume_Rahul_kushwaha_JD101: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD101: Score=0.00
# Shashwata_Mondal_JD101: Score=0.51
# Stuti Mehrotra_CV 1_JD101: Score=0.71
# Sulagna Paul Resume (1)_JD101: Score=0.67
# Vedanti Khokher_JD101: Score=0.00
# Anuska Das_JD102: Score=0.00
# CV_Aarsh_JD102: Score=0.63
# CV_Arnab Roy_Model_Validation_JD102: Score=0.55
# G N Sindhur_resume_2025_JD102: Score=0.65
# Isha Porwal Resume_JD102: Score=0.62
# KartikMohan_JD102: Score=0.73
# Kshitij_Sahdev_CV (002)_JD102: Score=0.53
# Kundan_Kumar_JD102: Score=0.70
# Munna Choudhary_JD102: Score=0.00
# Narendra_Sahu_CreditRisk_JD102: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD102: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD102: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD102: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD102: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD102: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD102: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD102: Score=0.61
# Naukri_YashRai[4y_0m]_JD102: Score=0.63
# Nidhika-Tomar_JD102: Score=0.53
# Praveen R- Resume_JD102: Score=0.72
# Priyajit Bishayee resume 2025_JD102: Score=0.72
# Rajvi Doshi_JD102: Score=0.65
# Resume - Reema Panday_JD102: Score=0.52
# Resume.SautrikGanguly_JD102: Score=0.51
# Resume_Rahul_kushwaha_JD102: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD102: Score=0.00
# Shashwata_Mondal_JD102: Score=0.51
# Stuti Mehrotra_CV 1_JD102: Score=0.71
# Sulagna Paul Resume (1)_JD102: Score=0.67
# Vedanti Khokher_JD102: Score=0.00
# Anuska Das_JD103: Score=0.00
# CV_Aarsh_JD103: Score=0.63
# CV_Arnab Roy_Model_Validation_JD103: Score=0.55
# G N Sindhur_resume_2025_JD103: Score=0.65
# Isha Porwal Resume_JD103: Score=0.62
# KartikMohan_JD103: Score=0.73
# Kshitij_Sahdev_CV (002)_JD103: Score=0.53
# Kundan_Kumar_JD103: Score=0.70
# Munna Choudhary_JD103: Score=0.00
# Narendra_Sahu_CreditRisk_JD103: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD103: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD103: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD103: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD103: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD103: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD103: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD103: Score=0.61
# Naukri_YashRai[4y_0m]_JD103: Score=0.63
# Nidhika-Tomar_JD103: Score=0.53
# Praveen R- Resume_JD103: Score=0.72
# Priyajit Bishayee resume 2025_JD103: Score=0.72
# Rajvi Doshi_JD103: Score=0.65
# Resume - Reema Panday_JD103: Score=0.52
# Resume.SautrikGanguly_JD103: Score=0.51
# Resume_Rahul_kushwaha_JD103: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD103: Score=0.00
# Shashwata_Mondal_JD103: Score=0.51
# Stuti Mehrotra_CV 1_JD103: Score=0.71
# Sulagna Paul Resume (1)_JD103: Score=0.67
# Vedanti Khokher_JD103: Score=0.00
# Anuska Das_JD104: Score=0.00
# CV_Aarsh_JD104: Score=0.63
# CV_Arnab Roy_Model_Validation_JD104: Score=0.55
# G N Sindhur_resume_2025_JD104: Score=0.65
# Isha Porwal Resume_JD104: Score=0.62
# KartikMohan_JD104: Score=0.73
# Kshitij_Sahdev_CV (002)_JD104: Score=0.53
# Kundan_Kumar_JD104: Score=0.70
# Munna Choudhary_JD104: Score=0.00
# Narendra_Sahu_CreditRisk_JD104: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD104: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD104: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD104: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD104: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD104: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD104: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD104: Score=0.61
# Naukri_YashRai[4y_0m]_JD104: Score=0.63
# Nidhika-Tomar_JD104: Score=0.53
# Praveen R- Resume_JD104: Score=0.72
# Priyajit Bishayee resume 2025_JD104: Score=0.72
# Rajvi Doshi_JD104: Score=0.65
# Resume - Reema Panday_JD104: Score=0.52
# Resume.SautrikGanguly_JD104: Score=0.51
# Resume_Rahul_kushwaha_JD104: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD104: Score=0.00
# Shashwata_Mondal_JD104: Score=0.51
# Stuti Mehrotra_CV 1_JD104: Score=0.71
# Sulagna Paul Resume (1)_JD104: Score=0.67
# Vedanti Khokher_JD104: Score=0.00
# Anuska Das_JD105: Score=0.00
# CV_Aarsh_JD105: Score=0.63
# CV_Arnab Roy_Model_Validation_JD105: Score=0.55
# G N Sindhur_resume_2025_JD105: Score=0.65
# Isha Porwal Resume_JD105: Score=0.62
# KartikMohan_JD105: Score=0.73
# Kshitij_Sahdev_CV (002)_JD105: Score=0.53
# Kundan_Kumar_JD105: Score=0.70
# Munna Choudhary_JD105: Score=0.00
# Narendra_Sahu_CreditRisk_JD105: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD105: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD105: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD105: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD105: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD105: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD105: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD105: Score=0.61
# Naukri_YashRai[4y_0m]_JD105: Score=0.63
# Nidhika-Tomar_JD105: Score=0.53
# Praveen R- Resume_JD105: Score=0.72
# Priyajit Bishayee resume 2025_JD105: Score=0.72
# Rajvi Doshi_JD105: Score=0.65
# Resume - Reema Panday_JD105: Score=0.52
# Resume.SautrikGanguly_JD105: Score=0.51
# Resume_Rahul_kushwaha_JD105: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD105: Score=0.00
# Shashwata_Mondal_JD105: Score=0.51
# Stuti Mehrotra_CV 1_JD105: Score=0.71
# Sulagna Paul Resume (1)_JD105: Score=0.67
# Vedanti Khokher_JD105: Score=0.00
# Anuska Das_JD106: Score=0.00
# CV_Aarsh_JD106: Score=0.63
# CV_Arnab Roy_Model_Validation_JD106: Score=0.55
# G N Sindhur_resume_2025_JD106: Score=0.65
# Isha Porwal Resume_JD106: Score=0.62
# KartikMohan_JD106: Score=0.73
# Kshitij_Sahdev_CV (002)_JD106: Score=0.53
# Kundan_Kumar_JD106: Score=0.70
# Munna Choudhary_JD106: Score=0.00
# Narendra_Sahu_CreditRisk_JD106: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD106: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD106: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD106: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD106: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD106: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD106: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD106: Score=0.61
# Naukri_YashRai[4y_0m]_JD106: Score=0.63
# Nidhika-Tomar_JD106: Score=0.53
# Praveen R- Resume_JD106: Score=0.72
# Priyajit Bishayee resume 2025_JD106: Score=0.72
# Rajvi Doshi_JD106: Score=0.65
# Resume - Reema Panday_JD106: Score=0.52
# Resume.SautrikGanguly_JD106: Score=0.51
# Resume_Rahul_kushwaha_JD106: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD106: Score=0.00
# Shashwata_Mondal_JD106: Score=0.51
# Stuti Mehrotra_CV 1_JD106: Score=0.71
# Sulagna Paul Resume (1)_JD106: Score=0.67
# Vedanti Khokher_JD106: Score=0.00
# Anuska Das_JD107: Score=0.00
# CV_Aarsh_JD107: Score=0.63
# CV_Arnab Roy_Model_Validation_JD107: Score=0.55
# G N Sindhur_resume_2025_JD107: Score=0.65
# Isha Porwal Resume_JD107: Score=0.62
# KartikMohan_JD107: Score=0.73
# Kshitij_Sahdev_CV (002)_JD107: Score=0.53
# Kundan_Kumar_JD107: Score=0.70
# Munna Choudhary_JD107: Score=0.00
# Narendra_Sahu_CreditRisk_JD107: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD107: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD107: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD107: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD107: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD107: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD107: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD107: Score=0.61
# Naukri_YashRai[4y_0m]_JD107: Score=0.63
# Nidhika-Tomar_JD107: Score=0.53
# Praveen R- Resume_JD107: Score=0.72
# Priyajit Bishayee resume 2025_JD107: Score=0.72
# Rajvi Doshi_JD107: Score=0.65
# Resume - Reema Panday_JD107: Score=0.52
# Resume.SautrikGanguly_JD107: Score=0.51
# Resume_Rahul_kushwaha_JD107: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD107: Score=0.00
# Shashwata_Mondal_JD107: Score=0.51
# Stuti Mehrotra_CV 1_JD107: Score=0.71
# Sulagna Paul Resume (1)_JD107: Score=0.67
# Vedanti Khokher_JD107: Score=0.00
# Anuska Das_JD108: Score=0.00
# CV_Aarsh_JD108: Score=0.63
# CV_Arnab Roy_Model_Validation_JD108: Score=0.55
# G N Sindhur_resume_2025_JD108: Score=0.65
# Isha Porwal Resume_JD108: Score=0.62
# KartikMohan_JD108: Score=0.73
# Kshitij_Sahdev_CV (002)_JD108: Score=0.53
# Kundan_Kumar_JD108: Score=0.70
# Munna Choudhary_JD108: Score=0.00
# Narendra_Sahu_CreditRisk_JD108: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD108: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD108: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD108: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD108: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD108: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD108: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD108: Score=0.61
# Naukri_YashRai[4y_0m]_JD108: Score=0.63
# Nidhika-Tomar_JD108: Score=0.53
# Praveen R- Resume_JD108: Score=0.72
# Priyajit Bishayee resume 2025_JD108: Score=0.72
# Rajvi Doshi_JD108: Score=0.65
# Resume - Reema Panday_JD108: Score=0.52
# Resume.SautrikGanguly_JD108: Score=0.51
# Resume_Rahul_kushwaha_JD108: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD108: Score=0.00
# Shashwata_Mondal_JD108: Score=0.51
# Stuti Mehrotra_CV 1_JD108: Score=0.71
# Sulagna Paul Resume (1)_JD108: Score=0.67
# Vedanti Khokher_JD108: Score=0.00
# Anuska Das_JD109: Score=0.00
# CV_Aarsh_JD109: Score=0.63
# CV_Arnab Roy_Model_Validation_JD109: Score=0.55
# G N Sindhur_resume_2025_JD109: Score=0.65
# Isha Porwal Resume_JD109: Score=0.62
# KartikMohan_JD109: Score=0.73
# Kshitij_Sahdev_CV (002)_JD109: Score=0.53
# Kundan_Kumar_JD109: Score=0.70
# Munna Choudhary_JD109: Score=0.00
# Narendra_Sahu_CreditRisk_JD109: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD109: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD109: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD109: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD109: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD109: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD109: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD109: Score=0.61
# Naukri_YashRai[4y_0m]_JD109: Score=0.63
# Nidhika-Tomar_JD109: Score=0.53
# Praveen R- Resume_JD109: Score=0.72
# Priyajit Bishayee resume 2025_JD109: Score=0.72
# Rajvi Doshi_JD109: Score=0.65
# Resume - Reema Panday_JD109: Score=0.52
# Resume.SautrikGanguly_JD109: Score=0.51
# Resume_Rahul_kushwaha_JD109: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD109: Score=0.00
# Shashwata_Mondal_JD109: Score=0.51
# Stuti Mehrotra_CV 1_JD109: Score=0.71
# Sulagna Paul Resume (1)_JD109: Score=0.67
# Vedanti Khokher_JD109: Score=0.00
# Anuska Das_JD11: Score=0.00
# CV_Aarsh_JD11: Score=0.63
# CV_Arnab Roy_Model_Validation_JD11: Score=0.55
# G N Sindhur_resume_2025_JD11: Score=0.65
# Isha Porwal Resume_JD11: Score=0.62
# KartikMohan_JD11: Score=0.73
# Kshitij_Sahdev_CV (002)_JD11: Score=0.53
# Kundan_Kumar_JD11: Score=0.70
# Munna Choudhary_JD11: Score=0.00
# Narendra_Sahu_CreditRisk_JD11: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD11: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD11: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD11: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD11: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD11: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD11: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD11: Score=0.61
# Naukri_YashRai[4y_0m]_JD11: Score=0.63
# Nidhika-Tomar_JD11: Score=0.53
# Praveen R- Resume_JD11: Score=0.72
# Priyajit Bishayee resume 2025_JD11: Score=0.72
# Rajvi Doshi_JD11: Score=0.65
# Resume - Reema Panday_JD11: Score=0.52
# Resume.SautrikGanguly_JD11: Score=0.51
# Resume_Rahul_kushwaha_JD11: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD11: Score=0.00
# Shashwata_Mondal_JD11: Score=0.51
# Stuti Mehrotra_CV 1_JD11: Score=0.71
# Sulagna Paul Resume (1)_JD11: Score=0.67
# Vedanti Khokher_JD11: Score=0.00
# Anuska Das_JD110: Score=0.00
# CV_Aarsh_JD110: Score=0.63
# CV_Arnab Roy_Model_Validation_JD110: Score=0.55
# G N Sindhur_resume_2025_JD110: Score=0.65
# Isha Porwal Resume_JD110: Score=0.62
# KartikMohan_JD110: Score=0.73
# Kshitij_Sahdev_CV (002)_JD110: Score=0.53
# Kundan_Kumar_JD110: Score=0.70
# Munna Choudhary_JD110: Score=0.00
# Narendra_Sahu_CreditRisk_JD110: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD110: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD110: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD110: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD110: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD110: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD110: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD110: Score=0.61
# Naukri_YashRai[4y_0m]_JD110: Score=0.63
# Nidhika-Tomar_JD110: Score=0.53
# Praveen R- Resume_JD110: Score=0.72
# Priyajit Bishayee resume 2025_JD110: Score=0.72
# Rajvi Doshi_JD110: Score=0.65
# Resume - Reema Panday_JD110: Score=0.52
# Resume.SautrikGanguly_JD110: Score=0.51
# Resume_Rahul_kushwaha_JD110: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD110: Score=0.00
# Shashwata_Mondal_JD110: Score=0.51
# Stuti Mehrotra_CV 1_JD110: Score=0.71
# Sulagna Paul Resume (1)_JD110: Score=0.67
# Vedanti Khokher_JD110: Score=0.00
# Anuska Das_JD111: Score=0.00
# CV_Aarsh_JD111: Score=0.63
# CV_Arnab Roy_Model_Validation_JD111: Score=0.55
# G N Sindhur_resume_2025_JD111: Score=0.65
# Isha Porwal Resume_JD111: Score=0.62
# KartikMohan_JD111: Score=0.73
# Kshitij_Sahdev_CV (002)_JD111: Score=0.53
# Kundan_Kumar_JD111: Score=0.70
# Munna Choudhary_JD111: Score=0.00
# Narendra_Sahu_CreditRisk_JD111: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD111: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD111: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD111: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD111: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD111: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD111: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD111: Score=0.61
# Naukri_YashRai[4y_0m]_JD111: Score=0.63
# Nidhika-Tomar_JD111: Score=0.53
# Praveen R- Resume_JD111: Score=0.72
# Priyajit Bishayee resume 2025_JD111: Score=0.72
# Rajvi Doshi_JD111: Score=0.65
# Resume - Reema Panday_JD111: Score=0.52
# Resume.SautrikGanguly_JD111: Score=0.51
# Resume_Rahul_kushwaha_JD111: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD111: Score=0.00
# Shashwata_Mondal_JD111: Score=0.51
# Stuti Mehrotra_CV 1_JD111: Score=0.71
# Sulagna Paul Resume (1)_JD111: Score=0.67
# Vedanti Khokher_JD111: Score=0.00
# Anuska Das_JD112: Score=0.00
# CV_Aarsh_JD112: Score=0.63
# CV_Arnab Roy_Model_Validation_JD112: Score=0.55
# G N Sindhur_resume_2025_JD112: Score=0.65
# Isha Porwal Resume_JD112: Score=0.62
# KartikMohan_JD112: Score=0.73
# Kshitij_Sahdev_CV (002)_JD112: Score=0.53
# Kundan_Kumar_JD112: Score=0.70
# Munna Choudhary_JD112: Score=0.00
# Narendra_Sahu_CreditRisk_JD112: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD112: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD112: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD112: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD112: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD112: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD112: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD112: Score=0.61
# Naukri_YashRai[4y_0m]_JD112: Score=0.63
# Nidhika-Tomar_JD112: Score=0.53
# Praveen R- Resume_JD112: Score=0.72
# Priyajit Bishayee resume 2025_JD112: Score=0.72
# Rajvi Doshi_JD112: Score=0.65
# Resume - Reema Panday_JD112: Score=0.52
# Resume.SautrikGanguly_JD112: Score=0.51
# Resume_Rahul_kushwaha_JD112: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD112: Score=0.00
# Shashwata_Mondal_JD112: Score=0.51
# Stuti Mehrotra_CV 1_JD112: Score=0.71
# Sulagna Paul Resume (1)_JD112: Score=0.67
# Vedanti Khokher_JD112: Score=0.00
# Anuska Das_JD113: Score=0.00
# CV_Aarsh_JD113: Score=0.63
# CV_Arnab Roy_Model_Validation_JD113: Score=0.55
# G N Sindhur_resume_2025_JD113: Score=0.65
# Isha Porwal Resume_JD113: Score=0.62
# KartikMohan_JD113: Score=0.73
# Kshitij_Sahdev_CV (002)_JD113: Score=0.53
# Kundan_Kumar_JD113: Score=0.70
# Munna Choudhary_JD113: Score=0.00
# Narendra_Sahu_CreditRisk_JD113: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD113: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD113: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD113: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD113: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD113: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD113: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD113: Score=0.61
# Naukri_YashRai[4y_0m]_JD113: Score=0.63
# Nidhika-Tomar_JD113: Score=0.53
# Praveen R- Resume_JD113: Score=0.72
# Priyajit Bishayee resume 2025_JD113: Score=0.72
# Rajvi Doshi_JD113: Score=0.65
# Resume - Reema Panday_JD113: Score=0.52
# Resume.SautrikGanguly_JD113: Score=0.51
# Resume_Rahul_kushwaha_JD113: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD113: Score=0.00
# Shashwata_Mondal_JD113: Score=0.51
# Stuti Mehrotra_CV 1_JD113: Score=0.71
# Sulagna Paul Resume (1)_JD113: Score=0.67
# Vedanti Khokher_JD113: Score=0.00
# Anuska Das_JD114: Score=0.00
# CV_Aarsh_JD114: Score=0.63
# CV_Arnab Roy_Model_Validation_JD114: Score=0.55
# G N Sindhur_resume_2025_JD114: Score=0.65
# Isha Porwal Resume_JD114: Score=0.62
# KartikMohan_JD114: Score=0.73
# Kshitij_Sahdev_CV (002)_JD114: Score=0.53
# Kundan_Kumar_JD114: Score=0.70
# Munna Choudhary_JD114: Score=0.00
# Narendra_Sahu_CreditRisk_JD114: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD114: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD114: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD114: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD114: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD114: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD114: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD114: Score=0.61
# Naukri_YashRai[4y_0m]_JD114: Score=0.63
# Nidhika-Tomar_JD114: Score=0.53
# Praveen R- Resume_JD114: Score=0.72
# Priyajit Bishayee resume 2025_JD114: Score=0.72
# Rajvi Doshi_JD114: Score=0.65
# Resume - Reema Panday_JD114: Score=0.52
# Resume.SautrikGanguly_JD114: Score=0.51
# Resume_Rahul_kushwaha_JD114: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD114: Score=0.00
# Shashwata_Mondal_JD114: Score=0.51
# Stuti Mehrotra_CV 1_JD114: Score=0.71
# Sulagna Paul Resume (1)_JD114: Score=0.67
# Vedanti Khokher_JD114: Score=0.00
# Anuska Das_JD115: Score=0.00
# CV_Aarsh_JD115: Score=0.63
# CV_Arnab Roy_Model_Validation_JD115: Score=0.55
# G N Sindhur_resume_2025_JD115: Score=0.65
# Isha Porwal Resume_JD115: Score=0.62
# KartikMohan_JD115: Score=0.73
# Kshitij_Sahdev_CV (002)_JD115: Score=0.53
# Kundan_Kumar_JD115: Score=0.70
# Munna Choudhary_JD115: Score=0.00
# Narendra_Sahu_CreditRisk_JD115: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD115: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD115: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD115: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD115: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD115: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD115: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD115: Score=0.61
# Naukri_YashRai[4y_0m]_JD115: Score=0.63
# Nidhika-Tomar_JD115: Score=0.53
# Praveen R- Resume_JD115: Score=0.72
# Priyajit Bishayee resume 2025_JD115: Score=0.72
# Rajvi Doshi_JD115: Score=0.65
# Resume - Reema Panday_JD115: Score=0.52
# Resume.SautrikGanguly_JD115: Score=0.51
# Resume_Rahul_kushwaha_JD115: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD115: Score=0.00
# Shashwata_Mondal_JD115: Score=0.51
# Stuti Mehrotra_CV 1_JD115: Score=0.71
# Sulagna Paul Resume (1)_JD115: Score=0.67
# Vedanti Khokher_JD115: Score=0.00
# Anuska Das_JD116: Score=0.00
# CV_Aarsh_JD116: Score=0.63
# CV_Arnab Roy_Model_Validation_JD116: Score=0.55
# G N Sindhur_resume_2025_JD116: Score=0.65
# Isha Porwal Resume_JD116: Score=0.62
# KartikMohan_JD116: Score=0.73
# Kshitij_Sahdev_CV (002)_JD116: Score=0.53
# Kundan_Kumar_JD116: Score=0.70
# Munna Choudhary_JD116: Score=0.00
# Narendra_Sahu_CreditRisk_JD116: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD116: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD116: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD116: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD116: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD116: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD116: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD116: Score=0.61
# Naukri_YashRai[4y_0m]_JD116: Score=0.63
# Nidhika-Tomar_JD116: Score=0.53
# Praveen R- Resume_JD116: Score=0.72
# Priyajit Bishayee resume 2025_JD116: Score=0.72
# Rajvi Doshi_JD116: Score=0.65
# Resume - Reema Panday_JD116: Score=0.52
# Resume.SautrikGanguly_JD116: Score=0.51
# Resume_Rahul_kushwaha_JD116: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD116: Score=0.00
# Shashwata_Mondal_JD116: Score=0.51
# Stuti Mehrotra_CV 1_JD116: Score=0.71
# Sulagna Paul Resume (1)_JD116: Score=0.67
# Vedanti Khokher_JD116: Score=0.00
# Anuska Das_JD117: Score=0.00
# CV_Aarsh_JD117: Score=0.63
# CV_Arnab Roy_Model_Validation_JD117: Score=0.55
# G N Sindhur_resume_2025_JD117: Score=0.65
# Isha Porwal Resume_JD117: Score=0.62
# KartikMohan_JD117: Score=0.73
# Kshitij_Sahdev_CV (002)_JD117: Score=0.53
# Kundan_Kumar_JD117: Score=0.70
# Munna Choudhary_JD117: Score=0.00
# Narendra_Sahu_CreditRisk_JD117: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD117: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD117: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD117: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD117: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD117: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD117: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD117: Score=0.61
# Naukri_YashRai[4y_0m]_JD117: Score=0.63
# Nidhika-Tomar_JD117: Score=0.53
# Praveen R- Resume_JD117: Score=0.72
# Priyajit Bishayee resume 2025_JD117: Score=0.72
# Rajvi Doshi_JD117: Score=0.65
# Resume - Reema Panday_JD117: Score=0.52
# Resume.SautrikGanguly_JD117: Score=0.51
# Resume_Rahul_kushwaha_JD117: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD117: Score=0.00
# Shashwata_Mondal_JD117: Score=0.51
# Stuti Mehrotra_CV 1_JD117: Score=0.71
# Sulagna Paul Resume (1)_JD117: Score=0.67
# Vedanti Khokher_JD117: Score=0.00
# Anuska Das_JD118: Score=0.00
# CV_Aarsh_JD118: Score=0.63
# CV_Arnab Roy_Model_Validation_JD118: Score=0.55
# G N Sindhur_resume_2025_JD118: Score=0.65
# Isha Porwal Resume_JD118: Score=0.62
# KartikMohan_JD118: Score=0.73
# Kshitij_Sahdev_CV (002)_JD118: Score=0.53
# Kundan_Kumar_JD118: Score=0.70
# Munna Choudhary_JD118: Score=0.00
# Narendra_Sahu_CreditRisk_JD118: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD118: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD118: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD118: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD118: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD118: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD118: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD118: Score=0.61
# Naukri_YashRai[4y_0m]_JD118: Score=0.63
# Nidhika-Tomar_JD118: Score=0.53
# Praveen R- Resume_JD118: Score=0.72
# Priyajit Bishayee resume 2025_JD118: Score=0.72
# Rajvi Doshi_JD118: Score=0.65
# Resume - Reema Panday_JD118: Score=0.52
# Resume.SautrikGanguly_JD118: Score=0.51
# Resume_Rahul_kushwaha_JD118: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD118: Score=0.00
# Shashwata_Mondal_JD118: Score=0.51
# Stuti Mehrotra_CV 1_JD118: Score=0.71
# Sulagna Paul Resume (1)_JD118: Score=0.67
# Vedanti Khokher_JD118: Score=0.00
# Anuska Das_JD119: Score=0.00
# CV_Aarsh_JD119: Score=0.63
# CV_Arnab Roy_Model_Validation_JD119: Score=0.55
# G N Sindhur_resume_2025_JD119: Score=0.65
# Isha Porwal Resume_JD119: Score=0.62
# KartikMohan_JD119: Score=0.73
# Kshitij_Sahdev_CV (002)_JD119: Score=0.53
# Kundan_Kumar_JD119: Score=0.70
# Munna Choudhary_JD119: Score=0.00
# Narendra_Sahu_CreditRisk_JD119: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD119: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD119: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD119: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD119: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD119: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD119: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD119: Score=0.61
# Naukri_YashRai[4y_0m]_JD119: Score=0.63
# Nidhika-Tomar_JD119: Score=0.53
# Praveen R- Resume_JD119: Score=0.72
# Priyajit Bishayee resume 2025_JD119: Score=0.72
# Rajvi Doshi_JD119: Score=0.65
# Resume - Reema Panday_JD119: Score=0.52
# Resume.SautrikGanguly_JD119: Score=0.51
# Resume_Rahul_kushwaha_JD119: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD119: Score=0.00
# Shashwata_Mondal_JD119: Score=0.51
# Stuti Mehrotra_CV 1_JD119: Score=0.71
# Sulagna Paul Resume (1)_JD119: Score=0.67
# Vedanti Khokher_JD119: Score=0.00
# Anuska Das_JD12: Score=0.00
# CV_Aarsh_JD12: Score=0.63
# CV_Arnab Roy_Model_Validation_JD12: Score=0.55
# G N Sindhur_resume_2025_JD12: Score=0.65
# Isha Porwal Resume_JD12: Score=0.62
# KartikMohan_JD12: Score=0.73
# Kshitij_Sahdev_CV (002)_JD12: Score=0.53
# Kundan_Kumar_JD12: Score=0.70
# Munna Choudhary_JD12: Score=0.00
# Narendra_Sahu_CreditRisk_JD12: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD12: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD12: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD12: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD12: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD12: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD12: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD12: Score=0.61
# Naukri_YashRai[4y_0m]_JD12: Score=0.63
# Nidhika-Tomar_JD12: Score=0.53
# Praveen R- Resume_JD12: Score=0.72
# Priyajit Bishayee resume 2025_JD12: Score=0.72
# Rajvi Doshi_JD12: Score=0.65
# Resume - Reema Panday_JD12: Score=0.52
# Resume.SautrikGanguly_JD12: Score=0.51
# Resume_Rahul_kushwaha_JD12: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD12: Score=0.00
# Shashwata_Mondal_JD12: Score=0.51
# Stuti Mehrotra_CV 1_JD12: Score=0.71
# Sulagna Paul Resume (1)_JD12: Score=0.67
# Vedanti Khokher_JD12: Score=0.00
# Anuska Das_JD120: Score=0.00
# CV_Aarsh_JD120: Score=0.63
# CV_Arnab Roy_Model_Validation_JD120: Score=0.55
# G N Sindhur_resume_2025_JD120: Score=0.65
# Isha Porwal Resume_JD120: Score=0.62
# KartikMohan_JD120: Score=0.73
# Kshitij_Sahdev_CV (002)_JD120: Score=0.53
# Kundan_Kumar_JD120: Score=0.70
# Munna Choudhary_JD120: Score=0.00
# Narendra_Sahu_CreditRisk_JD120: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD120: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD120: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD120: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD120: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD120: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD120: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD120: Score=0.61
# Naukri_YashRai[4y_0m]_JD120: Score=0.63
# Nidhika-Tomar_JD120: Score=0.53
# Praveen R- Resume_JD120: Score=0.72
# Priyajit Bishayee resume 2025_JD120: Score=0.72
# Rajvi Doshi_JD120: Score=0.65
# Resume - Reema Panday_JD120: Score=0.52
# Resume.SautrikGanguly_JD120: Score=0.51
# Resume_Rahul_kushwaha_JD120: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD120: Score=0.00
# Shashwata_Mondal_JD120: Score=0.51
# Stuti Mehrotra_CV 1_JD120: Score=0.71
# Sulagna Paul Resume (1)_JD120: Score=0.67
# Vedanti Khokher_JD120: Score=0.00
# Anuska Das_JD121: Score=0.00
# CV_Aarsh_JD121: Score=0.63
# CV_Arnab Roy_Model_Validation_JD121: Score=0.55
# G N Sindhur_resume_2025_JD121: Score=0.65
# Isha Porwal Resume_JD121: Score=0.62
# KartikMohan_JD121: Score=0.73
# Kshitij_Sahdev_CV (002)_JD121: Score=0.53
# Kundan_Kumar_JD121: Score=0.70
# Munna Choudhary_JD121: Score=0.00
# Narendra_Sahu_CreditRisk_JD121: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD121: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD121: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD121: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD121: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD121: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD121: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD121: Score=0.61
# Naukri_YashRai[4y_0m]_JD121: Score=0.63
# Nidhika-Tomar_JD121: Score=0.53
# Praveen R- Resume_JD121: Score=0.72
# Priyajit Bishayee resume 2025_JD121: Score=0.72
# Rajvi Doshi_JD121: Score=0.65
# Resume - Reema Panday_JD121: Score=0.52
# Resume.SautrikGanguly_JD121: Score=0.51
# Resume_Rahul_kushwaha_JD121: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD121: Score=0.00
# Shashwata_Mondal_JD121: Score=0.51
# Stuti Mehrotra_CV 1_JD121: Score=0.71
# Sulagna Paul Resume (1)_JD121: Score=0.67
# Vedanti Khokher_JD121: Score=0.00
# Anuska Das_JD123: Score=0.00
# CV_Aarsh_JD123: Score=0.63
# CV_Arnab Roy_Model_Validation_JD123: Score=0.55
# G N Sindhur_resume_2025_JD123: Score=0.65
# Isha Porwal Resume_JD123: Score=0.62
# KartikMohan_JD123: Score=0.73
# Kshitij_Sahdev_CV (002)_JD123: Score=0.53
# Kundan_Kumar_JD123: Score=0.70
# Munna Choudhary_JD123: Score=0.00
# Narendra_Sahu_CreditRisk_JD123: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD123: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD123: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD123: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD123: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD123: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD123: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD123: Score=0.61
# Naukri_YashRai[4y_0m]_JD123: Score=0.63
# Nidhika-Tomar_JD123: Score=0.53
# Praveen R- Resume_JD123: Score=0.72
# Priyajit Bishayee resume 2025_JD123: Score=0.72
# Rajvi Doshi_JD123: Score=0.65
# Resume - Reema Panday_JD123: Score=0.52
# Resume.SautrikGanguly_JD123: Score=0.51
# Resume_Rahul_kushwaha_JD123: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD123: Score=0.00
# Shashwata_Mondal_JD123: Score=0.51
# Stuti Mehrotra_CV 1_JD123: Score=0.71
# Sulagna Paul Resume (1)_JD123: Score=0.67
# Vedanti Khokher_JD123: Score=0.00
# Anuska Das_JD124: Score=0.00
# CV_Aarsh_JD124: Score=0.63
# CV_Arnab Roy_Model_Validation_JD124: Score=0.55
# G N Sindhur_resume_2025_JD124: Score=0.65
# Isha Porwal Resume_JD124: Score=0.62
# KartikMohan_JD124: Score=0.73
# Kshitij_Sahdev_CV (002)_JD124: Score=0.53
# Kundan_Kumar_JD124: Score=0.70
# Munna Choudhary_JD124: Score=0.00
# Narendra_Sahu_CreditRisk_JD124: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD124: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD124: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD124: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD124: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD124: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD124: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD124: Score=0.61
# Naukri_YashRai[4y_0m]_JD124: Score=0.63
# Nidhika-Tomar_JD124: Score=0.53
# Praveen R- Resume_JD124: Score=0.72
# Priyajit Bishayee resume 2025_JD124: Score=0.72
# Rajvi Doshi_JD124: Score=0.65
# Resume - Reema Panday_JD124: Score=0.52
# Resume.SautrikGanguly_JD124: Score=0.51
# Resume_Rahul_kushwaha_JD124: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD124: Score=0.00
# Shashwata_Mondal_JD124: Score=0.51
# Stuti Mehrotra_CV 1_JD124: Score=0.71
# Sulagna Paul Resume (1)_JD124: Score=0.67
# Vedanti Khokher_JD124: Score=0.00
# Anuska Das_JD125: Score=0.00
# CV_Aarsh_JD125: Score=0.63
# CV_Arnab Roy_Model_Validation_JD125: Score=0.55
# G N Sindhur_resume_2025_JD125: Score=0.65
# Isha Porwal Resume_JD125: Score=0.62
# KartikMohan_JD125: Score=0.73
# Kshitij_Sahdev_CV (002)_JD125: Score=0.53
# Kundan_Kumar_JD125: Score=0.70
# Munna Choudhary_JD125: Score=0.00
# Narendra_Sahu_CreditRisk_JD125: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD125: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD125: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD125: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD125: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD125: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD125: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD125: Score=0.61
# Naukri_YashRai[4y_0m]_JD125: Score=0.63
# Nidhika-Tomar_JD125: Score=0.53
# Praveen R- Resume_JD125: Score=0.72
# Priyajit Bishayee resume 2025_JD125: Score=0.72
# Rajvi Doshi_JD125: Score=0.65
# Resume - Reema Panday_JD125: Score=0.52
# Resume.SautrikGanguly_JD125: Score=0.51
# Resume_Rahul_kushwaha_JD125: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD125: Score=0.00
# Shashwata_Mondal_JD125: Score=0.51
# Stuti Mehrotra_CV 1_JD125: Score=0.71
# Sulagna Paul Resume (1)_JD125: Score=0.67
# Vedanti Khokher_JD125: Score=0.00
# Anuska Das_JD126: Score=0.00
# CV_Aarsh_JD126: Score=0.63
# CV_Arnab Roy_Model_Validation_JD126: Score=0.55
# G N Sindhur_resume_2025_JD126: Score=0.65
# Isha Porwal Resume_JD126: Score=0.62
# KartikMohan_JD126: Score=0.73
# Kshitij_Sahdev_CV (002)_JD126: Score=0.53
# Kundan_Kumar_JD126: Score=0.70
# Munna Choudhary_JD126: Score=0.00
# Narendra_Sahu_CreditRisk_JD126: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD126: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD126: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD126: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD126: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD126: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD126: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD126: Score=0.61
# Naukri_YashRai[4y_0m]_JD126: Score=0.63
# Nidhika-Tomar_JD126: Score=0.53
# Praveen R- Resume_JD126: Score=0.72
# Priyajit Bishayee resume 2025_JD126: Score=0.72
# Rajvi Doshi_JD126: Score=0.65
# Resume - Reema Panday_JD126: Score=0.52
# Resume.SautrikGanguly_JD126: Score=0.51
# Resume_Rahul_kushwaha_JD126: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD126: Score=0.00
# Shashwata_Mondal_JD126: Score=0.51
# Stuti Mehrotra_CV 1_JD126: Score=0.71
# Sulagna Paul Resume (1)_JD126: Score=0.67
# Vedanti Khokher_JD126: Score=0.00
# Anuska Das_JD127: Score=0.00
# CV_Aarsh_JD127: Score=0.63
# CV_Arnab Roy_Model_Validation_JD127: Score=0.55
# G N Sindhur_resume_2025_JD127: Score=0.65
# Isha Porwal Resume_JD127: Score=0.62
# KartikMohan_JD127: Score=0.73
# Kshitij_Sahdev_CV (002)_JD127: Score=0.53
# Kundan_Kumar_JD127: Score=0.70
# Munna Choudhary_JD127: Score=0.00
# Narendra_Sahu_CreditRisk_JD127: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD127: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD127: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD127: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD127: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD127: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD127: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD127: Score=0.61
# Naukri_YashRai[4y_0m]_JD127: Score=0.63
# Nidhika-Tomar_JD127: Score=0.53
# Praveen R- Resume_JD127: Score=0.72
# Priyajit Bishayee resume 2025_JD127: Score=0.72
# Rajvi Doshi_JD127: Score=0.65
# Resume - Reema Panday_JD127: Score=0.52
# Resume.SautrikGanguly_JD127: Score=0.51
# Resume_Rahul_kushwaha_JD127: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD127: Score=0.00
# Shashwata_Mondal_JD127: Score=0.51
# Stuti Mehrotra_CV 1_JD127: Score=0.71
# Sulagna Paul Resume (1)_JD127: Score=0.67
# Vedanti Khokher_JD127: Score=0.00
# Anuska Das_JD129: Score=0.00
# CV_Aarsh_JD129: Score=0.63
# CV_Arnab Roy_Model_Validation_JD129: Score=0.55
# G N Sindhur_resume_2025_JD129: Score=0.65
# Isha Porwal Resume_JD129: Score=0.62
# KartikMohan_JD129: Score=0.73
# Kshitij_Sahdev_CV (002)_JD129: Score=0.53
# Kundan_Kumar_JD129: Score=0.70
# Munna Choudhary_JD129: Score=0.00
# Narendra_Sahu_CreditRisk_JD129: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD129: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD129: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD129: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD129: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD129: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD129: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD129: Score=0.61
# Naukri_YashRai[4y_0m]_JD129: Score=0.63
# Nidhika-Tomar_JD129: Score=0.53
# Praveen R- Resume_JD129: Score=0.72
# Priyajit Bishayee resume 2025_JD129: Score=0.72
# Rajvi Doshi_JD129: Score=0.65
# Resume - Reema Panday_JD129: Score=0.52
# Resume.SautrikGanguly_JD129: Score=0.51
# Resume_Rahul_kushwaha_JD129: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD129: Score=0.00
# Shashwata_Mondal_JD129: Score=0.51
# Stuti Mehrotra_CV 1_JD129: Score=0.71
# Sulagna Paul Resume (1)_JD129: Score=0.67
# Vedanti Khokher_JD129: Score=0.00
# Anuska Das_JD13: Score=0.00
# CV_Aarsh_JD13: Score=0.63
# CV_Arnab Roy_Model_Validation_JD13: Score=0.55
# G N Sindhur_resume_2025_JD13: Score=0.65
# Isha Porwal Resume_JD13: Score=0.62
# KartikMohan_JD13: Score=0.73
# Kshitij_Sahdev_CV (002)_JD13: Score=0.53
# Kundan_Kumar_JD13: Score=0.70
# Munna Choudhary_JD13: Score=0.00
# Narendra_Sahu_CreditRisk_JD13: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD13: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD13: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD13: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD13: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD13: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD13: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD13: Score=0.61
# Naukri_YashRai[4y_0m]_JD13: Score=0.63
# Nidhika-Tomar_JD13: Score=0.53
# Praveen R- Resume_JD13: Score=0.72
# Priyajit Bishayee resume 2025_JD13: Score=0.72
# Rajvi Doshi_JD13: Score=0.65
# Resume - Reema Panday_JD13: Score=0.52
# Resume.SautrikGanguly_JD13: Score=0.51
# Resume_Rahul_kushwaha_JD13: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD13: Score=0.00
# Shashwata_Mondal_JD13: Score=0.51
# Stuti Mehrotra_CV 1_JD13: Score=0.71
# Sulagna Paul Resume (1)_JD13: Score=0.67
# Vedanti Khokher_JD13: Score=0.00
# Anuska Das_JD130: Score=0.00
# CV_Aarsh_JD130: Score=0.63
# CV_Arnab Roy_Model_Validation_JD130: Score=0.55
# G N Sindhur_resume_2025_JD130: Score=0.65
# Isha Porwal Resume_JD130: Score=0.62
# KartikMohan_JD130: Score=0.73
# Kshitij_Sahdev_CV (002)_JD130: Score=0.53
# Kundan_Kumar_JD130: Score=0.70
# Munna Choudhary_JD130: Score=0.00
# Narendra_Sahu_CreditRisk_JD130: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD130: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD130: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD130: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD130: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD130: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD130: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD130: Score=0.61
# Naukri_YashRai[4y_0m]_JD130: Score=0.63
# Nidhika-Tomar_JD130: Score=0.53
# Praveen R- Resume_JD130: Score=0.72
# Priyajit Bishayee resume 2025_JD130: Score=0.72
# Rajvi Doshi_JD130: Score=0.65
# Resume - Reema Panday_JD130: Score=0.52
# Resume.SautrikGanguly_JD130: Score=0.51
# Resume_Rahul_kushwaha_JD130: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD130: Score=0.00
# Shashwata_Mondal_JD130: Score=0.51
# Stuti Mehrotra_CV 1_JD130: Score=0.71
# Sulagna Paul Resume (1)_JD130: Score=0.67
# Vedanti Khokher_JD130: Score=0.00
# Anuska Das_JD131: Score=0.00
# CV_Aarsh_JD131: Score=0.63
# CV_Arnab Roy_Model_Validation_JD131: Score=0.55
# G N Sindhur_resume_2025_JD131: Score=0.65
# Isha Porwal Resume_JD131: Score=0.62
# KartikMohan_JD131: Score=0.73
# Kshitij_Sahdev_CV (002)_JD131: Score=0.53
# Kundan_Kumar_JD131: Score=0.70
# Munna Choudhary_JD131: Score=0.00
# Narendra_Sahu_CreditRisk_JD131: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD131: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD131: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD131: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD131: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD131: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD131: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD131: Score=0.61
# Naukri_YashRai[4y_0m]_JD131: Score=0.63
# Nidhika-Tomar_JD131: Score=0.53
# Praveen R- Resume_JD131: Score=0.72
# Priyajit Bishayee resume 2025_JD131: Score=0.72
# Rajvi Doshi_JD131: Score=0.65
# Resume - Reema Panday_JD131: Score=0.52
# Resume.SautrikGanguly_JD131: Score=0.51
# Resume_Rahul_kushwaha_JD131: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD131: Score=0.00
# Shashwata_Mondal_JD131: Score=0.51
# Stuti Mehrotra_CV 1_JD131: Score=0.71
# Sulagna Paul Resume (1)_JD131: Score=0.67
# Vedanti Khokher_JD131: Score=0.00
# Anuska Das_JD132: Score=0.00
# CV_Aarsh_JD132: Score=0.63
# CV_Arnab Roy_Model_Validation_JD132: Score=0.55
# G N Sindhur_resume_2025_JD132: Score=0.65
# Isha Porwal Resume_JD132: Score=0.62
# KartikMohan_JD132: Score=0.73
# Kshitij_Sahdev_CV (002)_JD132: Score=0.53
# Kundan_Kumar_JD132: Score=0.70
# Munna Choudhary_JD132: Score=0.00
# Narendra_Sahu_CreditRisk_JD132: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD132: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD132: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD132: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD132: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD132: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD132: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD132: Score=0.61
# Naukri_YashRai[4y_0m]_JD132: Score=0.63
# Nidhika-Tomar_JD132: Score=0.53
# Praveen R- Resume_JD132: Score=0.72
# Priyajit Bishayee resume 2025_JD132: Score=0.72
# Rajvi Doshi_JD132: Score=0.65
# Resume - Reema Panday_JD132: Score=0.52
# Resume.SautrikGanguly_JD132: Score=0.51
# Resume_Rahul_kushwaha_JD132: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD132: Score=0.00
# Shashwata_Mondal_JD132: Score=0.51
# Stuti Mehrotra_CV 1_JD132: Score=0.71
# Sulagna Paul Resume (1)_JD132: Score=0.67
# Vedanti Khokher_JD132: Score=0.00
# Anuska Das_JD134: Score=0.00
# CV_Aarsh_JD134: Score=0.63
# CV_Arnab Roy_Model_Validation_JD134: Score=0.55
# G N Sindhur_resume_2025_JD134: Score=0.65
# Isha Porwal Resume_JD134: Score=0.62
# KartikMohan_JD134: Score=0.73
# Kshitij_Sahdev_CV (002)_JD134: Score=0.53
# Kundan_Kumar_JD134: Score=0.70
# Munna Choudhary_JD134: Score=0.00
# Narendra_Sahu_CreditRisk_JD134: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD134: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD134: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD134: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD134: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD134: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD134: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD134: Score=0.61
# Naukri_YashRai[4y_0m]_JD134: Score=0.63
# Nidhika-Tomar_JD134: Score=0.53
# Praveen R- Resume_JD134: Score=0.72
# Priyajit Bishayee resume 2025_JD134: Score=0.72
# Rajvi Doshi_JD134: Score=0.65
# Resume - Reema Panday_JD134: Score=0.52
# Resume.SautrikGanguly_JD134: Score=0.51
# Resume_Rahul_kushwaha_JD134: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD134: Score=0.00
# Shashwata_Mondal_JD134: Score=0.51
# Stuti Mehrotra_CV 1_JD134: Score=0.71
# Sulagna Paul Resume (1)_JD134: Score=0.67
# Vedanti Khokher_JD134: Score=0.00
# Anuska Das_JD135: Score=0.00
# CV_Aarsh_JD135: Score=0.63
# CV_Arnab Roy_Model_Validation_JD135: Score=0.55
# G N Sindhur_resume_2025_JD135: Score=0.65
# Isha Porwal Resume_JD135: Score=0.62
# KartikMohan_JD135: Score=0.73
# Kshitij_Sahdev_CV (002)_JD135: Score=0.53
# Kundan_Kumar_JD135: Score=0.70
# Munna Choudhary_JD135: Score=0.00
# Narendra_Sahu_CreditRisk_JD135: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD135: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD135: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD135: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD135: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD135: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD135: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD135: Score=0.61
# Naukri_YashRai[4y_0m]_JD135: Score=0.63
# Nidhika-Tomar_JD135: Score=0.53
# Praveen R- Resume_JD135: Score=0.72
# Priyajit Bishayee resume 2025_JD135: Score=0.72
# Rajvi Doshi_JD135: Score=0.65
# Resume - Reema Panday_JD135: Score=0.52
# Resume.SautrikGanguly_JD135: Score=0.51
# Resume_Rahul_kushwaha_JD135: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD135: Score=0.00
# Shashwata_Mondal_JD135: Score=0.51
# Stuti Mehrotra_CV 1_JD135: Score=0.71
# Sulagna Paul Resume (1)_JD135: Score=0.67
# Vedanti Khokher_JD135: Score=0.00
# Anuska Das_JD136: Score=0.00
# CV_Aarsh_JD136: Score=0.63
# CV_Arnab Roy_Model_Validation_JD136: Score=0.55
# G N Sindhur_resume_2025_JD136: Score=0.65
# Isha Porwal Resume_JD136: Score=0.62
# KartikMohan_JD136: Score=0.73
# Kshitij_Sahdev_CV (002)_JD136: Score=0.53
# Kundan_Kumar_JD136: Score=0.70
# Munna Choudhary_JD136: Score=0.00
# Narendra_Sahu_CreditRisk_JD136: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD136: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD136: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD136: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD136: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD136: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD136: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD136: Score=0.61
# Naukri_YashRai[4y_0m]_JD136: Score=0.63
# Nidhika-Tomar_JD136: Score=0.53
# Praveen R- Resume_JD136: Score=0.72
# Priyajit Bishayee resume 2025_JD136: Score=0.72
# Rajvi Doshi_JD136: Score=0.65
# Resume - Reema Panday_JD136: Score=0.52
# Resume.SautrikGanguly_JD136: Score=0.51
# Resume_Rahul_kushwaha_JD136: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD136: Score=0.00
# Shashwata_Mondal_JD136: Score=0.51
# Stuti Mehrotra_CV 1_JD136: Score=0.71
# Sulagna Paul Resume (1)_JD136: Score=0.67
# Vedanti Khokher_JD136: Score=0.00
# Anuska Das_JD137: Score=0.00
# CV_Aarsh_JD137: Score=0.63
# CV_Arnab Roy_Model_Validation_JD137: Score=0.55
# G N Sindhur_resume_2025_JD137: Score=0.65
# Isha Porwal Resume_JD137: Score=0.62
# KartikMohan_JD137: Score=0.73
# Kshitij_Sahdev_CV (002)_JD137: Score=0.53
# Kundan_Kumar_JD137: Score=0.70
# Munna Choudhary_JD137: Score=0.00
# Narendra_Sahu_CreditRisk_JD137: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD137: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD137: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD137: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD137: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD137: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD137: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD137: Score=0.61
# Naukri_YashRai[4y_0m]_JD137: Score=0.63
# Nidhika-Tomar_JD137: Score=0.53
# Praveen R- Resume_JD137: Score=0.72
# Priyajit Bishayee resume 2025_JD137: Score=0.72
# Rajvi Doshi_JD137: Score=0.65
# Resume - Reema Panday_JD137: Score=0.52
# Resume.SautrikGanguly_JD137: Score=0.51
# Resume_Rahul_kushwaha_JD137: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD137: Score=0.00
# Shashwata_Mondal_JD137: Score=0.51
# Stuti Mehrotra_CV 1_JD137: Score=0.71
# Sulagna Paul Resume (1)_JD137: Score=0.67
# Vedanti Khokher_JD137: Score=0.00
# Anuska Das_JD138: Score=0.00
# CV_Aarsh_JD138: Score=0.63
# CV_Arnab Roy_Model_Validation_JD138: Score=0.55
# G N Sindhur_resume_2025_JD138: Score=0.65
# Isha Porwal Resume_JD138: Score=0.62
# KartikMohan_JD138: Score=0.73
# Kshitij_Sahdev_CV (002)_JD138: Score=0.53
# Kundan_Kumar_JD138: Score=0.70
# Munna Choudhary_JD138: Score=0.00
# Narendra_Sahu_CreditRisk_JD138: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD138: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD138: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD138: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD138: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD138: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD138: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD138: Score=0.61
# Naukri_YashRai[4y_0m]_JD138: Score=0.63
# Nidhika-Tomar_JD138: Score=0.53
# Praveen R- Resume_JD138: Score=0.72
# Priyajit Bishayee resume 2025_JD138: Score=0.72
# Rajvi Doshi_JD138: Score=0.65
# Resume - Reema Panday_JD138: Score=0.52
# Resume.SautrikGanguly_JD138: Score=0.51
# Resume_Rahul_kushwaha_JD138: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD138: Score=0.00
# Shashwata_Mondal_JD138: Score=0.51
# ...
# CV_Aarsh_JD87: Score=0.63
# CV_Arnab Roy_Model_Validation_JD87: Score=0.55
# G N Sindhur_resume_2025_JD87: Score=0.65
# Isha Porwal Resume_JD87: Score=0.62
# KartikMohan_JD87: Score=0.73
# Kshitij_Sahdev_CV (002)_JD87: Score=0.53
# Kundan_Kumar_JD87: Score=0.70
# Munna Choudhary_JD87: Score=0.00
# Narendra_Sahu_CreditRisk_JD87: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD87: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD87: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD87: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD87: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD87: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD87: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD87: Score=0.61
# Naukri_YashRai[4y_0m]_JD87: Score=0.63
# Nidhika-Tomar_JD87: Score=0.53
# Praveen R- Resume_JD87: Score=0.72
# Priyajit Bishayee resume 2025_JD87: Score=0.72
# Rajvi Doshi_JD87: Score=0.65
# Resume - Reema Panday_JD87: Score=0.52
# Resume.SautrikGanguly_JD87: Score=0.51
# Resume_Rahul_kushwaha_JD87: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD87: Score=0.00
# Shashwata_Mondal_JD87: Score=0.51
# Stuti Mehrotra_CV 1_JD87: Score=0.71
# Sulagna Paul Resume (1)_JD87: Score=0.67
# Vedanti Khokher_JD87: Score=0.00
# Anuska Das_JD88: Score=0.00
# CV_Aarsh_JD88: Score=0.63
# CV_Arnab Roy_Model_Validation_JD88: Score=0.55
# G N Sindhur_resume_2025_JD88: Score=0.65
# Isha Porwal Resume_JD88: Score=0.62
# KartikMohan_JD88: Score=0.73
# Kshitij_Sahdev_CV (002)_JD88: Score=0.53
# Kundan_Kumar_JD88: Score=0.70
# Munna Choudhary_JD88: Score=0.00
# Narendra_Sahu_CreditRisk_JD88: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD88: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD88: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD88: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD88: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD88: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD88: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD88: Score=0.61
# Naukri_YashRai[4y_0m]_JD88: Score=0.63
# Nidhika-Tomar_JD88: Score=0.53
# Praveen R- Resume_JD88: Score=0.72
# Priyajit Bishayee resume 2025_JD88: Score=0.72
# Rajvi Doshi_JD88: Score=0.65
# Resume - Reema Panday_JD88: Score=0.52
# Resume.SautrikGanguly_JD88: Score=0.51
# Resume_Rahul_kushwaha_JD88: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD88: Score=0.00
# Shashwata_Mondal_JD88: Score=0.51
# Stuti Mehrotra_CV 1_JD88: Score=0.71
# Sulagna Paul Resume (1)_JD88: Score=0.67
# Vedanti Khokher_JD88: Score=0.00
# Anuska Das_JD89: Score=0.00
# CV_Aarsh_JD89: Score=0.63
# CV_Arnab Roy_Model_Validation_JD89: Score=0.55
# G N Sindhur_resume_2025_JD89: Score=0.65
# Isha Porwal Resume_JD89: Score=0.62
# KartikMohan_JD89: Score=0.73
# Kshitij_Sahdev_CV (002)_JD89: Score=0.53
# Kundan_Kumar_JD89: Score=0.70
# Munna Choudhary_JD89: Score=0.00
# Narendra_Sahu_CreditRisk_JD89: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD89: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD89: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD89: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD89: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD89: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD89: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD89: Score=0.61
# Naukri_YashRai[4y_0m]_JD89: Score=0.63
# Nidhika-Tomar_JD89: Score=0.53
# Praveen R- Resume_JD89: Score=0.72
# Priyajit Bishayee resume 2025_JD89: Score=0.72
# Rajvi Doshi_JD89: Score=0.65
# Resume - Reema Panday_JD89: Score=0.52
# Resume.SautrikGanguly_JD89: Score=0.51
# Resume_Rahul_kushwaha_JD89: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD89: Score=0.00
# Shashwata_Mondal_JD89: Score=0.51
# Stuti Mehrotra_CV 1_JD89: Score=0.71
# Sulagna Paul Resume (1)_JD89: Score=0.67
# Vedanti Khokher_JD89: Score=0.00
# Anuska Das_JD9: Score=0.00
# CV_Aarsh_JD9: Score=0.63
# CV_Arnab Roy_Model_Validation_JD9: Score=0.55
# G N Sindhur_resume_2025_JD9: Score=0.65
# Isha Porwal Resume_JD9: Score=0.62
# KartikMohan_JD9: Score=0.73
# Kshitij_Sahdev_CV (002)_JD9: Score=0.53
# Kundan_Kumar_JD9: Score=0.70
# Munna Choudhary_JD9: Score=0.00
# Narendra_Sahu_CreditRisk_JD9: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD9: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD9: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD9: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD9: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD9: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD9: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD9: Score=0.61
# Naukri_YashRai[4y_0m]_JD9: Score=0.63
# Nidhika-Tomar_JD9: Score=0.53
# Praveen R- Resume_JD9: Score=0.72
# Priyajit Bishayee resume 2025_JD9: Score=0.72
# Rajvi Doshi_JD9: Score=0.65
# Resume - Reema Panday_JD9: Score=0.52
# Resume.SautrikGanguly_JD9: Score=0.51
# Resume_Rahul_kushwaha_JD9: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD9: Score=0.00
# Shashwata_Mondal_JD9: Score=0.51
# Stuti Mehrotra_CV 1_JD9: Score=0.71
# Sulagna Paul Resume (1)_JD9: Score=0.67
# Vedanti Khokher_JD9: Score=0.00
# Anuska Das_JD90: Score=0.00
# CV_Aarsh_JD90: Score=0.63
# CV_Arnab Roy_Model_Validation_JD90: Score=0.55
# G N Sindhur_resume_2025_JD90: Score=0.65
# Isha Porwal Resume_JD90: Score=0.62
# KartikMohan_JD90: Score=0.73
# Kshitij_Sahdev_CV (002)_JD90: Score=0.53
# Kundan_Kumar_JD90: Score=0.70
# Munna Choudhary_JD90: Score=0.00
# Narendra_Sahu_CreditRisk_JD90: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD90: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD90: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD90: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD90: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD90: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD90: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD90: Score=0.61
# Naukri_YashRai[4y_0m]_JD90: Score=0.63
# Nidhika-Tomar_JD90: Score=0.53
# Praveen R- Resume_JD90: Score=0.72
# Priyajit Bishayee resume 2025_JD90: Score=0.72
# Rajvi Doshi_JD90: Score=0.65
# Resume - Reema Panday_JD90: Score=0.52
# Resume.SautrikGanguly_JD90: Score=0.51
# Resume_Rahul_kushwaha_JD90: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD90: Score=0.00
# Shashwata_Mondal_JD90: Score=0.51
# Stuti Mehrotra_CV 1_JD90: Score=0.71
# Sulagna Paul Resume (1)_JD90: Score=0.67
# Vedanti Khokher_JD90: Score=0.00
# Anuska Das_JD91: Score=0.00
# CV_Aarsh_JD91: Score=0.63
# CV_Arnab Roy_Model_Validation_JD91: Score=0.55
# G N Sindhur_resume_2025_JD91: Score=0.65
# Isha Porwal Resume_JD91: Score=0.62
# KartikMohan_JD91: Score=0.73
# Kshitij_Sahdev_CV (002)_JD91: Score=0.53
# Kundan_Kumar_JD91: Score=0.70
# Munna Choudhary_JD91: Score=0.00
# Narendra_Sahu_CreditRisk_JD91: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD91: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD91: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD91: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD91: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD91: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD91: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD91: Score=0.61
# Naukri_YashRai[4y_0m]_JD91: Score=0.63
# Nidhika-Tomar_JD91: Score=0.53
# Praveen R- Resume_JD91: Score=0.72
# Priyajit Bishayee resume 2025_JD91: Score=0.72
# Rajvi Doshi_JD91: Score=0.65
# Resume - Reema Panday_JD91: Score=0.52
# Resume.SautrikGanguly_JD91: Score=0.51
# Resume_Rahul_kushwaha_JD91: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD91: Score=0.00
# Shashwata_Mondal_JD91: Score=0.51
# Stuti Mehrotra_CV 1_JD91: Score=0.71
# Sulagna Paul Resume (1)_JD91: Score=0.67
# Vedanti Khokher_JD91: Score=0.00
# Anuska Das_JD92: Score=0.00
# CV_Aarsh_JD92: Score=0.63
# CV_Arnab Roy_Model_Validation_JD92: Score=0.55
# G N Sindhur_resume_2025_JD92: Score=0.65
# Isha Porwal Resume_JD92: Score=0.62
# KartikMohan_JD92: Score=0.73
# Kshitij_Sahdev_CV (002)_JD92: Score=0.53
# Kundan_Kumar_JD92: Score=0.70
# Munna Choudhary_JD92: Score=0.00
# Narendra_Sahu_CreditRisk_JD92: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD92: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD92: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD92: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD92: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD92: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD92: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD92: Score=0.61
# Naukri_YashRai[4y_0m]_JD92: Score=0.63
# Nidhika-Tomar_JD92: Score=0.53
# Praveen R- Resume_JD92: Score=0.72
# Priyajit Bishayee resume 2025_JD92: Score=0.72
# Rajvi Doshi_JD92: Score=0.65
# Resume - Reema Panday_JD92: Score=0.52
# Resume.SautrikGanguly_JD92: Score=0.51
# Resume_Rahul_kushwaha_JD92: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD92: Score=0.00
# Shashwata_Mondal_JD92: Score=0.51
# Stuti Mehrotra_CV 1_JD92: Score=0.71
# Sulagna Paul Resume (1)_JD92: Score=0.67
# Vedanti Khokher_JD92: Score=0.00
# Anuska Das_JD93: Score=0.00
# CV_Aarsh_JD93: Score=0.63
# CV_Arnab Roy_Model_Validation_JD93: Score=0.55
# G N Sindhur_resume_2025_JD93: Score=0.65
# Isha Porwal Resume_JD93: Score=0.62
# KartikMohan_JD93: Score=0.73
# Kshitij_Sahdev_CV (002)_JD93: Score=0.53
# Kundan_Kumar_JD93: Score=0.70
# Munna Choudhary_JD93: Score=0.00
# Narendra_Sahu_CreditRisk_JD93: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD93: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD93: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD93: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD93: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD93: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD93: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD93: Score=0.61
# Naukri_YashRai[4y_0m]_JD93: Score=0.63
# Nidhika-Tomar_JD93: Score=0.53
# Praveen R- Resume_JD93: Score=0.72
# Priyajit Bishayee resume 2025_JD93: Score=0.72
# Rajvi Doshi_JD93: Score=0.65
# Resume - Reema Panday_JD93: Score=0.52
# Resume.SautrikGanguly_JD93: Score=0.51
# Resume_Rahul_kushwaha_JD93: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD93: Score=0.00
# Shashwata_Mondal_JD93: Score=0.51
# Stuti Mehrotra_CV 1_JD93: Score=0.71
# Sulagna Paul Resume (1)_JD93: Score=0.67
# Vedanti Khokher_JD93: Score=0.00
# Anuska Das_JD94: Score=0.00
# CV_Aarsh_JD94: Score=0.63
# CV_Arnab Roy_Model_Validation_JD94: Score=0.55
# G N Sindhur_resume_2025_JD94: Score=0.65
# Isha Porwal Resume_JD94: Score=0.62
# KartikMohan_JD94: Score=0.73
# Kshitij_Sahdev_CV (002)_JD94: Score=0.53
# Kundan_Kumar_JD94: Score=0.70
# Munna Choudhary_JD94: Score=0.00
# Narendra_Sahu_CreditRisk_JD94: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD94: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD94: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD94: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD94: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD94: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD94: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD94: Score=0.61
# Naukri_YashRai[4y_0m]_JD94: Score=0.63
# Nidhika-Tomar_JD94: Score=0.53
# Praveen R- Resume_JD94: Score=0.72
# Priyajit Bishayee resume 2025_JD94: Score=0.72
# Rajvi Doshi_JD94: Score=0.65
# Resume - Reema Panday_JD94: Score=0.52
# Resume.SautrikGanguly_JD94: Score=0.51
# Resume_Rahul_kushwaha_JD94: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD94: Score=0.00
# Shashwata_Mondal_JD94: Score=0.51
# Stuti Mehrotra_CV 1_JD94: Score=0.71
# Sulagna Paul Resume (1)_JD94: Score=0.67
# Vedanti Khokher_JD94: Score=0.00
# Anuska Das_JD95: Score=0.00
# CV_Aarsh_JD95: Score=0.63
# CV_Arnab Roy_Model_Validation_JD95: Score=0.55
# G N Sindhur_resume_2025_JD95: Score=0.65
# Isha Porwal Resume_JD95: Score=0.62
# KartikMohan_JD95: Score=0.73
# Kshitij_Sahdev_CV (002)_JD95: Score=0.53
# Kundan_Kumar_JD95: Score=0.70
# Munna Choudhary_JD95: Score=0.00
# Narendra_Sahu_CreditRisk_JD95: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD95: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD95: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD95: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD95: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD95: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD95: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD95: Score=0.61
# Naukri_YashRai[4y_0m]_JD95: Score=0.63
# Nidhika-Tomar_JD95: Score=0.53
# Praveen R- Resume_JD95: Score=0.72
# Priyajit Bishayee resume 2025_JD95: Score=0.72
# Rajvi Doshi_JD95: Score=0.65
# Resume - Reema Panday_JD95: Score=0.52
# Resume.SautrikGanguly_JD95: Score=0.51
# Resume_Rahul_kushwaha_JD95: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD95: Score=0.00
# Shashwata_Mondal_JD95: Score=0.51
# Stuti Mehrotra_CV 1_JD95: Score=0.71
# Sulagna Paul Resume (1)_JD95: Score=0.67
# Vedanti Khokher_JD95: Score=0.00
# Anuska Das_JD96: Score=0.00
# CV_Aarsh_JD96: Score=0.63
# CV_Arnab Roy_Model_Validation_JD96: Score=0.55
# G N Sindhur_resume_2025_JD96: Score=0.65
# Isha Porwal Resume_JD96: Score=0.62
# KartikMohan_JD96: Score=0.73
# Kshitij_Sahdev_CV (002)_JD96: Score=0.53
# Kundan_Kumar_JD96: Score=0.70
# Munna Choudhary_JD96: Score=0.00
# Narendra_Sahu_CreditRisk_JD96: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD96: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD96: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD96: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD96: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD96: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD96: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD96: Score=0.61
# Naukri_YashRai[4y_0m]_JD96: Score=0.63
# Nidhika-Tomar_JD96: Score=0.53
# Praveen R- Resume_JD96: Score=0.72
# Priyajit Bishayee resume 2025_JD96: Score=0.72
# Rajvi Doshi_JD96: Score=0.65
# Resume - Reema Panday_JD96: Score=0.52
# Resume.SautrikGanguly_JD96: Score=0.51
# Resume_Rahul_kushwaha_JD96: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD96: Score=0.00
# Shashwata_Mondal_JD96: Score=0.51
# Stuti Mehrotra_CV 1_JD96: Score=0.71
# Sulagna Paul Resume (1)_JD96: Score=0.67
# Vedanti Khokher_JD96: Score=0.00
# Anuska Das_JD97: Score=0.00
# CV_Aarsh_JD97: Score=0.63
# CV_Arnab Roy_Model_Validation_JD97: Score=0.55
# G N Sindhur_resume_2025_JD97: Score=0.65
# Isha Porwal Resume_JD97: Score=0.62
# KartikMohan_JD97: Score=0.73
# Kshitij_Sahdev_CV (002)_JD97: Score=0.53
# Kundan_Kumar_JD97: Score=0.70
# Munna Choudhary_JD97: Score=0.00
# Narendra_Sahu_CreditRisk_JD97: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD97: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD97: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD97: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD97: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD97: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD97: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD97: Score=0.61
# Naukri_YashRai[4y_0m]_JD97: Score=0.63
# Nidhika-Tomar_JD97: Score=0.53
# Praveen R- Resume_JD97: Score=0.72
# Priyajit Bishayee resume 2025_JD97: Score=0.72
# Rajvi Doshi_JD97: Score=0.65
# Resume - Reema Panday_JD97: Score=0.52
# Resume.SautrikGanguly_JD97: Score=0.51
# Resume_Rahul_kushwaha_JD97: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD97: Score=0.00
# Shashwata_Mondal_JD97: Score=0.51
# Stuti Mehrotra_CV 1_JD97: Score=0.71
# Sulagna Paul Resume (1)_JD97: Score=0.67
# Vedanti Khokher_JD97: Score=0.00
# Anuska Das_JD98: Score=0.00
# CV_Aarsh_JD98: Score=0.63
# CV_Arnab Roy_Model_Validation_JD98: Score=0.55
# G N Sindhur_resume_2025_JD98: Score=0.65
# Isha Porwal Resume_JD98: Score=0.62
# KartikMohan_JD98: Score=0.73
# Kshitij_Sahdev_CV (002)_JD98: Score=0.53
# Kundan_Kumar_JD98: Score=0.70
# Munna Choudhary_JD98: Score=0.00
# Narendra_Sahu_CreditRisk_JD98: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD98: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD98: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD98: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD98: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD98: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD98: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD98: Score=0.61
# Naukri_YashRai[4y_0m]_JD98: Score=0.63
# Nidhika-Tomar_JD98: Score=0.53
# Praveen R- Resume_JD98: Score=0.72
# Priyajit Bishayee resume 2025_JD98: Score=0.72
# Rajvi Doshi_JD98: Score=0.65
# Resume - Reema Panday_JD98: Score=0.52
# Resume.SautrikGanguly_JD98: Score=0.51
# Resume_Rahul_kushwaha_JD98: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD98: Score=0.00
# Shashwata_Mondal_JD98: Score=0.51
# Stuti Mehrotra_CV 1_JD98: Score=0.71
# Sulagna Paul Resume (1)_JD98: Score=0.67
# Vedanti Khokher_JD98: Score=0.00
# Anuska Das_JD99: Score=0.00
# CV_Aarsh_JD99: Score=0.63
# CV_Arnab Roy_Model_Validation_JD99: Score=0.55
# G N Sindhur_resume_2025_JD99: Score=0.65
# Isha Porwal Resume_JD99: Score=0.62
# KartikMohan_JD99: Score=0.73
# Kshitij_Sahdev_CV (002)_JD99: Score=0.53
# Kundan_Kumar_JD99: Score=0.70
# Munna Choudhary_JD99: Score=0.00
# Narendra_Sahu_CreditRisk_JD99: Score=0.68
# Naukri_AbhimanyuSingh[3y_7m]_JD99: Score=0.65
# Naukri_AnandKumar[10y_0m]_JD99: Score=0.58
# Naukri_DEBSUBHRAGHOSH[7y_0m]_JD99: Score=0.63
# Naukri_GirishKhandelwal[11y_0m]_JD99: Score=0.73
# Naukri_SAHILPATIL[2y_11m]_JD99: Score=0.69
# Naukri_SusmitaMisra[3y_9m]_JD99: Score=0.63
# Naukri_Vaibhav[3y_6m]_JD99: Score=0.61
# Naukri_YashRai[4y_0m]_JD99: Score=0.63
# Nidhika-Tomar_JD99: Score=0.53
# Praveen R- Resume_JD99: Score=0.72
# Priyajit Bishayee resume 2025_JD99: Score=0.72
# Rajvi Doshi_JD99: Score=0.65
# Resume - Reema Panday_JD99: Score=0.52
# Resume.SautrikGanguly_JD99: Score=0.51
# Resume_Rahul_kushwaha_JD99: Score=0.63
# SAIKIRAN KPMG CV-1-2-2_JD99: Score=0.00
# Shashwata_Mondal_JD99: Score=0.51
# Stuti Mehrotra_CV 1_JD99: Score=0.71
# Sulagna Paul Resume (1)_JD99: Score=0.67
# Vedanti Khokher_JD99: Score=0.00

# %%
import os
import zipfile
import fitz  # PyMuPDF
import docx
import re
import requests
import time

# --------------------- CONFIGURATION ---------------------

base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
jd_dir = os.path.join(base_path, "JDs")
manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")
raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
output_dir = os.path.join(base_path, "customised_resumes_llm")
temp_raw_dir = os.path.join(base_path, "temp_raw")
os.makedirs(output_dir, exist_ok=True)
os.makedirs(temp_raw_dir, exist_ok=True)

# --------------------- UTILS ---------------------

def extract_zip(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

def read_pdf_text(pdf_path):
    doc = fitz.open(pdf_path)
    return "\n".join([page.get_text() for page in doc])

def read_docx_text(docx_path):
    doc = docx.Document(docx_path)
    return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

def read_resume(path):
    if path.endswith(".pdf"):
        return read_pdf_text(path)
    elif path.endswith(".docx"):
        return read_docx_text(path)
    elif path.endswith(".txt"):
        with open(path, 'r', encoding='utf-8') as f:
            return f.read()
    return ""

def split_sentences(text):
    return re.split(r'(?<=[.;])\s+', text)

def call_lmstudio_llm(jd_text, resume_bullets):
    prompt = f"""
You are a resume customization assistant for a consulting firm. Your job is to:
1. Select only relevant resume bullet points that match the job description (JD).
2. Rephrase those points to align with the tone and keywords of the JD.
3. Output in plain, professional bullet points.

JD:
{jd_text}

Candidate Resume:
{resume_bullets}

Final Output (only bullet points in EY tone):
"""

    try:
        response = requests.post(
            "http://localhost:1234/v1/chat",
            headers={"Content-Type": "application/json"},
            json={
                "model": "mistral",  # Your actual model name/alias from LM Studio
                "messages": [{"role": "user", "content": prompt}],
                "temperature": 0.5,
                "max_tokens": 1024
            },
            timeout=180
        )
        result = response.json()
        return result['choices'][0]['message']['content'].strip()
    except Exception as e:
        print("LM Studio error:", e)
        return ""

# --------------------- MAIN FUNCTION ---------------------

def customize_resumes_with_lmstudio():
    print("STEP 1: Extracting resumes...")
    extract_zip(raw_resume_zip, temp_raw_dir)
    with open(ey_format_path, "r", encoding="utf-8") as f:
        ey_template = f.read()

    jd_files = [f for f in os.listdir(jd_dir) if f.endswith(".txt")]
    raw_files = [f for f in os.listdir(temp_raw_dir) if f.endswith((".pdf", ".docx", ".txt"))]

    print("STEP 2: LLM-based customization in progress...")
    for raw_file in raw_files:
        raw_path = os.path.join(temp_raw_dir, raw_file)
        raw_name = os.path.splitext(raw_file)[0]
        raw_text = read_resume(raw_path)
        raw_sentences = split_sentences(raw_text)
        resume_bullets = "\n".join(f"- {line.strip()}" for line in raw_sentences if len(line.strip()) > 30)

        for jd_file in jd_files:
            jd_path = os.path.join(jd_dir, jd_file)
            jd_name = os.path.splitext(jd_file)[0]
            with open(jd_path, "r", encoding="utf-8") as f:
                jd_text = f.read()

            rewritten_bullets = call_lmstudio_llm(jd_text, resume_bullets)
            final_resume = ey_template.replace("[EXPERIENCE_PLACEHOLDER]", rewritten_bullets)

            output_path = os.path.join(output_dir, f"{raw_name}_{jd_name}.txt")
            with open(output_path, "w", encoding="utf-8") as out_f:
                out_f.write(final_resume)

            print(f"✅ Saved: {output_path}")
            time.sleep(1)

# --------------------- RUN ---------------------

if __name__ == "__main__":
    customize_resumes_with_lmstudio()
# Out:
# STEP 1: Extracting resumes...
# STEP 2: LLM-based customization in progress...

# %%
# import os
# import zipfile
# import fitz  # PyMuPDF
# import docx
# import requests
# import json
# import re
# import time
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # ---------------- CONFIGURATION ----------------

# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"

# ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
# jd_dir = os.path.join(base_path, "JDs")
# raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
# manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")

# raw_resume_dir = os.path.join(base_path, "raw_extracted")
# manual_resume_dir = os.path.join(base_path, "manual_extracted")
# output_dir = os.path.join(base_path, "customised_resumes_llm")
# log_dir = os.path.join(base_path, "match_logs")

# os.makedirs(output_dir, exist_ok=True)
# os.makedirs(log_dir, exist_ok=True)

# # ---------------- UTIL FUNCTIONS ----------------

# def extract_zip(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join(page.get_text() for page in doc)

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join(p.text for p in doc.paragraphs if p.text.strip())

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf(path)
#     elif path.endswith(".docx"):
#         return read_docx(path)
#     else:
#         return ""

# def get_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def call_lmstudio_llm(jd_text, bullet_points):
#     prompt = f"""You are a resume expert. Based on the job description below, select and rewrite only the most relevant bullet points from the candidate's experience to match the JD tone professionally.

# JD:
# {jd_text}

# Candidate Bullet Points:
# {bullet_points}

# Return only the final bullet points."""
    
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": "mistral-7b-instruct-v0.3-q4_k_m-gguf",
#         "prompt": prompt,
#         "temperature": 0.7,
#         "max_tokens": 1024,
#         "stop": ["</s>"]
#     }

#     try:
#         response = requests.post("http://localhost:1234/v1/completions", headers=headers, data=json.dumps(payload), timeout=180)
#         return response.json().get("choices", [{}])[0].get("text", "").strip()
#     except Exception as e:
#         return f"LLM error: {e}"

# # ---------------- MAIN FUNCTION ----------------

# def customize_resumes_with_lmstudio():
#     print("STEP 1: Extracting resumes...")
#     extract_zip(raw_resume_zip, raw_resume_dir)
#     extract_zip(manual_resume_zip, manual_resume_dir)

#     raw_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(raw_resume_dir)
#         for f in files
#     }

#     jd_texts = {
#         os.path.splitext(f)[0]: open(os.path.join(root, f), "r", encoding="utf-8").read()
#         for root, _, files in os.walk(jd_dir)
#         for f in files if f.endswith(".txt")
#     }

#     manual_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(manual_resume_dir)
#         for f in files
#     }

#     ey_template = open(ey_format_path, "r", encoding="utf-8").read()

#     print("STEP 2: LLM-based customization in progress...")

#     for raw_name, raw_text in raw_resumes.items():
#         # Find best JD for this resume
#         best_jd, best_score = None, 0
#         for jd_name, jd_text in jd_texts.items():
#             score = get_similarity(raw_text, jd_text)
#             if score > best_score:
#                 best_score = score
#                 best_jd = jd_name

#         if not best_jd:
#             continue

#         jd_text = jd_texts[best_jd]
#         resume_bullets = "\n".join([s.strip() for s in raw_text.split(". ") if len(s.strip()) > 30])

#         rewritten_bullets = call_lmstudio_llm(jd_text, resume_bullets)
#         final_resume = ey_template.replace("[EXPERIENCE_PLACEHOLDER]", rewritten_bullets)

#         output_path = os.path.join(output_dir, f"{raw_name}_{best_jd}.txt")
#         with open(output_path, "w", encoding="utf-8") as out_f:
#             out_f.write(final_resume)

#         print(f"✅ Saved: {output_path}")

#         # Optional: Compare with manual resume
#         matched_manual_key = next((k for k in manual_resumes if raw_name.lower() in k.lower()), None)
#         if matched_manual_key:
#             manual_text = manual_resumes[matched_manual_key]
#             sim = get_similarity(final_resume, manual_text)
#             log_line = f"{raw_name} <-> {best_jd}: {sim:.2f}\n"
#             with open(os.path.join(log_dir, "similarity_scores.txt"), "a", encoding="utf-8") as log_f:
#                 log_f.write(log_line)

#         time.sleep(1)

# # ---------------- RUN ----------------

# if __name__ == "__main__":
#     customize_resumes_with_lmstudio()
# Out:
# STEP 1: Extracting resumes...
# STEP 2: LLM-based customization in progress...
# ✅ Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\customised_resumes_llm\Anuska Das_JD_52.txt
# ✅ Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\customised_resumes_llm\CV_Aarsh_JD_55.txt
# ✅ Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\customised_resumes_llm\CV_Arnab Roy_Model_Validation_JD_77.txt
# ✅ Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\customised_resumes_llm\G N Sindhur_resume_2025_JD_23.txt

# %%
import os, zipfile, fitz, docx, re, requests, json
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ----------- CONFIG -----------
base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
jd_dir = os.path.join(base_path, "JDs")
raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
raw_resume_dir = os.path.join(base_path, "raw_extracted")
ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
output_dir = os.path.join(base_path, "LLM_Customised_Resumes")

os.makedirs(raw_resume_dir, exist_ok=True)
os.makedirs(output_dir, exist_ok=True)

# ----------- HELPERS -----------
def extract_zip(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

def read_pdf_text(pdf_path):
    doc = fitz.open(pdf_path)
    return "\n".join([page.get_text() for page in doc])

def read_docx_text(docx_path):
    doc = docx.Document(docx_path)
    return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

def read_resume(path):
    return read_pdf_text(path) if path.endswith(".pdf") else read_docx_text(path)

def get_similarity(text1, text2):
    vec = TfidfVectorizer().fit_transform([text1, text2])
    return cosine_similarity(vec[0:1], vec[1:2])[0][0]

def call_llm_mistral(jd_text, resume_text):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}

    prompt = f"""
You are an AI assistant helping customise resumes to job descriptions. Based on the job description below, rewrite the resume experience bullets to align with the required skills. Rephrase and match the tone accordingly.

Job Description:
{jd_text}

Resume Experience:
{resume_text}

Customised Resume Experience Bullets:
"""

    payload = {
        "model": "mistral-7b-instruct-v0.3-q4_k_m",
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
    }

    response = requests.post(url, headers=headers, data=json.dumps(payload))
    return response.json()["choices"][0]["message"]["content"]

# ----------- MAIN PIPELINE -----------
def customize_all_resumes():
    print("STEP 1: Extracting resumes...")
    extract_zip(raw_resume_zip, raw_resume_dir)
    ey_template = open(ey_format_path, "r", encoding="utf-8").read()

    for root, _, files in os.walk(raw_resume_dir):
        for f in files:
            resume_name = os.path.splitext(f)[0]
            resume_path = os.path.join(root, f)
            resume_text = read_resume(resume_path)

            # STEP 2: Match best JD
            best_jd = None
            best_score = -1
            for jd_file in os.listdir(jd_dir):
                jd_path = os.path.join(jd_dir, jd_file)
                with open(jd_path, "r", encoding="utf-8") as jf:
                    jd_text = jf.read()
                score = get_similarity(resume_text, jd_text)
                if score > best_score:
                    best_score = score
                    best_jd = jd_text
                    best_jd_name = os.path.splitext(jd_file)[0]

            print(f"\n✅ Customizing {resume_name} with best JD match: {best_jd_name} (Score: {best_score:.2f})")

            # STEP 3: LLM Customisation
            rewritten_bullets = call_llm_mistral(best_jd, resume_text)
            final_resume = ey_template.replace("[EXPERIENCE_PLACEHOLDER]", rewritten_bullets)

            # STEP 4: Save
            out_path = os.path.join(output_dir, f"{resume_name}_{best_jd_name}.txt")
            with open(out_path, "w", encoding="utf-8") as outf:
                outf.write(final_resume)
            print(f"💾 Saved: {out_path}")

# ----------- RUN -----------
if __name__ == "__main__":
    customize_all_resumes()
# Out:
# STEP 1: Extracting resumes...
#
# ✅ Customizing Anuska Das with best JD match: JD_52 (Score: 0.49)
# 💾 Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\LLM_Customised_Resumes\Anuska Das_JD_52.txt
#
# ✅ Customizing CV_Aarsh with best JD match: JD_55 (Score: 0.61)
# 💾 Saved: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\LLM_Customised_Resumes\CV_Aarsh_JD_55.txt
#
# ✅ Customizing CV_Arnab Roy_Model_Validation with best JD match: JD_77 (Score: 0.40)

# %%
# import os
# import zipfile
# import fitz  # PyMuPDF
# import docx
# import re
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # --------------------- CONFIGURATION ---------------------

# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
# jd_output_dir = os.path.join(base_path, "JDs")
# manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")
# manual_resume_dir = os.path.join(base_path, "manualcustomisedresumes")
# raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
# raw_resume_dir = os.path.join(base_path, "rawresumes")
# ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
# customised_output_dir = os.path.join(base_path, "LLM_Customised_Resumes_Anuska")
# logs_dir = os.path.join(base_path, "logs_anuska")

# # Target candidate to process
# target_name = "Anuska Das"

# for folder in [manual_resume_dir, raw_resume_dir, customised_output_dir, logs_dir]:
#     os.makedirs(folder, exist_ok=True)

# # --------------------- UTILS ---------------------

# def extract_zip(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx_text(docx_path):
#     doc = docx.Document(docx_path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf_text(path)
#     elif path.endswith(".docx"):
#         return read_docx_text(path)
#     else:
#         return ""

# def get_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def customize_resume(raw_text, jd_text, ey_template):
#     raw_sentences = raw_text.split(". ")
#     matched = []
#     for sentence in raw_sentences:
#         score = get_similarity(sentence, jd_text)
#         if score > 0.15:
#             matched.append(sentence.strip())
#     final_experience = "\n".join(matched).strip()
#     return ey_template.replace("[EXPERIENCE_PLACEHOLDER]", final_experience)

# # --------------------- MAIN PIPELINE ---------------------

# def customise_anuska_resumes():
#     print("STEP 1: Extracting Resumes...")
#     extract_zip(raw_resume_zip, raw_resume_dir)
#     extract_zip(manual_resume_zip, manual_resume_dir)

#     ey_template = open(ey_format_path, "r", encoding="utf-8").read()

#     # Filter raw resumes for Anuska
#     raw_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(raw_resume_dir)
#         for f in files
#         if target_name.lower() in f.lower()
#     }

#     manual_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(manual_resume_dir)
#         for f in files
#         if target_name.lower() in f.lower()
#     }

#     if not raw_resumes:
#         print("No raw resume found for Anuska Das.")
#         return

#     print("STEP 2: Matching JDs to Anuska's raw resume...")
#     for jd_file in sorted(os.listdir(jd_output_dir)):
#         jd_index = os.path.splitext(jd_file)[0].split("_")[1]
#         jd_path = os.path.join(jd_output_dir, jd_file)
#         jd_text = open(jd_path, "r", encoding="utf-8").read()

#         for raw_name, raw_text in raw_resumes.items():
#             customised = customize_resume(raw_text, jd_text, ey_template)
#             output_path = os.path.join(customised_output_dir, f"{raw_name}_JD_{jd_index}.txt")
#             with open(output_path, "w", encoding="utf-8") as f:
#                 f.write(customised)

#             # Compare with Anuska's manual resume
#             match_key = next((k for k in manual_resumes if raw_name.lower() in k.lower()), None)
#             if match_key:
#                 manual_text = manual_resumes[match_key]
#                 score = get_similarity(customised, manual_text)
#                 log = f"{raw_name}_JD_{jd_index}: Similarity Score = {score:.2f}"
#                 print(log)
#                 with open(os.path.join(logs_dir, f"log_JD_{jd_index}.txt"), "a", encoding="utf-8") as logf:
#                     logf.write(log + "\n")

# # --------------------- RUN ---------------------

# if __name__ == "__main__":
#     customise_anuska_resumes()
# Out:
# STEP 1: Extracting Resumes...
# STEP 2: Matching JDs to Anuska's raw resume...
# Anuska Das_JD_1: Similarity Score = 0.00
# Anuska Das_JD_10: Similarity Score = 0.00
# Anuska Das_JD_100: Similarity Score = 0.00
# Anuska Das_JD_101: Similarity Score = 0.00
# Anuska Das_JD_102: Similarity Score = 0.00
# Anuska Das_JD_103: Similarity Score = 0.00
# Anuska Das_JD_104: Similarity Score = 0.00
# Anuska Das_JD_105: Similarity Score = 0.00
# Anuska Das_JD_106: Similarity Score = 0.00
# Anuska Das_JD_107: Similarity Score = 0.00
# Anuska Das_JD_108: Similarity Score = 0.00
# Anuska Das_JD_109: Similarity Score = 0.00
# Anuska Das_JD_11: Similarity Score = 0.00
# Anuska Das_JD_110: Similarity Score = 0.00
# Anuska Das_JD_111: Similarity Score = 0.00
# Anuska Das_JD_112: Similarity Score = 0.00
# Anuska Das_JD_113: Similarity Score = 0.00
# Anuska Das_JD_114: Similarity Score = 0.00
# Anuska Das_JD_115: Similarity Score = 0.00
# Anuska Das_JD_116: Similarity Score = 0.00
# Anuska Das_JD_117: Similarity Score = 0.00
# Anuska Das_JD_118: Similarity Score = 0.00
# Anuska Das_JD_119: Similarity Score = 0.00
# Anuska Das_JD_12: Similarity Score = 0.00
# Anuska Das_JD_120: Similarity Score = 0.00
# Anuska Das_JD_121: Similarity Score = 0.00
# Anuska Das_JD_123: Similarity Score = 0.00
# Anuska Das_JD_124: Similarity Score = 0.00
# Anuska Das_JD_125: Similarity Score = 0.00
# Anuska Das_JD_126: Similarity Score = 0.00
# Anuska Das_JD_127: Similarity Score = 0.00
# Anuska Das_JD_129: Similarity Score = 0.00
# Anuska Das_JD_13: Similarity Score = 0.00
# Anuska Das_JD_130: Similarity Score = 0.00
# Anuska Das_JD_131: Similarity Score = 0.00
# Anuska Das_JD_132: Similarity Score = 0.00
# Anuska Das_JD_134: Similarity Score = 0.00
# Anuska Das_JD_135: Similarity Score = 0.00
# Anuska Das_JD_136: Similarity Score = 0.00
# Anuska Das_JD_137: Similarity Score = 0.00
# Anuska Das_JD_138: Similarity Score = 0.00
# Anuska Das_JD_139: Similarity Score = 0.00
# Anuska Das_JD_14: Similarity Score = 0.00
# Anuska Das_JD_140: Similarity Score = 0.00
# Anuska Das_JD_141: Similarity Score = 0.00
# Anuska Das_JD_142: Similarity Score = 0.00
# Anuska Das_JD_143: Similarity Score = 0.00
# Anuska Das_JD_144: Similarity Score = 0.00
# Anuska Das_JD_15: Similarity Score = 0.00
# Anuska Das_JD_16: Similarity Score = 0.00
# Anuska Das_JD_17: Similarity Score = 0.00
# Anuska Das_JD_18: Similarity Score = 0.00
# Anuska Das_JD_19: Similarity Score = 0.00
# Anuska Das_JD_2: Similarity Score = 0.00
# Anuska Das_JD_20: Similarity Score = 0.00
# Anuska Das_JD_21: Similarity Score = 0.00
# Anuska Das_JD_22: Similarity Score = 0.00
# Anuska Das_JD_23: Similarity Score = 0.00
# Anuska Das_JD_24: Similarity Score = 0.00
# Anuska Das_JD_25: Similarity Score = 0.00
# Anuska Das_JD_26: Similarity Score = 0.00
# Anuska Das_JD_27: Similarity Score = 0.00
# Anuska Das_JD_28: Similarity Score = 0.00
# Anuska Das_JD_29: Similarity Score = 0.00
# Anuska Das_JD_3: Similarity Score = 0.00
# Anuska Das_JD_30: Similarity Score = 0.00
# Anuska Das_JD_31: Similarity Score = 0.00
# Anuska Das_JD_32: Similarity Score = 0.00
# Anuska Das_JD_33: Similarity Score = 0.00
# Anuska Das_JD_34: Similarity Score = 0.00
# Anuska Das_JD_35: Similarity Score = 0.00
# Anuska Das_JD_36: Similarity Score = 0.00
# Anuska Das_JD_37: Similarity Score = 0.00
# Anuska Das_JD_38: Similarity Score = 0.00
# Anuska Das_JD_39: Similarity Score = 0.00
# Anuska Das_JD_4: Similarity Score = 0.00
# Anuska Das_JD_40: Similarity Score = 0.00
# Anuska Das_JD_41: Similarity Score = 0.00
# Anuska Das_JD_42: Similarity Score = 0.00
# Anuska Das_JD_43: Similarity Score = 0.00
# Anuska Das_JD_44: Similarity Score = 0.00
# Anuska Das_JD_45: Similarity Score = 0.00
# Anuska Das_JD_46: Similarity Score = 0.00
# Anuska Das_JD_47: Similarity Score = 0.00
# Anuska Das_JD_48: Similarity Score = 0.00
# Anuska Das_JD_5: Similarity Score = 0.00
# Anuska Das_JD_50: Similarity Score = 0.00
# Anuska Das_JD_52: Similarity Score = 0.00
# Anuska Das_JD_53: Similarity Score = 0.00
# Anuska Das_JD_54: Similarity Score = 0.00
# Anuska Das_JD_55: Similarity Score = 0.00
# Anuska Das_JD_56: Similarity Score = 0.00
# Anuska Das_JD_57: Similarity Score = 0.00
# Anuska Das_JD_58: Similarity Score = 0.00
# Anuska Das_JD_59: Similarity Score = 0.00
# Anuska Das_JD_6: Similarity Score = 0.00
# Anuska Das_JD_60: Similarity Score = 0.00
# Anuska Das_JD_61: Similarity Score = 0.00
# Anuska Das_JD_62: Similarity Score = 0.00
# Anuska Das_JD_64: Similarity Score = 0.00
# Anuska Das_JD_65: Similarity Score = 0.00
# Anuska Das_JD_67: Similarity Score = 0.00
# Anuska Das_JD_68: Similarity Score = 0.00
# Anuska Das_JD_69: Similarity Score = 0.00
# Anuska Das_JD_7: Similarity Score = 0.00
# Anuska Das_JD_70: Similarity Score = 0.00
# Anuska Das_JD_71: Similarity Score = 0.00
# Anuska Das_JD_72: Similarity Score = 0.00
# Anuska Das_JD_73: Similarity Score = 0.00
# Anuska Das_JD_74: Similarity Score = 0.00
# Anuska Das_JD_75: Similarity Score = 0.00
# Anuska Das_JD_76: Similarity Score = 0.00
# Anuska Das_JD_77: Similarity Score = 0.00
# Anuska Das_JD_78: Similarity Score = 0.00
# Anuska Das_JD_79: Similarity Score = 0.00
# Anuska Das_JD_80: Similarity Score = 0.00
# Anuska Das_JD_81: Similarity Score = 0.00
# Anuska Das_JD_82: Similarity Score = 0.00
# Anuska Das_JD_83: Similarity Score = 0.00
# Anuska Das_JD_84: Similarity Score = 0.00
# Anuska Das_JD_85: Similarity Score = 0.00
# Anuska Das_JD_86: Similarity Score = 0.00
# Anuska Das_JD_87: Similarity Score = 0.00
# Anuska Das_JD_88: Similarity Score = 0.00
# Anuska Das_JD_89: Similarity Score = 0.00
# Anuska Das_JD_9: Similarity Score = 0.00
# Anuska Das_JD_90: Similarity Score = 0.00
# Anuska Das_JD_91: Similarity Score = 0.00
# Anuska Das_JD_92: Similarity Score = 0.00
# Anuska Das_JD_93: Similarity Score = 0.00
# Anuska Das_JD_94: Similarity Score = 0.00
# Anuska Das_JD_95: Similarity Score = 0.00
# Anuska Das_JD_96: Similarity Score = 0.00
# Anuska Das_JD_97: Similarity Score = 0.00
# Anuska Das_JD_98: Similarity Score = 0.00
# Anuska Das_JD_99: Similarity Score = 0.00

# %%
# import os
# import zipfile
# import re
# import fitz  # PyMuPDF
# import docx
# import requests
# import json
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # ---------------- CONFIG ----------------
# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
# jd_dir = os.path.join(base_path, "JDs")
# manual_resume_zip = os.path.join(base_path, "manualcustomisedresumes.zip")
# manual_resume_dir = os.path.join(base_path, "manualcustomisedresumes")
# raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
# raw_resume_dir = os.path.join(base_path, "rawresumes")
# ey_format_path = os.path.join(base_path, "EY_sample_format1.txt")
# customised_output_dir = os.path.join(base_path, "LLM_Customised_Resumes")
# os.makedirs(customised_output_dir, exist_ok=True)

# lmstudio_url = "http://localhost:1234/v1/chat/completions"
# lmstudio_model = "mistral-7b-instruct-v0.3-q4_k_m-gguf"

# # ---------------- UTILS ----------------

# def extract_zip(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf(path)
#     elif path.endswith(".docx"):
#         return read_docx(path)
#     return ""

# def get_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1.lower(), text2.lower()])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def query_lmstudio(prompt):
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": lmstudio_model,
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.5,
#         "stream": False
#     }
#     try:
#         response = requests.post(lmstudio_url, headers=headers, data=json.dumps(payload), timeout=120)
#         return response.json()['choices'][0]['message']['content'].strip()
#     except Exception as e:
#         print(f"LM Studio failed: {e}")
#         return ""

# # ---------------- CORE ----------------

# def extract_skills(text):
#     prompt = f"""Extract all technical and domain-related skills from this resume:
# {text}
# Only return the list of skills as comma-separated values."""
#     return query_lmstudio(prompt)

# def customize_resume(candidate_text, jd_text, ey_template):
#     prompt = f"""Given the following resume content:
# {candidate_text}

# And the following job description:
# {jd_text}

# Extract the relevant experiences from the resume that match the JD. Then, rephrase them professionally to fit into EY format.

# Respond only with the formatted EXPERIENCE section content."""
#     experience = query_lmstudio(prompt)
#     return ey_template.replace("[EXPERIENCE_PLACEHOLDER]", experience)

# # ---------------- PIPELINE ----------------

# def run_pipeline():
#     print("STEP 1: Extracting files...")
#     extract_zip(raw_resume_zip, raw_resume_dir)
#     extract_zip(manual_resume_zip, manual_resume_dir)

#     ey_template = open(ey_format_path, "r", encoding="utf-8").read()

#     jd_files = {os.path.splitext(f)[0]: open(os.path.join(jd_dir, f), "r", encoding="utf-8").read()
#                 for f in os.listdir(jd_dir) if f.endswith(".txt")}

#     print("STEP 2: Processing candidates...")
#     for root, _, files in os.walk(raw_resume_dir):
#         for f in files:
#             candidate_name = os.path.splitext(f)[0]
#             print(f"\nProcessing: {candidate_name}")

#             candidate_path = os.path.join(root, f)
#             raw_text = read_resume(candidate_path)
#             skills_csv = extract_skills(raw_text)
#             print(f"Extracted skills: {skills_csv}")

#             matched_jds = []
#             for jd_name, jd_text in jd_files.items():
#                 match_score = get_similarity(skills_csv, jd_text)
#                 if match_score >= 0.6:
#                     matched_jds.append((jd_name, jd_text))
#             print(f"Matched JDs: {[j[0] for j in matched_jds]}")

#             for jd_name, jd_text in matched_jds:
#                 customised_text = customize_resume(raw_text, jd_text, ey_template)
#                 out_path = os.path.join(customised_output_dir, f"{candidate_name}_JD_{jd_name}.txt")
#                 with open(out_path, "w", encoding="utf-8") as out_f:
#                     out_f.write(customised_text)

# # ---------------- RUN ----------------

# if __name__ == "__main__":
#     run_pipeline()
# Out:
# STEP 1: Extracting files...
# STEP 2: Processing candidates...
#
# Processing: Anuska Das
# Extracted skills: Statistical Analysis, Data analysis (logistic regression, linear regression, random forest, decision trees, credit risk analysis), Regulatory Reporting, Programming languages (SAS, Python, SQL, Excel, VBA, PowerPoint), Machine learning techniques, Primary and secondary market research
# Matched JDs: []
#
# Processing: CV_Aarsh

# %%
# # Load model directly
# from transformers import AutoModel
# model = AutoModel.from_pretrained("TheBloke/zephyr-7B-beta-GGUF")
# Out:
# config.json:   0%|          | 0.00/31.0 [00:00<?, ?B/s]
# c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\HN338QQ\.cache\huggingface\hub\models--TheBloke--zephyr-7B-beta-GGUF. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Load model directly
#       2 from transformers import AutoModel
# ----> 3 model = AutoModel.from_pretrained("TheBloke/zephyr-7B-beta-GGUF")
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\transformers\models\auto\auto_factory.py:600, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     598     if model_class.config_class == config.sub_configs.get("text_config", None):
#     599         config = config.get_text_config()
# --> 600     return model_class.from_pretrained(
#     601         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     602     )
#     603 raise ValueError(
#     604     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     605     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     606 )
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\transformers\modeling_utils.py:311, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     309 old_dtype = torch.get_default_dtype()
#     310 try:
# --> 311     return func(*args, **kwargs)
#     312 finally:
#     313     torch.set_default_dtype(old_dtype)
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\transformers\modeling_utils.py:4674, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4664 if (
#    4665     gguf_file
#    4666     and device_map is not None
#    4667     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4668 ):
#    4669     raise RuntimeError(
#    4670         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4671         "loaded from GGUF files."
#    4672     )
# -> 4674 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4675     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4676     subfolder=subfolder,
#    4677     variant=variant,
#    4678     gguf_file=gguf_file,
#    4679     from_tf=from_tf,
#    4680     from_flax=from_flax,
#    4681     use_safetensors=use_safetensors,
#    4682     cache_dir=cache_dir,
#    4683     force_download=force_download,
#    4684     proxies=proxies,
#    4685     local_files_only=local_files_only,
#    4686     token=token,
#    4687     user_agent=user_agent,
#    4688     revision=revision,
#    4689     commit_hash=commit_hash,
#    4690     is_remote_code=cls._auto_class is not None,
#    4691     transformers_explicit_filename=transformers_explicit_filename,
#    4692 )
#    4694 is_sharded = sharded_metadata is not None
#    4695 is_quantized = hf_quantizer is not None
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\transformers\modeling_utils.py:1243, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash, is_remote_code, transformers_explicit_filename)
#    1237                 raise OSError(
#    1238                     f"{pretrained_model_name_or_path} does not appear to have a file named"
#    1239                     f" {_add_variant(WEIGHTS_NAME, variant)} but there is a file without the variant"
#    1240                     f" {variant}. Use `variant=None` to load this model from those weights."
#    1241                 )
#    1242             else:
# -> 1243                 raise OSError(
#    1244                     f"{pretrained_model_name_or_path} does not appear to have a file named"
#    1245                     f" {_add_variant(WEIGHTS_NAME, variant)}, {_add_variant(SAFE_WEIGHTS_NAME, variant)},"
#    1246                     f" {TF2_WEIGHTS_NAME}, {TF_WEIGHTS_NAME} or {FLAX_WEIGHTS_NAME}."
#    1247                 )
#    1249 except OSError:
#    1250     # Raise any environment error raise by `cached_file`. It will have a helpful error message adapted
#    1251     # to the original exception.
#    1252     raise
#
# OSError: TheBloke/zephyr-7B-beta-GGUF does not appear to have a file named pytorch_model.bin, model.safetensors, tf_model.h5, model.ckpt or flax_model.msgpack.

# %%
# import os
# import zipfile
# import fitz  # PyMuPDF
# import docx
# import re
# import json
# import time
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # -------------------- CONFIG --------------------
# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"

# raw_resume_zip = os.path.join(base_path, "Rawresumes.zip")
# jd_zip = os.path.join(base_path, "JDs.zip")
# ey_template_path = os.path.join(base_path, "EY_sample_resume_template.txt")

# raw_resume_dir = os.path.join(base_path, "rawresumes")
# jd_dir = os.path.join(base_path, "JDs")
# customised_dir = os.path.join(base_path, "final_customised_resumes")

# for folder in [raw_resume_dir, jd_dir, customised_dir]:
#     os.makedirs(folder, exist_ok=True)

# # -------------------- UTILITIES --------------------
# def extract_zip(zip_path, extract_to):
#     with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#         zip_ref.extractall(extract_to)

# def read_pdf_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx_text(docx_path):
#     doc = docx.Document(docx_path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf_text(path)
#     elif path.endswith(".docx"):
#         return read_docx_text(path)
#     elif path.endswith(".txt"):
#         return open(path, "r", encoding="utf-8").read()
#     else:
#         return ""

# def get_tfidf_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
#     url = "http://localhost:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": model,
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.7,
#         "stream": False
#     }
#     for attempt in range(retries):
#         try:
#             response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
#             return response.json()['choices'][0]['message']['content']
#         except Exception as e:
#             if attempt == retries - 1:
#                 print("❌ LM Studio failed:", e)
#                 return ""
#             time.sleep(2)

# # -------------------- MAIN PIPELINE --------------------
# def process():
#     print("STEP 1: Extracting files...")
#     extract_zip(raw_resume_zip, raw_resume_dir)
#     extract_zip(jd_zip, jd_dir)

#     print("STEP 2: Loading resumes and JDs...")
#     ey_template = open(ey_template_path, "r", encoding="utf-8").read()

#     raw_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(raw_resume_dir)
#         for f in files
#     }

#     jd_texts = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(jd_dir)
#         for f in files
#     }

#     print("STEP 3: Matching resumes with best JD + Customizing...")
#     for candidate, resume_text in raw_resumes.items():
#         best_jd = ""
#         best_score = 0
#         for jd_name, jd_text in jd_texts.items():
#             score = get_tfidf_similarity(resume_text.lower(), jd_text.lower())
#             if score > best_score:
#                 best_score = score
#                 best_jd = jd_name

#         if best_jd == "":
#             print(f"No match found for {candidate}")
#             continue

#         print(f"→ Customizing {candidate} with JD: {best_jd} (Score: {best_score:.2f})")

#         jd_content = jd_texts[best_jd]

#         # Build the main prompt for all sections
#         prompt = f"""
# You are a resume writing assistant. Using the candidate's raw resume and the JD below, extract and rewrite the following sections:

# 1. SUMMARY: Write a 2–3 line summary tailored to the JD.
# 2. QUALIFICATIONS: Extract degrees and colleges, nicely formatted.
# 3. EXPERIENCE: Rewrite to reflect JD language, tone, and skills.
# 4. TECHNICAL_SKILLS: List relevant tools and technical expertise.

# --- RAW RESUME ---
# {resume_text}

# --- JOB DESCRIPTION ---
# {jd_content}

# Now provide the following output with exact labels:

# SUMMARY:
# ...

# QUALIFICATIONS:
# ...

# EXPERIENCE:
# ...

# TECHNICAL_SKILLS:
# ...
# """

#         result = call_lmstudio(prompt)
#         if not result:
#             continue

#         # Extract each block from the LLM output
#         summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
#         qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
#         experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
#         tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

#         final_resume = ey_template
#         final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate)
#         final_resume = final_resume.replace("[ROLE]", best_jd.replace("_", " "))
#         final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
#         final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
#         final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
#         final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

#         out_path = os.path.join(customised_dir, f"{candidate}_customised_for_{best_jd}.txt")
#         with open(out_path, "w", encoding="utf-8") as f:
#             f.write(final_resume)

#     print("\n✅ Customisation completed. Check:", customised_dir)

# # -------------------- EXECUTE --------------------
# if __name__ == "__main__":
#     process()
# Out:
# STEP 1: Extracting files...
# STEP 2: Loading resumes and JDs...
# STEP 3: Matching resumes with best JD + Customizing...
# → Customizing Anuska Das with JD: JD_52 (Score: 0.49)
# → Customizing CV_Aarsh with JD: JD_55 (Score: 0.61)
# → Customizing CV_Arnab Roy_Model_Validation with JD: JD_77 (Score: 0.40)
# → Customizing G N Sindhur_resume_2025 with JD: JD_23 (Score: 0.61)
# ❌ LM Studio failed: HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# → Customizing Isha Porwal Resume with JD: JD_58 (Score: 0.54)
# → Customizing KartikMohan with JD: JD_55 (Score: 0.61)
# → Customizing Kshitij_Sahdev_CV (002) with JD: JD_110 (Score: 0.57)
# → Customizing Kundan_Kumar with JD: JD_115 (Score: 0.66)
# → Customizing Munna Choudhary with JD: JD_100 (Score: 0.68)
# → Customizing Narendra_Sahu_CreditRisk with JD: JD_75 (Score: 0.55)
# → Customizing Naukri_AbhimanyuSingh[3y_7m] with JD: JD_111 (Score: 0.55)
# → Customizing Naukri_AnandKumar[10y_0m] with JD: JD_55 (Score: 0.47)
# → Customizing Naukri_DEBSUBHRAGHOSH[7y_0m] with JD: JD_111 (Score: 0.55)
# → Customizing Naukri_GirishKhandelwal[11y_0m] with JD: JD_55 (Score: 0.70)

# %%
# import os
# import fitz  # PyMuPDF
# import docx
# import re
# import json
# import time
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # -------------------- CONFIG --------------------
# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"

# raw_resume_dir = os.path.join(base_path, "Rawresumes")
# jd_dir = os.path.join(base_path, "JDs")
# ey_template_path = os.path.join(base_path, "EY_sample_resume_template.txt")
# customised_dir = os.path.join(base_path, "final_customised_resumes")

# os.makedirs(customised_dir, exist_ok=True)

# # -------------------- UTILITIES --------------------
# def read_pdf_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     return "\n".join([page.get_text() for page in doc])

# def read_docx_text(docx_path):
#     doc = docx.Document(docx_path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf_text(path)
#     elif path.endswith(".docx"):
#         return read_docx_text(path)
#     elif path.endswith(".txt"):
#         return open(path, "r", encoding="utf-8").read()
#     else:
#         return ""

# def get_tfidf_similarity(text1, text2):
#     vectorizer = TfidfVectorizer().fit_transform([text1, text2])
#     vectors = vectorizer.toarray()
#     return cosine_similarity([vectors[0]], [vectors[1]])[0][0]

# def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
#     url = "http://localhost:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": model,
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.7,
#         "stream": False
#     }
#     for attempt in range(retries):
#         try:
#             response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
#             return response.json()['choices'][0]['message']['content']
#         except Exception as e:
#             if attempt == retries - 1:
#                 print("❌ LM Studio failed:", e)
#                 return ""
#             time.sleep(2)

# # -------------------- MAIN PIPELINE --------------------
# def process():
#     print("STEP 1: Loading resumes and JDs...")
#     ey_template = open(ey_template_path, "r", encoding="utf-8").read()

#     raw_resumes = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(raw_resume_dir)
#         for f in files
#     }

#     jd_texts = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(root, f))
#         for root, _, files in os.walk(jd_dir)
#         for f in files
#     }

#     print("STEP 2: Matching resumes with best JD + Customizing...")
#     for candidate, resume_text in raw_resumes.items():
#         best_jd = ""
#         best_score = 0
#         for jd_name, jd_text in jd_texts.items():
#             score = get_tfidf_similarity(resume_text.lower(), jd_text.lower())
#             if score > best_score:
#                 best_score = score
#                 best_jd = jd_name

#         if best_jd == "":
#             print(f"❌ No JD match found for {candidate}")
#             continue

#         print(f"→ Customizing {candidate} with JD: {best_jd} (Score: {best_score:.2f})")
#         jd_content = jd_texts[best_jd]

#         prompt = f"""
# You are a resume writing assistant. Using the candidate's raw resume and the JD below, extract and rewrite the following sections:

# 1. SUMMARY: Write a 2–3 line summary tailored to the JD.
# 2. QUALIFICATIONS: Extract degrees and colleges, nicely formatted.
# 3. EXPERIENCE: Rewrite to reflect JD language, tone, and skills.
# 4. TECHNICAL_SKILLS: List relevant tools and technical expertise.

# --- RAW RESUME ---
# {resume_text}

# --- JOB DESCRIPTION ---
# {jd_content}

# Now provide the following output with exact labels:

# SUMMARY:
# ...

# QUALIFICATIONS:
# ...

# EXPERIENCE:
# ...

# TECHNICAL_SKILLS:
# ...
# """
#         result = call_lmstudio(prompt)
#         if not result:
#             continue

#         # Extract sections
#         summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
#         qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
#         experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
#         tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

#         final_resume = ey_template
#         final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate)
#         final_resume = final_resume.replace("[ROLE]", best_jd.replace("_", " "))
#         final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
#         final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
#         final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
#         final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

#         out_path = os.path.join(customised_dir, f"{candidate}_customised_for_{best_jd}.txt")
#         with open(out_path, "w", encoding="utf-8") as f:
#             f.write(final_resume)

#     print("\n✅ Customisation completed. Check:", customised_dir)

# # -------------------- EXECUTE --------------------
# if __name__ == "__main__":
#     process()
# Out:
# STEP 1: Loading resumes and JDs...
# STEP 2: Matching resumes with best JD + Customizing...
# → Customizing Anuska Das with JD: JD_52 (Score: 0.49)
# → Customizing CV_Aarsh with JD: JD_55 (Score: 0.61)
# → Customizing CV_Arnab Roy_Model_Validation with JD: JD_77 (Score: 0.40)
# → Customizing G N Sindhur_resume_2025 with JD: JD_23 (Score: 0.61)
# → Customizing Isha Porwal Resume with JD: JD_58 (Score: 0.54)

# %%
# import os
# import re
# import json
# import time
# import fitz  # PyMuPDF
# import docx
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # -------------------- CONFIG --------------------
# base_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples"
# raw_resume_dir = os.path.join(base_path, "Rawresumes")
# jd_dir = os.path.join(base_path, "JDs")
# template_path = os.path.join(base_path, "EY_sample_resume_template.txt")
# customised_dir = os.path.join(base_path, "final_customised_resumes")
# os.makedirs(customised_dir, exist_ok=True)

# # -------------------- UTILITIES --------------------
# def read_pdf(path):
#     doc = fitz.open(path)
#     return "\n".join(page.get_text() for page in doc)

# def read_docx(path):
#     doc = docx.Document(path)
#     return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])

# def read_resume(path):
#     if path.endswith(".pdf"):
#         return read_pdf(path)
#     elif path.endswith(".docx"):
#         return read_docx(path)
#     elif path.endswith(".txt"):
#         return open(path, "r", encoding="utf-8").read()
#     else:
#         return ""

# def get_tfidf_similarity(text1, text2):
#     vec = TfidfVectorizer().fit_transform([text1, text2])
#     return cosine_similarity(vec[0:1], vec[1:2])[0][0]

# def call_zephyr(prompt, model="zephyr-7b-beta.Q4_K_M.gguf"):
#     url = "http://localhost:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": model,
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.7,
#         "stream": False
#     }
#     try:
#         res = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
#         return res.json()["choices"][0]["message"]["content"]
#     except Exception as e:
#         print("❌ Error in Zephyr call:", e)
#         return ""

# # -------------------- MAIN FUNCTION --------------------
# def customise_resume(frontend_prompt: str, uploaded_resume_path: str):
#     print("🚀 Starting resume customization...")

#     # Step 1: Synthesize JD using Zephyr from prompt
#     synth_jd_prompt = f"""Write a clear and structured job description for the following role prompt:

# PROMPT: {frontend_prompt}

# Make sure to include responsibilities, required skills, and qualifications."""
#     generated_jd = call_zephyr(synth_jd_prompt)
#     print("✅ JD created using Zephyr")

#     # Step 2: Read uploaded resume
#     candidate_name = os.path.splitext(os.path.basename(uploaded_resume_path))[0]
#     resume_text = read_resume(uploaded_resume_path)
#     if not resume_text.strip():
#         print("❌ Resume text is empty.")
#         return

#     # Step 3: Load JD and resume corpus for similarity matching
#     jd_texts = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(jd_dir, f))
#         for f in os.listdir(jd_dir)
#         if f.endswith((".pdf", ".docx", ".txt"))
#     }
#     resume_texts = {
#         os.path.splitext(f)[0]: read_resume(os.path.join(raw_resume_dir, f))
#         for f in os.listdir(raw_resume_dir)
#         if f.endswith((".pdf", ".docx", ".txt"))
#     }

#     # Step 4: Find top matching JD from JD folder (optional, enrich context)
#     best_jd = ""
#     best_score = 0
#     for name, text in jd_texts.items():
#         score = get_tfidf_similarity(generated_jd.lower(), text.lower())
#         if score > best_score:
#             best_score = score
#             best_jd = text
#     combined_jd = generated_jd + "\n\n" + (best_jd if best_jd else "")

#     # Step 5: Ask Zephyr to customize resume
#     customise_prompt = f"""
# You are a professional resume writing assistant.

# Given the raw resume and JD below, rewrite the following sections:

# 1. SUMMARY
# 2. QUALIFICATIONS
# 3. EXPERIENCE
# 4. TECHNICAL_SKILLS

# --- RAW RESUME ---
# {resume_text}

# --- JOB DESCRIPTION ---
# {combined_jd}

# Now format output like:

# SUMMARY:
# ...

# QUALIFICATIONS:
# ...

# EXPERIENCE:
# ...

# TECHNICAL_SKILLS:
# ...
# """
#     result = call_zephyr(customise_prompt)
#     print("✅ Resume customized")

#     # Step 6: Extract sections using regex
#     summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
#     qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
#     experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
#     tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

#     # Step 7: Fill into EY template
#     template = open(template_path, "r", encoding="utf-8").read()
#     filled_resume = template
#     filled_resume = filled_resume.replace("[CANDIDATE_NAME]", candidate_name)
#     filled_resume = filled_resume.replace("[ROLE]", frontend_prompt)
#     filled_resume = filled_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
#     filled_resume = filled_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
#     filled_resume = filled_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
#     filled_resume = filled_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

#     # Step 8: Save the file
#     output_path = os.path.join(customised_dir, f"{candidate_name}_customised_resume.txt")
#     with open(output_path, "w", encoding="utf-8") as f:
#         f.write(filled_resume)

#     print(f"✅ Customised resume saved to: {output_path}")

# %%
# # Example frontend inputs
# frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
# uploaded_resume_path = r"C:\Users\HN338QQ\Downloads\Arnab Bhattacharya.pdf"

# customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# 🚀 Starting resume customization...
# ✅ JD created using Zephyr
# ❌ Error in Zephyr call: HTTPConnectionPool(host='localhost', port=1234): Read timed out. (read timeout=180)
# ✅ Resume customized
# ✅ Customised resume saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Arnab Bhattacharya_customised_resume.txt

# %%
# import os
# import fitz  # PyMuPDF
# import requests

# # === Constants ===
# LM_API_URL = "http://127.0.0.1:1234/v1/chat/completions"
# MODEL_NAME = "thebloke_zephyr-7b-beta:2"

# # === Utility Functions ===

# def read_pdf_text(pdf_path):
#     text = ""
#     with fitz.open(pdf_path) as doc:
#         for page in doc:
#             text += page.get_text()
#     return text.strip()

# def call_zephyr(prompt):
#     payload = {
#         "model": MODEL_NAME,
#         "messages": [
#             {"role": "user", "content": prompt}
#         ],
#         "temperature": 0.7
#     }
#     try:
#         response = requests.post(LM_API_URL, json=payload, timeout=300)
#         response.raise_for_status()
#         return response.json()["choices"][0]["message"]["content"].strip()
#     except Exception as e:
#         print(f"❌ Error in Zephyr LLM call: {e}")
#         return None

# def merge_resume_with_jd(resume_text, jd_text):
#     # A simple formatted template — can be modified
#     customised_resume = f"""
# ========================
# CUSTOMISED RESUME
# ========================

# SUMMARY:
# {jd_text.split('SUMMARY:')[1].split('QUALIFICATIONS:')[0].strip() if 'SUMMARY:' in jd_text else ''}

# QUALIFICATIONS:
# {jd_text.split('QUALIFICATIONS:')[1].split('EXPERIENCE:')[0].strip() if 'QUALIFICATIONS:' in jd_text else ''}

# EXPERIENCE:
# {jd_text.split('EXPERIENCE:')[1].split('TECHNICAL_SKILLS:')[0].strip() if 'EXPERIENCE:' in jd_text else ''}

# TECHNICAL SKILLS:
# {jd_text.split('TECHNICAL_SKILLS:')[1].strip() if 'TECHNICAL_SKILLS:' in jd_text else ''}

# ========================
# ORIGINAL RESUME TEXT (Reference)
# ========================
# {resume_text}
# """
#     return customised_resume

# def save_customised_resume(resume_text, output_path):
#     with open(output_path, "w", encoding="utf-8") as f:
#         f.write(resume_text)
#     print(f"✅ Customised resume saved to: {output_path}")

# # === Main Customisation Function ===

# def customise_resume(frontend_prompt, uploaded_resume_path):
#     # Step 1: Read resume
#     resume_text = read_pdf_text(uploaded_resume_path)

#     # Step 2: Generate JD from prompt via Zephyr
#     generated_jd = call_zephyr(frontend_prompt)
#     if not generated_jd:
#         print("❌ JD generation failed. Exiting.")
#         return

#     # Step 3: Customise resume
#     final_resume = merge_resume_with_jd(resume_text, generated_jd)

#     # Step 4: Save customised resume
#     base_name = os.path.splitext(os.path.basename(uploaded_resume_path))[0]
#     output_path = f"{base_name}_customised_resume.txt"
#     save_customised_resume(final_resume, output_path)

#     return output_path

# %%
# frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
# uploaded_resume_path = r"C:\Users\HN338QQ\Downloads\Arnab Bhattacharya.pdf"

# customised_path = customise_resume(frontend_prompt, uploaded_resume_path)
# print("📄 Customised Resume Path:", customised_path)
# Out:
# ✅ Customised resume saved to: Arnab Bhattacharya_customised_resume.txt
# 📄 Customised Resume Path: Arnab Bhattacharya_customised_resume.txt

# %%
# import os
# import fitz  # PyMuPDF
# import re
# import json
# import time
# import requests
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # -------------------- CONFIG --------------------
# EY_TEMPLATE_PATH = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
# RAW_RESUMES_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes"
# JDS_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\JDs"
# CUSTOMISED_DIR = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
# os.makedirs(CUSTOMISED_DIR, exist_ok=True)

# # -------------------- UTILITIES --------------------
# def read_pdf_text(pdf_path):
#     doc = fitz.open(pdf_path)
#     return "\n".join([page.get_text() for page in doc])

# def call_lmstudio(prompt, model="thebloke_zephyr-7b-beta:2", retries=3):
#     url = "http://localhost:1234/v1/chat/completions"
#     headers = {"Content-Type": "application/json"}
#     payload = {
#         "model": model,
#         "messages": [{"role": "user", "content": prompt}],
#         "temperature": 0.7,
#         "stream": False
#     }
#     for attempt in range(retries):
#         try:
#             response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=120)
#             return response.json()['choices'][0]['message']['content']
#         except Exception as e:
#             if attempt == retries - 1:
#                 print("❌ LM Studio failed:", e)
#                 return ""
#             time.sleep(2)

# # -------------------- MAIN FUNCTION --------------------
# def customise_resume(frontend_prompt, uploaded_resume_path):
#     print("STEP 1: Reading uploaded resume and sample template...")
#     resume_text = read_pdf_text(uploaded_resume_path)
#     with open(EY_TEMPLATE_PATH, "r", encoding="utf-8") as f:
#         ey_template = f.read()

#     print("STEP 2: Generating JD using prompt...")
#     jd_prompt = f"""You are a recruiter assistant. Write a detailed job description based on this prompt:

# \"\"\"{frontend_prompt}\"\"\"

# Provide a structured JD suitable for candidates."""
#     jd_generated = call_lmstudio(jd_prompt)
#     if not jd_generated.strip():
#         print("❌ JD generation failed.")
#         return

#     print("STEP 3: Customising resume with resume + JD...")
#     prompt = f"""
# You are a resume assistant. Given the candidate's resume and the JD below, rewrite and extract the following sections tailored to the JD:

# 1. SUMMARY: Write a 2–3 line summary aligned to the JD.
# 2. QUALIFICATIONS: Extract degrees, universities.
# 3. EXPERIENCE: Rewrite based on JD tone and keywords.
# 4. TECHNICAL_SKILLS: Highlight relevant tools/skills.

# --- RESUME ---
# {resume_text}

# --- JD ---
# {jd_generated}

# Respond ONLY in the following format:

# SUMMARY:
# ...

# QUALIFICATIONS:
# ...

# EXPERIENCE:
# ...

# TECHNICAL_SKILLS:
# ...
# """
#     result = call_lmstudio(prompt)
#     if not result.strip():
#         print("❌ Resume customisation failed.")
#         return

#     summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
#     qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
#     experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
#     tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

#     # Fill into template
#     candidate_name = os.path.splitext(os.path.basename(uploaded_resume_path))[0]
#     final_resume = ey_template
#     final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
#     final_resume = final_resume.replace("[ROLE]", frontend_prompt)
#     final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
#     final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
#     final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
#     final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

#     # Save
#     output_filename = f"{candidate_name}_customised_resume.txt"
#     output_path = os.path.join(CUSTOMISED_DIR, output_filename)
#     with open(output_path, "w", encoding="utf-8") as f:
#         f.write(final_resume)

#     print(f"\n✅ Resume customised and saved to:\n{output_path}")

# %%
# frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
# uploaded_resume_path = r"C:\Users\HN338QQ\Downloads\Arnab Bhattacharya.pdf"

# customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# STEP 1: Reading uploaded resume and sample template...
# STEP 2: Generating JD using prompt...
# STEP 3: Customising resume with resume + JD...
#
# ✅ Resume customised and saved to:
# C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Arnab Bhattacharya_customised_resume.txt

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resume.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\Downloads\Arnab Bhattacharya.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\Downloads\Arnab Bhattacharya.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Arnab Bhattacharya_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Arnab Bhattacharya_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\Downloads\Archit_Resume.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\Downloads\Archit_Resume.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Archit_Resume_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Archit_Resume_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\1. CV - Karishma Rathi.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\1. CV - Karishma Rathi.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\1. CV - Karishma Rathi_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\1. CV - Karishma Rathi_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\20250123_Raja Saha (Manager at Citi).pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\20250123_Raja Saha (Manager at Citi).pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\20250123_Raja Saha (Manager at Citi)_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\20250123_Raja Saha (Manager at Citi)_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarti Chaba.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarti Chaba.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Aarti Chaba_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Aarti Chaba_customised_resume.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumeaarti1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarti Chaba.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarti Chaba.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Aarti Chaba_customised_resumeaarti1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Aarti Chaba_customised_resumeaarti1.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarushi_Vohra.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Aarushi_Vohra.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Aarushi_Vohra_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Aarushi_Vohra_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\AbhiGoswami(Insightsquared).pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\AbhiGoswami(Insightsquared).pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\AbhiGoswami(Insightsquared)_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\AbhiGoswami(Insightsquared)_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Abhishek_Agrahari_CreditRiskModelling-1.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Abhishek_Agrahari_CreditRiskModelling-1.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Abhishek_Agrahari_CreditRiskModelling-1_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Abhishek_Agrahari_CreditRiskModelling-1_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Abir_Sarkar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Abir_Sarkar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Abir_Sarkar_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Abir_Sarkar_customised_resume.txt'

# %%
frontend_prompt = "Create a JD for a retail Scorecards model development requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail Scorecards model development requirement. Mention that SAS is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Nidhika-Tomar_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Nidhika-Tomar_customised_resume.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumenidhika1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
# ---- EXAMPLE FRONTEND USAGE ----
frontend_prompt = "Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must."
# Path to the uploaded resume from the frontend
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf"

# ---- RUN FUNCTION ----
customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must.
# Generated JD:
#   "Job Title: Retail Scorecards Model Development Specialist
#
# Job Description:
# We are seeking a talented and experienced Model Development Specialist to join our team in creating Retail Scorecards utilizing SQL as the primary programming language. The ideal candidate will have a strong background in data science, statistics, and database management, with a focus on developing predictive models for retail operations.
#
# The role involves working closely with other teams in the company to gather and analyze large amounts of data, creating and testing models using SQL, and providing valuable insights and recommendations based on the results. The Model Development Specialist will also be responsible for ensuring that all models developed are accurate, reliable, and easy to interpret.
#
# Additional responsibilities include:
# - Working with cross-functional teams to identify business requirements and develop data solutions
# - Collaborating with data scientists and analysts to design and implement data pipelines and ETL processes
# - Developing documentation and presenting results to stakeholders in a clear and concise manner
# - Staying up-to-date with the latest developments in retail analytics and AI/ML technologies.
#
# Requirements:
# - Bachelor's or Master's degree in Computer Science, Data Science, Statistics, Mathematics, or a related field
# - Strong proficiency in SQL and relational database management systems
# - Experience in data modeling and predictive analytics
# - Familiarity with Python or R is a plus
# - Excellent problem-solving skills and attention to detail
# - Ability to work in a fast-paced environment and multitask effectively
# - Strong written and verbal communication skills.
#
# If you are a passionate and driven individual who enjoys working at the cutting edge of technology, we encourage you to apply for this exciting opportunity. Join us in creating the future of retail analytics!"
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Nidhika-Tomar_customised_resumenidhika1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Nidhika-Tomar_customised_resumenidhika1.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumereema.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a wholesale IRB model development requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Resume - Reema Panday.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a wholesale IRB model development requirement. Mention that SAS is a must.
# Generated JD:
#   The Wholesale IRB Model Development Specialist will be responsible for creating and implementing a new wholesale IRB model to streamline the review process of research protocols submitted by multiple institutions. This position requires a strong proficiency in SAS programming language as it will be used extensively to analyze data, generate reports, and conduct statistical analysis of research results. The successful candidate will work closely with stakeholders from various departments, including research, legal, and compliance, to ensure that the new model meets all regulatory requirements while reducing review time and costs. A Bachelor's or Master's degree in a related field is preferred, with at least 3 years of experience in IRB review process, clinical research, and SAS programming language.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Resume - Reema Panday.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Resume - Reema Panday_customised_resumereema.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Resume - Reema Panday_customised_resumereema.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumereema1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a wholesale IRB model development requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Resume - Reema Panday.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a wholesale IRB model development requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Resume - Reema Panday.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Resume - Reema Panday_customised_resumereema1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Resume - Reema Panday_customised_resumereema1.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumerajvi.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SAS is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Rajvi Doshi_customised_resume.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Rajvi Doshi_customised_resume.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumerajvi1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Rajvi Doshi_customised_resumerajvi1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Rajvi Doshi_customised_resumerajvi1.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumerajviifrs9.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Rajvi Doshi_customised_resumerajviifrs9.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Rajvi Doshi_customised_resumerajviifrs9.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumerajviifrs91.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IFRS9 model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IFRS9 model validation requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Rajvi Doshi_customised_resumerajviifrs91.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Rajvi Doshi_customised_resumerajviifrs91.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumekundan.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SAS is a must.
# Generated JD:
#   Job Title: Retail Model Validation Specialist - SAS Expert
# Job Summary:
# The retail model validation specialist will be responsible for ensuring the accuracy and reliability of models used in retail operations. This role will require expertise in SAS programming language to validate and test models, identify any errors or issues, and provide recommendations on improvements.
#
# Key Responsibilities:
# • Conduct regular model validations to ensure compliance with regulatory requirements and best practices
# • Use SAS to analyze data, validate models, and perform statistical tests
# • Identify and document any errors or inconsistencies in models and suggest corrective actions
# • Collaborate with cross-functional teams including data science, analytics, IT, and operations to ensure models are accurately implemented
# • Develop documentation and reports on model validation results for regulatory and internal review
# • Continuously improve model validation processes to enhance accuracy and efficiency
#
# Skills and Qualifications:
# • Bachelor's degree in a related field such as mathematics, statistics, or computer science
# • 3+ years of experience in model validation or data analysis
# • Strong expertise in SAS programming language
# • Strong analytical skills with attention to detail
# • Ability to work in a fast-paced and dynamic environment
# • Excellent communication and collaboration skills.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Kundan_Kumar_customised_resumekundan.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Kundan_Kumar_customised_resumekundan.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumekundanIRB1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SQL is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Kundan_Kumar_customised_resumeKundanIRB1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Kundan_Kumar_customised_resumeKundanIRB1.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumekundanifrs9.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SAS is a must.
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Kundan_Kumar_customised_resumeKundanIFRS9.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Kundan_Kumar_customised_resumeKundanIFRS9.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumekundanifrs91.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SQL is a must.
# Generated JD:
#   "Job Title: Retail IRB Model Validation Specialist
#
# Job Summary:
# We are seeking a highly skilled and detail-oriented individual to join our team as a Retail IRB Model Validation Specialist. This individual will be responsible for ensuring the accuracy and integrity of data utilized in our retail model validation processes, while also leveraging SQL to analyze complex data sets. Successful candidates must have a strong background in SQL and possess excellent analytical and problem-solving skills.
#
# Key Responsibilities:
# * Conducting regular audits and validations of our retail models to ensure compliance with regulatory requirements and best practices
# * Utilizing SQL to gather and analyze large data sets, including customer transactional data, sales figures, and other relevant metrics
# * Identifying inconsistencies or errors in model results and developing strategies for corrective action
# * Collaborating with cross-functional teams, including data scientists, analysts, and business stakeholders, to ensure model accuracy and effectiveness
# * Preparing detailed reports and presentations outlining model validation findings and recommendations
# * Maintaining up-to-date knowledge of regulatory changes and best practices in the retail industry.
#
# Required Skills and Experience:
# * Bachelor's or master's degree in a related field, such as Computer Science, Mathematics or Statistics
# * At least 3 years of experience in model validation or data analysis, with a strong focus on SQL programming language
# * Strong analytical skills, including the ability to interpret complex data and draw meaningful insights
# * Excellent problem-solving abilities and attention to detail
# * Effective communication skills, both written and verbal, with the ability to collaborate with cross-functional teams
# * Familiarity with retail industry regulatory requirements is a plus.
#
# We offer competitive salaries, comprehensive benefits, and opportunities for career growth in a dynamic and fast-paced work environment."
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Kundan_Kumar.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Kundan_Kumar_customised_resumekundanifrs91.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Kundan_Kumar_customised_resumekundanifrs91.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumearnabirb.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SQL is a must.
# Generated JD:
#   "Job Description: We are seeking a skilled Retail IRB Model Validation Specialist with expertise in SQL to join our team. In this role, the Specialist will be responsible for validating and ensuring compliance of retail models used by our clients in their sales and marketing efforts. This position requires strong problem-solving skills, attention to detail, and a solid understanding of data analytics. If you have experience with SQL and are passionate about data validation, we encourage you to apply."
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\CV_Arnab Roy_Model_Validation_customised_resumearnabirb.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\CV_Arnab Roy_Model_Validation_customised_resumearnabirb.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumarnabirb1.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IRB model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IRB model validation requirement. Mention that SAS is a must.
# Generated JD:
#   "Job Title: Retail IRB Model Validation Specialist
#
# Job Summary/Description:
# We are seeking an experienced and detail-oriented Retail IRB Model Validation Specialist to join our team. The ideal candidate will have a strong background in SAS and be responsible for reviewing, validating and ensuring the accuracy of data submitted by retail pharmacies to our company's regulatory board. The role requires a high degree of attention to detail, critical thinking skills, and excellent communication abilities.
#
# Key Responsibilities:
# • Review and validate retail IRB submissions using SAS software
# • Ensure that all data meets compliance standards and is accurate and complete
# • Identify any discrepancies or inconsistencies and document findings in a clear and concise manner
# • Communicate findings to relevant stakeholders in a timely and professional manner
# • Maintain confidentiality of sensitive information at all times
# • Collaborate with cross-functional teams to ensure smooth operations and successful outcomes
# • Assist in the development and implementation of best practices and processes for IRB submissions and validation.
#
# Requirements:
# • Bachelor's degree in a related field such as computer science, statistics or business administration
# • 3+ years of experience in SAS programming and model validation
# • Strong analytical skills with an emphasis on attention to detail
# • Excellent communication skills both written and verbal
# • Proficient in Microsoft Office Suite applications
# • Ability to work effectively in a fast-paced, dynamic environment.
#
# We offer competitive compensation, excellent benefits, and a dynamic work environment that values teamwork, professional development, and work-life balance."
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\CV_Arnab Roy_Model_Validation_customised_resumarnabirb1.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\CV_Arnab Roy_Model_Validation_customised_resumarnabirb1.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumearnabifrs9.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must.
# Generated JD:
#   "Job Description: We are seeking a talented professional to join our team as an IFRS9 Model Validation Specialist. The successful candidate will be responsible for ensuring our models adhere to regulatory guidelines, particularly with regards to the new IFRS9 standard. To succeed in this role, the individual must have a strong background in financial modeling and a thorough understanding of SAS tools. This is an exciting opportunity to contribute to our organization's success while making a difference in the financial industry."
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\CV_Arnab Roy_Model_Validation_customised_resumearnabifrs9.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\CV_Arnab Roy_Model_Validation_customised_resumearnabifrs9.txt'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("❌ LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD from prompt → {prompt_text}")
    generated_jd = call_lmstudio(f"Create a detailed job description based on this prompt:\n{prompt_text}")
    if not generated_jd:
        print("JD generation failed.")
        return

    # ✅ Print generated JD for reference
    print("Generated JD:\n", generated_jd)

    print(f"Step 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("Step 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumearnabifrs91.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)
    return output_path

# %%
frontend_prompt = "Create a JD for a retail IFRS9 model validation requirement. Mention that SQL is a must."
uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf"

customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# Step 1: Generating JD from prompt → Create a JD for a retail IFRS9 model validation requirement. Mention that SQL is a must.
# Generated JD:
#   "Job Title: IFRS9 Model Validation Specialist
#
# Job Summary:
# We are seeking an experienced and analytically-minded individual to join our team as an IFRS9 Model Validation Specialist. The candidate will be responsible for ensuring the accuracy of financial statements prepared in accordance with the International Financial Reporting Standards (IFRS) through the validation of models used in these calculations. The position requires advanced skills in SQL and strong problem-solving abilities, combined with a solid background in finance or accounting.
#
# Key Responsibilities:
# • Validation of models used in IFRS9 calculations, including review of documentation, input data, and output results.
# • Identification of potential errors or inconsistencies and investigation of their root causes.
# • Collaboration with cross-functional teams to ensure the accuracy and reliability of financial data.
# • Preparation of detailed reports outlining validation findings and recommendations for improvement.
# • Ongoing monitoring of models and updates to maintain compliance with regulatory requirements.
# • Assistance in the development and implementation of new models and processes.
#
# Skill Requirements:
# • Advanced skills in SQL, including experience with querying large data sets and working with relational databases.
# • Strong analytical abilities and attention to detail.
# • Solid understanding of financial concepts and accounting principles.
# • Ability to work in a fast-paced environment with multiple projects simultaneously.
# • Excellent communication skills, both written and verbal.
# • Bachelor's degree in Finance, Accounting, or a related field."
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\CV_Arnab Roy_Model_Validation.pdf
# Step 3: Customizing resume using resume + generated JD
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\CV_Arnab Roy_Model_Validation_customised_resumearnabifrs91.txt
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\CV_Arnab Roy_Model_Validation_customised_resumearnabifrs91.txt'

# %%
# from sentence_transformers import SentenceTransformer, util

# # Load model (this downloads if not already present)
# model = SentenceTransformer('all-MiniLM-L6-v2')

# # Example JD and resume texts
# jd_text = "Looking for a data scientist with SQL, Python, and scorecard modeling experience."
# resume_text = "I have developed credit scorecard models and use SQL daily for querying and analysis."

# # Get embeddings
# jd_embedding = model.encode(jd_text, convert_to_tensor=True)
# resume_embedding = model.encode(resume_text, convert_to_tensor=True)

# # Compute cosine similarity
# similarity_score = util.cos_sim(jd_embedding, resume_embedding)

# print("Cosine Similarity:", similarity_score.item())  # Should be between 0 and 1
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sentence_transformers import SentenceTransformer, util
#       3 # Load model (this downloads if not already present)
#       4 model = SentenceTransformer('all-MiniLM-L6-v2')
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:3
#       1 __version__ = "2.2.2"
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
#       5 from .SentenceLabelDataset import SentenceLabelDataset
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:4
#       2 import logging
#       3 import gzip
# ----> 4 from .. import SentenceTransformer
#       5 from ..readers import InputExample
#       6 from typing import List
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\SentenceTransformer.py:12
#      10 from numpy import ndarray
#      11 import transformers
# ---> 12 from huggingface_hub import HfApi, HfFolder, Repository, hf_hub_url, cached_download
#      13 import torch
#      14 from torch import nn, Tensor, device
#
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\__init__.py)

# %%
# from sentence_transformers import SentenceTransformer, util

# # Load model
# model = SentenceTransformer('all-MiniLM-L6-v2')

# # Sample JD and Resume snippet
# jd = "Looking for a candidate with experience in retail scorecard development and strong SQL skills."
# resume = "Developed retail banking scorecards and performed SQL-based data extraction for model monitoring."

# # Get embeddings
# embedding_jd = model.encode(jd, convert_to_tensor=True)
# embedding_resume = model.encode(resume, convert_to_tensor=True)

# # Calculate cosine similarity
# similarity_score = util.cos_sim(embedding_jd, embedding_resume).item()
# print(f"BERT Cosine Similarity Score: {similarity_score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 from sentence_transformers import SentenceTransformer, util
#       3 # Load model
#       4 model = SentenceTransformer('all-MiniLM-L6-v2')
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\__init__.py:3
#       1 __version__ = "2.2.2"
#       2 __MODEL_HUB_ORGANIZATION__ = 'sentence-transformers'
# ----> 3 from .datasets import SentencesDataset, ParallelSentencesDataset
#       4 from .LoggingHandler import LoggingHandler
#       5 from .SentenceTransformer import SentenceTransformer
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\datasets\__init__.py:3
#       1 from .DenoisingAutoEncoderDataset import DenoisingAutoEncoderDataset
#       2 from .NoDuplicatesDataLoader import NoDuplicatesDataLoader
# ----> 3 from .ParallelSentencesDataset import ParallelSentencesDataset
#       4 from .SentencesDataset import SentencesDataset
#       5 from .SentenceLabelDataset import SentenceLabelDataset
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\datasets\ParallelSentencesDataset.py:4
#       2 import logging
#       3 import gzip
# ----> 4 from .. import SentenceTransformer
#       5 from ..readers import InputExample
#       6 from typing import List
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\sentence_transformers\SentenceTransformer.py:12
#      10 from numpy import ndarray
#      11 import transformers
# ---> 12 from huggingface_hub import HfApi, HfFolder, Repository, hf_hub_url, cached_download
#      13 import torch
#      14 from torch import nn, Tensor, device
#
# ImportError: cannot import name 'cached_download' from 'huggingface_hub' (c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\huggingface_hub\__init__.py)

# %%
# import os
# import fitz  # PyMuPDF
# import docx
# from sentence_transformers import SentenceTransformer, util
# import shutil
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 4
#       2 import fitz  # PyMuPDF
#       3 import docx
# ----> 4 from sentence_transformers import SentenceTransformer, util
#       5 import shutil
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

nlp = spacy.load("en_core_web_sm")

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- METRICS ----
def compute_tfidf_similarity(jd, resume):
    tfidf = TfidfVectorizer().fit_transform([jd, resume])
    return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]

def keyword_coverage(jd, resume):
    jd_keywords = set(token.text.lower() for token in nlp(jd) if token.is_alpha and not token.is_stop)
    resume_words = resume.lower()
    matched = [kw for kw in jd_keywords if kw in resume_words]
    return len(matched) / len(jd_keywords) if jd_keywords else 0, matched

def qualitative_relevance(jd, resume):
    jd_words = set(jd.lower().split())
    resume_words = set(resume.lower().split())
    overlap = jd_words.intersection(resume_words)
    return len(overlap) / len(jd_words) if jd_words else 0

def section_audit(text):
    sections = ["summary", "qualification", "experience", "technical", "skill"]
    present = [sec for sec in sections if sec in text.lower()]
    return present

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD with only Responsibilities, Requirements, Preferred Skills for prompt → {prompt_text}")
    jd_prompt = f"""Create a structured job description based only on the following three sections:
1. Responsibilities
2. Requirements
3. Preferred Skills

Prompt:
{prompt_text}
"""
    generated_jd = call_lmstudio(jd_prompt)
    if not generated_jd:
        print("JD generation failed.")
        return

    print("\nGenerated JD:\n", generated_jd)

    print(f"\nStep 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("\nStep 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    print("\n=== Raw Output from LLM ===\n")
    print(result)

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL | re.IGNORECASE)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL | re.IGNORECASE)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL | re.IGNORECASE)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL | re.IGNORECASE)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resume.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)

    # ---- ACCURACY METRICS ----
    tfidf_score = compute_tfidf_similarity(generated_jd, final_resume)
    keyword_match_ratio, matched_keywords = keyword_coverage(generated_jd, final_resume)
    qualitative_score = qualitative_relevance(generated_jd, final_resume)
    section_flags = section_audit(final_resume)

    print("\nAccuracy Metrics:")
    print(f"TF-IDF Similarity:            {tfidf_score:.2f}")
    print(f"Keyword Coverage Ratio:       {keyword_match_ratio:.2f}")
    print(f"Qualitative Relevance:        {qualitative_score:.2f}")
    print(f"Matched Keywords:             {matched_keywords}")
    print(f"Section Presence Flags:       {section_flags}\n")

    return output_path

# ---- RUN EXAMPLE ----
prompt = "Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must."
resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf"

customise_resume(prompt, resume_path)
# Out:
# Step 1: Generating JD with only Responsibilities, Requirements, Preferred Skills for prompt → Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must.
#
# Generated JD:
#
# Job Description - Retail Scorecards Model Development
#
# Position Summary:
# We are seeking an experienced developer with a strong background in data science and modeling to join our team in developing scorecards for the retail industry. This role involves analyzing sales, inventory, and customer data to create predictive models that will help our clients make informed business decisions. The ideal candidate should have experience working with SQL databases and be comfortable using Python or R for data analysis and visualization.
#
# Responsibilities:
# - Collaborate with sales and marketing teams to gather required data and insights
# - Develop scorecards using SQL databases and Python/R for data science
# - Create visualizations and presentations to communicate results to clients
# - Stay up-to-date with the latest trends and best practices in retail modeling
#
# Requirements:
# - Bachelor's or Master's degree in a related field (e.g., Computer Science, Statistics, Mathematics)
# - At least 3 years of experience working as a data scientist or model developer
# - Strong proficiency in SQL databases for retrieving and managing large datasets
# - Experience using Python or R for data analysis, visualization, and modeling
# - Solid understanding of statistical methods for predictive modeling
# - Excellent communication skills for presenting results to non-technical audiences
#
# Preferred Skills:
# - Familiarity with common retail metrics (e.g., conversion rate, average order value)
# - Familiarity with e-commerce platforms (e.g., Shopify, Magento) and their data structures
# - Experience working in a fast-paced environment with tight deadlines
# - Ability to work well in a team and collaborate with cross-functional teams.
#
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf
#
# Step 3: Customizing resume using resume + generated JD
#
# === Raw Output from LLM ===
#
#
# "Thank you for providing your resume and job description. Based on the information provided, I've reworked the relevant sections to align with the job requirements. Please find attached an updated version of your resume that is aligned with the given job description."
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Nidhika-Tomar_customised_resume.txt
#
# Accuracy Metrics:
# TF-IDF Similarity:            0.15
# Keyword Coverage Ratio:       0.11
# Qualitative Relevance:        0.08
# Matched Keywords:             ['retail', 'e', 'experience', 'summary', 'create', 'r', 'skills', 'model', 'technical', 'develop', 'sql', 'scorecards', 'development']
# Section Presence Flags:       ['summary', 'qualification', 'experience', 'technical', 'skill']
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Nidhika-Tomar_customised_resume.txt'

# %%
# # ---- USAGE ----
# frontend_prompt = "Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must."
# uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf"

# customise_resume(frontend_prompt, uploaded_resume_path)
# Out:
# 🔹 Step 1: Generating JD from prompt → Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must.
# 🔹 Generated JD:
#   "Job Title: Retail Scorecards Model Development Specialist
#
# Job Summary/Description:
# We are looking to hire a Retail Scorecards Model Development Specialist who will utilize his/her expertise in SQL to develop and optimize retail scorecards for our organization. The successful candidate will have the opportunity to work with a dynamic team and contribute to the continued growth of our business.
#
# Key Responsibilities:
# • Develop and maintain retail scorecards using SQL.
# • Analyze sales data to identify trends and provide recommendations based on findings.
# • Collaborate with cross-functional teams including merchandising, marketing, and operations to ensure successful implementation of scorecard results.
# • Conduct regular reviews of scorecard performance and make necessary adjustments to optimize results.
# • Maintain confidentiality of sensitive data and adhere to company's policies and procedures.
#
# Requirements:
# • Bachelor's degree in a related field such as Computer Science, Mathematics or Statistics.
# • At least 3 years of experience in SQL and model development.
# • Strong analytical skills and ability to work in a fast-paced environment.
# • Excellent communication skills with both technical and non-technical teams.
# • Proficient in Microsoft Excel or other spreadsheet software.
# • Ability to multitask and manage multiple projects simultaneously.
#
# We are an equal opportunity employer and welcome candidates from diverse backgrounds to apply for this position."
#
# 🔹 Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf
#
# 🔹 Step 3: Customizing resume using resume + generated JD
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 frontend_prompt = "Create a JD for a retail Scorecards model development requirement. Mention that SQL is a must."
#       3 uploaded_resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Nidhika-Tomar.pdf"
# ----> 5 customise_resume(frontend_prompt, uploaded_resume_path)
#
# Cell In[1], line 130, in customise_resume(prompt_text, resume_path)
#     127 experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL)
#     128 tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL)
# --> 130 with open(ey_template_path, "r", encoding="utf-8") as f:
#     131     template = f.read()
#     133 final_resume = template
#
# File c:\Users\HN338QQ\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path\\to\\EY_sample_resume_template.txt'

# %%
# print("\n📊 Accuracy Metrics:")
# print(f"TF-IDF Similarity:{tfidf_score:.2f}")
# print(f"Keyword Coverage Ratio:    {keyword_match_ratio:.2f}")
# print(f"Qualitative Relevance %:   {qualitative_rate:.2f}")
# print(f"Matched Keywords:          {matched_keywords}")
# print(f"Section Presence Flags:    {section_flags}")

# %%
import os
import fitz  # PyMuPDF
import docx
import re
import json
import requests
import time
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# ---- CONFIGURATION ----
ey_template_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\EY_sample_resume_template.txt"
output_dir = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes"
os.makedirs(output_dir, exist_ok=True)

nlp = spacy.load("en_core_web_sm")

# ---- LM Studio CALL ----
def call_lmstudio(prompt, model="zephyr-7b-beta.Q4_K_M.gguf", retries=3):
    url = "http://localhost:1234/v1/chat/completions"
    headers = {"Content-Type": "application/json"}
    payload = {
        "model": model,
        "messages": [{"role": "user", "content": prompt}],
        "temperature": 0.7,
        "stream": False
    }
    for attempt in range(retries):
        try:
            response = requests.post(url, headers=headers, data=json.dumps(payload), timeout=180)
            return response.json()['choices'][0]['message']['content']
        except Exception as e:
            if attempt == retries - 1:
                print("LLM call failed:", e)
                return ""
            time.sleep(2)

# ---- READ RESUME ----
def read_resume_text(file_path):
    if file_path.endswith(".pdf"):
        doc = fitz.open(file_path)
        return "\n".join([page.get_text() for page in doc])
    elif file_path.endswith(".docx"):
        doc = docx.Document(file_path)
        return "\n".join([p.text for p in doc.paragraphs if p.text.strip()])
    else:
        with open(file_path, "r", encoding="utf-8") as f:
            return f.read()

# ---- METRICS ----
def compute_tfidf_similarity(jd, resume):
    tfidf = TfidfVectorizer().fit_transform([jd, resume])
    return cosine_similarity(tfidf[0:1], tfidf[1:2])[0][0]

def keyword_coverage(jd, resume):
    jd_keywords = set(token.text.lower() for token in nlp(jd) if token.is_alpha and not token.is_stop)
    resume_words = resume.lower()
    matched = [kw for kw in jd_keywords if kw in resume_words]
    return len(matched) / len(jd_keywords) if jd_keywords else 0, matched

def qualitative_relevance(jd, resume):
    jd_words = set(jd.lower().split())
    resume_words = set(resume.lower().split())
    overlap = jd_words.intersection(resume_words)
    return len(overlap) / len(jd_words) if jd_words else 0

def section_audit(text):
    sections = ["summary", "qualification", "experience", "technical", "skill"]
    present = [sec for sec in sections if sec in text.lower()]
    return present

# ---- MAIN FUNCTION ----
def customise_resume(prompt_text, resume_path):
    candidate_name = os.path.splitext(os.path.basename(resume_path))[0]

    print(f"Step 1: Generating JD with only Responsibilities, Requirements, Preferred Skills for prompt → {prompt_text}")
    jd_prompt = f"""Create a structured job description based only on the following three sections:
1. Responsibilities
2. Requirements
3. Preferred Skills

Prompt:
{prompt_text}
"""
    generated_jd = call_lmstudio(jd_prompt)
    if not generated_jd:
        print("JD generation failed.")
        return

    print("\nGenerated JD:\n", generated_jd)

    print(f"\nStep 2: Reading resume → {resume_path}")
    resume_text = read_resume_text(resume_path)

    print("\nStep 3: Customizing resume using resume + generated JD")
    custom_prompt = f"""
You are a resume writer. Given the candidate's resume and the job description, rewrite the following sections to make the resume aligned with the JD. DO NOT INVENT DETAILS. Use only the content in the resume.

Resume:
{resume_text}

Job Description:
{generated_jd}

Provide the output in this format (with labels):
SUMMARY:
...

QUALIFICATIONS:
...

EXPERIENCE:
...

TECHNICAL_SKILLS:
...
"""

    result = call_lmstudio(custom_prompt)
    if not result:
        print("Customization failed.")
        return

    print("\n=== Raw Output from LLM ===\n")
    print(result)

    summary = re.search(r"SUMMARY:(.*?)QUALIFICATIONS:", result, re.DOTALL | re.IGNORECASE)
    qualifications = re.search(r"QUALIFICATIONS:(.*?)EXPERIENCE:", result, re.DOTALL | re.IGNORECASE)
    experience = re.search(r"EXPERIENCE:(.*?)TECHNICAL_SKILLS:", result, re.DOTALL | re.IGNORECASE)
    tech_skills = re.search(r"TECHNICAL_SKILLS:(.*)", result, re.DOTALL | re.IGNORECASE)

    # Read EY template
    with open(ey_template_path, "r", encoding="utf-8") as f:
        template = f.read()

    # Fill template
    final_resume = template
    final_resume = final_resume.replace("[CANDIDATE_NAME]", candidate_name)
    final_resume = final_resume.replace("[ROLE]", prompt_text)
    final_resume = final_resume.replace("[SUMMARY]", summary.group(1).strip() if summary else "")
    final_resume = final_resume.replace("[QUALIFICATIONS]", qualifications.group(1).strip() if qualifications else "")
    final_resume = final_resume.replace("[EXPERIENCE_PLACEHOLDER]", experience.group(1).strip() if experience else "")
    final_resume = final_resume.replace("[TECHNICAL_SKILLS]", tech_skills.group(1).strip() if tech_skills else "")

    # Save customized resume
    output_path = os.path.join(output_dir, f"{candidate_name}_customised_resumerajviifrs9.txt")
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(final_resume)

    print("✅ Resume customized and saved to:", output_path)

    # ---- ACCURACY METRICS ----
    tfidf_score = compute_tfidf_similarity(generated_jd, final_resume)
    keyword_match_ratio, matched_keywords = keyword_coverage(generated_jd, final_resume)
    qualitative_score = qualitative_relevance(generated_jd, final_resume)
    section_flags = section_audit(final_resume)

    print("\nAccuracy Metrics:")
    print(f"TF-IDF Similarity:            {tfidf_score:.2f}")
    print(f"Keyword Coverage Ratio:       {keyword_match_ratio:.2f}")
    print(f"Qualitative Relevance:        {qualitative_score:.2f}")
    print(f"Matched Keywords:             {matched_keywords}")
    print(f"Section Presence Flags:       {section_flags}\n")

    return output_path

# ---- RUN EXAMPLE ----
prompt = "Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must."
resume_path = r"C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf"

customise_resume(prompt, resume_path)
# Out:
# Step 1: Generating JD with only Responsibilities, Requirements, Preferred Skills for prompt → Create a JD for a retail IFRS9 model validation requirement. Mention that SAS is a must.
#
# Generated JD:
#
# Job Title: Model Validation Specialist - IFRS9
#
# Job Summary:
# We are seeking a skilled Model Validation Specialist with expertise in IFRS9 and strong knowledge of SAS to join our team. In this role, you will be responsible for ensuring the accuracy and reliability of our IFRS9 models while maintaining compliance with regulatory requirements. This is an exciting opportunity to work in a dynamic and fast-paced environment where your skills and expertise will make a significant contribution to the success of the company.
#
# Responsibilities:
# • Conduct regular validation tests of IFRS9 models using SAS to ensure accuracy, reliability, and compliance with regulatory requirements.
# • Prepare detailed documentation and reports on validation results for review by internal stakeholders and regulators.
# • Collaborate with cross-functional teams, including finance, risk management, and IT, to implement model validations and mitigate risks.
# • Stay up-to-date with the latest regulatory developments related to IFRS9 and best practices in model validation.
#
# Requirements:
# • Bachelor's degree in Finance, Accounting, or a related field.
# • Minimum of 3 years of experience in model validation or risk management, with a focus on IFRS9.
# • Strong analytical skills and attention to detail.
# • Excellent communication and collaboration abilities.
# • Proficient in SAS (Statistical Analysis System).
#
# Preferred Skills:
# • Familiarity with regulatory requirements related to IFRS9, such as Basel III and IFRR 2013.
# • Experience working in a financial services company or a multinational organization.
# • Strong problem-solving skills and ability to work in a fast-paced environment.
#
# Step 2: Reading resume → C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\Rawresumes\Rajvi Doshi.pdf
#
# Step 3: Customizing resume using resume + generated JD
#
# === Raw Output from LLM ===
#
#
# SUMMARY:
# Rajvi Doshi is a Model Validation Specialist with expertise in IFRS9 and experience in financial services. Her experience includes conducting regular validation tests of IFRS9 models using SAS to ensure accuracy, reliability, and compliance with regulatory requirements. Rajvi has a strong analytical skills set and pays special attention to detail while maintaining cross-functional collaboration with finance, risk management, and IT teams to implement model validations and mitigate risks.
#
# QUALIFICATIONS:
# • Bachelor's degree in Finance, Accounting, or a related field.
# • Minimum of 3 years of experience in Model Validation or Risk Management, with a focus on IFRS9.
#
# EXPERIENCE:
# Rajvi has worked as an Associate Director at CPM Risk Analytics and Kotak Mahindra Bank in her previous roles. At Standard Chartered Bank, she managed end-to-end development of Behaviour Scorecards for Credit Cards and CashOne (loan on cards) portfolios of ASEAN markets to be used in portfolio management actions like line management, cross-sell, collections, and IRB and IFRS9 PD models. At Kotak Mahindra Bank, she built propensity models to target opportunities for secured credit card, term deposit, life insurance, and other liability products. She devised a customer lifecycle management strategy for NTB (new to bank) customers to cross-sell insurance, trading, and consumer loans in first 6 months.
#
# TECHNICAL_SKILLS:
# • Proficient in SAS (Statistical Analysis System).
# • Strong analytical skills and attention to detail.
# • Excellent communication and collaboration abilities.
# ✅ Resume customized and saved to: C:\Users\HN338QQ\OneDrive - EY\Documents\raw and ey curated samples\final_customised_resumes\Rajvi Doshi_customised_resumerajviifrs9.txt
#
# Accuracy Metrics:
# TF-IDF Similarity:            0.68
# Keyword Coverage Ratio:       0.54
# Qualitative Relevance:        0.48
# Matched Keywords:             ['risks', 'analytical', 'functional', 'validations', 'related', 'bachelor', 'abilities', 'ensure', 'degree', 'statistical', 'role', 'excellent', 'financial', 'system', 'collaboration', 'services', 'accuracy', 'mitigate', 'requirements', 'experience', 'reliability', 'strong', 'summary', 'finance', 'management', 'regulatory', 'team', 'compliance', 'analysis', 'teams', 'skills', 'conduct', 'field', 'model', 'tests', 'cross', 'risk', 'attention', 'regular', 'years', 'detail', 'sas', 'minimum', 'maintaining', 'specialist', 'expertise', 'proficient', 'focus', 'validation', 'accounting', 'models', 'implement', 'ability', 'communication', 'work']
# Section Presence Flags:       ['summary', 'qualification', 'experience', 'technical', 'skill']
# 'C:\\Users\\HN338QQ\\OneDrive - EY\\Documents\\raw and ey curated samples\\final_customised_resumes\\Rajvi Doshi_customised_resumerajviifrs9.txt'
